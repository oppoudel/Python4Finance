# %% [markdown]
# ## Downloads all Stock Data from a Given Index for 5 Years

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "/Users/oppoudel/dev/Python4Finance/Stocks/"

# Start end date defaults
S_DATE = "2017-12-12"
E_DATE = "2022-12-10"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Function that Returns a Stock Dataframe from a CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Returns a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
# Total of 3482 tickers
tickers = get_column_from_csv("D:/Python for Finance/Wilshire-5000-Stocks.csv", "Ticker")
tickers

# for x in tickers:
#     print(x, end=", ")

print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Function that Saves Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        if df.empty:
            stocks_not_downloaded.append(ticker)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Get 5 Years of Data for the 1st 20 Stocks

# %%
# # Folder used to store stock data
# folder = "D:/Python for Finance/Wilshire_Stocks/"

# for x in range(20):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")

# %% [markdown]
# ## Stocks Not Downloaded

# %%
# stocks_not_downloaded

# %% [markdown]
# ## Get Next 80 Stocks

# %%
# for x in range(20, 100):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Rest of Stocks

# %%
# for x in range(3001, 3481):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Delete Empty Files

# %%
try:
  for x in missing_stocks:
    os.remove("/Users/oppoudel/dev/Python4Finance/Stocks/" + x + ".csv")
except FileNotFoundError:
  print("Couldn't Find " + x)

print("Finished")
# Out:
# Finished

# %% [markdown]
# ## Are FAANG Stocks Worth Investing in?

# %%
# Download just those stocks were are working with to make them up to date
# Facebook, Amazon, Apple, Netflix, Google
tickers = ["FB", "AMZN", "AAPL", "NFLX", "GOOG"]

for i in tickers:
    save_to_csv_from_yahoo("/Users/oppoudel/dev/Python4Finance/Stocks/", i)
    print("Finished " + i)
# Out:
# Get Data for :  FB
# /Users/oppoudel/dev/Python4Finance/Stocks/FB.csv  Saved
# Finished FB
# Get Data for :  AMZN
# /Users/oppoudel/dev/Python4Finance/Stocks/AMZN.csv  Saved
# Finished AMZN
# Get Data for :  AAPL
# /Users/oppoudel/dev/Python4Finance/Stocks/AAPL.csv  Saved
# Finished AAPL
# Get Data for :  NFLX
# /Users/oppoudel/dev/Python4Finance/Stocks/NFLX.csv  Saved
# Finished NFLX
# Get Data for :  GOOG
# /Users/oppoudel/dev/Python4Finance/Stocks/GOOG.csv  Saved
# Finished GOOG

# %%
fig = go.Figure()

# Get the dataframe with all FB's data
fb_df = get_stock_df_from_csv("FB")

# fb_df.head()

# Get closing price for the rest
amzn_df = get_stock_df_from_csv("AMZN")
aapl_df = get_stock_df_from_csv("AAPL")
nflx_df = get_stock_df_from_csv("NFLX")
goog_df = get_stock_df_from_csv("GOOG")

amzn_df

fb_plot = go.Scatter(x=fb_df.index, y=fb_df['Close'], name="Facebook")
amzn_plot = go.Scatter(x=amzn_df.index, y=amzn_df['Close'], name="Amazon")
aapl_plot = go.Scatter(x=aapl_df.index, y=aapl_df['Close'], name="Apple")
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")
goog_plot = go.Scatter(x=goog_df.index, y=goog_df['Close'], name="Google")

# Plot price changes
fig.add_trace(fb_plot)
fig.add_trace(amzn_plot)
fig.add_trace(aapl_plot)
fig.add_trace(nflx_plot)
fig.add_trace(goog_plot)

fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=800, width=1300, 
                  showlegend=True)
fig.show()

# This data isn't useful for our purposes because the scales are different
# We must calculate the daily returns for these stocks to get data we can
# work with
# Out:
# <div>                            <div id="bff182c0-7de7-4237-ae65-558c4ffcd665" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bff182c0-7de7-4237-ae65-558c4ffcd665")) {                    Plotly.newPlot(                        "bff182c0-7de7-4237-ae65-558c4ffcd665",                        [{"name":"Facebook","x":["2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10 ...

# %% [markdown]
# ## Daily Returns

# %% [markdown]
# For single stocks to find the daily return we subtract opening price from the closing price. Then you could multiply by the number of shares owned.
#
# We calculate a percentage rate of return for each day to compare investments.
# Simple Rate of Return = (End Price - Beginning Price) / Beginning Price OR (EP / BP) - 1

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df, ticker):
    df['daily_return'] = (df['Close'] / df['Close'].shift(1)) - 1
    # Save data to a CSV file
    df.to_csv(PATH + ticker + '.csv')
    return df

# %%
add_daily_return_to_df(fb_df, "FB")
add_daily_return_to_df(amzn_df, "AMZN")
add_daily_return_to_df(aapl_df, "AAPL")
add_daily_return_to_df(nflx_df, "NFLX")
add_daily_return_to_df(goog_df, "GOOG")
goog_df.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2017-04-24  851.200012  863.450012  849.859985  862.760010  1372500
# 2017-04-25  865.000000  875.000000  862.809998  872.299988  1672000
# 2017-04-26  874.229980  876.049988  867.747986  871.729980  1237200
# 2017-04-27  873.599976  875.400024  870.380005  874.250000  2026800
# 2017-04-28  910.659973  916.849976  905.770020  905.960022  3276300
#
#             Dividends  Stock Splits  daily_return
# Date
# 2017-04-24          0             0           NaN
# 2017-04-25          0             0      0.011058
# 2017-04-26          0             0     -0.000653
# 2017-04-27          0             0      0.002891
# 2017-04-28          0             0      0.036271

# %% [markdown]
# ## Get Cumulative Return

# %%
def add_cum_return_to_df(df, ticker):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    df.to_csv(PATH + ticker + '.csv')
    return df

# %%
add_cum_return_to_df(fb_df, "FB")
add_cum_return_to_df(amzn_df, "AMZN")
add_cum_return_to_df(aapl_df, "AAPL")
add_cum_return_to_df(nflx_df, "NFLX")
add_cum_return_to_df(goog_df, "GOOG")
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2017-04-24   851.200012   863.450012   849.859985   862.760010  1372500
# 2017-04-25   865.000000   875.000000   862.809998   872.299988  1672000
# 2017-04-26   874.229980   876.049988   867.747986   871.729980  1237200
# 2017-04-27   873.599976   875.400024   870.380005   874.250000  2026800
# 2017-04-28   910.659973   916.849976   905.770020   905.960022  3276300
# ...                 ...          ...          ...          ...      ...
# 2022-04-14  2612.989990  2614.205078  2542.229980  2545.060059  1171400
# 2022-04-18  2548.199951  2574.239990  2531.569092  2559.219971   745900
# 2022-04-19  2561.540039  2618.074951  2549.030029  2610.620117  1136000
# 2022-04-20  2625.679932  2638.469971  2557.881104  2564.909912  1130500
# 2022-04-21  2587.000000  2605.870117  2493.229980  2498.750000  1453013
#
#             Dividends  Stock Splits  daily_return  cum_return
# Date
# 2017-04-24          0             0           NaN         NaN
# 2017-04-25          0             0      0.011058    1.011058
# 2017-04-26          0             0     -0.000653    1.010397
# 2017-04-27          0             0      0.002891    1.013318
# 2017-04-28          0             0      0.036271    1.050072
# ...               ...           ...           ...         ...
# 2022-04-14          0             0     -0.023280    2.949905
# 2022-04-18          0             0      0.005564    2.966317
# 2022-04-19          0             0      0.020084    3.025894
# 2022-04-20          0             0     -0.017509    2.972912
# 2022-04-21          0             0     -0.025794    2.896228
#
# [1259 rows x 9 columns]

# %% [markdown]
# ## Merge Multiple Stocks in One Dataframe by Column Name

# %%
def merge_df_by_column_name(col_name, sdate, edate, *tickers):
    # Will hold data for all dataframes with the same column name
    mult_df = pd.DataFrame()
    
    for x in tickers:
        df = get_stock_df_from_csv(x)
        
        # NEW Check if your dataframe has duplicate indexes
        if not df.index.is_unique:
            # Delete duplicates 
            df = df.loc[~df.index.duplicated(), :]
        
        mask = (df.index >= sdate) & (df.index <= edate)
        mult_df[x] = df.loc[mask][col_name]
        
    return mult_df

# %%
mult_df = merge_df_by_column_name('cum_return',  S_DATE, 
                                  E_DATE, *tickers)
mult_df
# Out:
#                   FB      AMZN      AAPL      NFLX      GOOG
# Date
# 2017-12-12  1.216471  1.283962  1.209328  1.291316  1.205990
# 2017-12-13  1.225682  1.282915  1.213343  1.306125  1.206141
# 2017-12-14  1.226301  1.294079  1.212991  1.317945  1.216039
# 2017-12-15  1.238606  1.299457  1.225317  1.321838  1.233472
# 2017-12-18  1.243005  1.312064  1.242573  1.323924  1.248482
# ...              ...       ...       ...       ...       ...
# 2022-04-14  1.444834  3.343726  4.875123  2.371758  2.949905
# 2022-04-18  1.448890  3.367497  4.868635  2.349023  2.966317
# 2022-04-19  1.493847  3.484985  4.937356  2.423764  3.025894
# 2022-04-20  1.377741  3.394232  4.932342  1.572620  2.972912
# 2022-04-21  1.292844  3.268556  4.908452  1.517208  2.896228
#
# [1097 rows x 5 columns]

# %%
# Plot out cumulative returns on $1 in each stock since beginning of 2017
fig = px.line(mult_df, x=mult_df.index, y=mult_df.columns)
fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=800, width=1300, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="19181b70-247c-4ea2-af47-dff6383f3890" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19181b70-247c-4ea2-af47-dff6383f3890")) {                    Plotly.newPlot(                        "19181b70-247c-4ea2-af47-dff6383f3890",                        [{"hovertemplate":"variable=FB<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"FB","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"FB","showlegend":true,"x":["2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10","2018-05-11","2018-05-14","2018-05-15","2018-05-16","2018-05-17","2018-05-18","2018-05-21","2018-05-22","2018-05-23","2018-05-24","2018-05-25","2018-05-29","2018-05-30","2018-05-31","2018-06-01","2018-06-04","2018-06-05","2018-06-06","2018-06-07","2018-06-08","2018-06-11","2018-06-12","2018-06-13","2018-06-14","2018-06-15","2018-06-18","2018-06-19","2018-06-20","2018-06-21","2018-06-22","2018-06-25","2018-06-26","2018-06-27","2018-06-28","2018-06-29","2018-07-02","2018-07-03","2018-07-05","2018-07-06","2018-07-09","2018-07-10","2018-07-11","2018-07-12","2018-07-13","2018-07-16","2018-07-17","2018-07-18","2018-07-19","2018-07-20","2018-07-23","2018-07-24","2018-07-25","2018-07-26","2018-07-27","2018-07-30","2018-07-31","2018-08-01","2018-08-02","2018-08-03","2018-08-06","2018-08-07","2018-08-08","2018-08-09","2018-08-10","2018-08-13","2018-08-14","2018-08-15","2018-08-16","2018-08-17","2018-08-20","2018-08-21","2018-08-22","2018-08-23","2018-08-24","2018-08-27","2018-08-28","2018-08-29","2018-08-30","2018-08-31","2018-09-04","2018-09-05","2018-09-06","2018-09-07","2018-09-10","2018-09-11","2018-09-12","2018-09-13","2018-09-14","2018-09-17","2018-09-18","2018-09-19","2018-09-20","2018-09-21","2018-09-24","2018-09-25","2018-09-26","2018-09-27","2018-09-28","2018-10-01","2018-10-02","2018-10-03","2018-10-04","2018-10-05","2018-10-08","2018-10-09","2018-10-10","2018-10-11","2018-10-12","2018-10-15","2018-10-16","2018-10-17","2018-10-18","2018-10-19","2018-10-22","2018-10-23","2018-10-24","2018-10-25","2018-10-26","2018-10-29","2018-10-30","2018-10-31","2018-11-01","2018-11-02","2018-11-05","2018-11-06","2018-11-07","2018-11-08","2018-11-09","2018-11-12","2018-11-13","2018-11-14","2018-11-15","2018-11-16","2018-11-19","2018-11-20","2018-11-21","2018-11-23","2018-11-26","2018-11-27","2018-11-28","2018-11-29","2018-11-30","2018-12-03","2018-12-04","2018-12-06","2018-12-07","2018-12-10","201 ...

# %% [markdown]
# ## Create a Price / Volume Chart

# %%
fig = go.Figure()
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")

# Plot price changes
fig.add_trace(nflx_plot)

# Plot volume as bar graph
fig.add_trace(go.Bar(x=nflx_df.index, y=nflx_df['Volume']/200000, name='Volume Traded'))

fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=800, width=1300, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="d7de5a4f-6868-45ef-ad2e-a23018f7b3e4" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7de5a4f-6868-45ef-ad2e-a23018f7b3e4")) {                    Plotly.newPlot(                        "d7de5a4f-6868-45ef-ad2e-a23018f7b3e4",                        [{"name":"Netflix","x":["2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10" ...

# %% [markdown]
# ## Adding Bollinger Bands

# %% [markdown]
# Bollinger Bands plot 2 lines using a moving average and the standard deviation defines how far apart the lines are. They also are used to define if prices are to high or low. When bands tighten it is believed a sharp price move in some direction. Prices tend to bounce off of the bands which provides potential market actions.
#
# A strong trend should be noted if the price moves outside the band. If prices go over the resistance line it is in overbought territory and if it breaks through support it is a sign of an oversold position.
#
# You normally use 20 sessions when using them.

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)
def add_bollinger_bands(df):
    df['middle_band'] = df['Close'].rolling(window=20).mean()
    df['upper_band'] = df['middle_band'] + 1.96 * df['Close'].rolling(window=20).std()
    df['lower_band'] = df['middle_band'] - 1.96 * df['Close'].rolling(window=20).std()

# %%
stk_dfs = [fb_df, amzn_df, aapl_df, nflx_df, goog_df]

# %%
for x in stk_dfs:
    add_bollinger_bands(x)

# %%
fb_df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2017-04-24  144.960007  145.669998  144.339996  145.470001  14407200
# 2017-04-25  145.789993  147.149994  145.789993  146.490005  17767500
# 2017-04-26  147.089996  147.589996  146.089996  146.559998  12395000
# 2017-04-27  146.669998  147.750000  146.139999  147.699997  11275100
# 2017-04-28  149.500000  151.529999  149.070007  150.250000  30652200
# ...                ...         ...         ...         ...       ...
# 2022-04-14  214.889999  214.990005  210.000000  210.179993  18332700
# 2022-04-18  210.000000  213.380005  208.300003  210.770004  16580800
# 2022-04-19  210.520004  218.429993  209.000000  217.309998  20089900
# 2022-04-20  213.610001  214.160004  198.919998  200.419998  43036500
# 2022-04-21  201.600006  202.964996  185.580002  188.070007  49593568
#
#             Dividends  Stock Splits  daily_return  cum_return  middle_band  \
# Date
# 2017-04-24          0             0           NaN         NaN          NaN
# 2017-04-25          0             0      0.007012    1.007012          NaN
# 2017-04-26          0             0      0.000478    1.007493          NaN
# 2017-04-27          0             0      0.007778    1.015330          NaN
# 2017-04-28          0             0      0.017265    1.032859          NaN
# ...               ...           ...           ...         ...          ...
# 2022-04-14          0             0     -0.022373    1.444834   220.903502
# 2022-04-18          0             0      0.002807    1.448890   220.617502
# 2022-04-19          0             0      0.031029    1.493847   220.908501
# 2022-04-20          0             0     -0.077723    1.377741   220.097002
# 2022-04-21          0             0     -0.061621    1.292844   218.827502
#
#             upper_band  lower_band
# Date
# 2017-04-24         NaN         NaN
# 2017-04-25         NaN         NaN
# 2017-04-26         NaN         NaN
# 2017-04-27         NaN         NaN
# 2017-04-28         NaN         NaN
# ...                ...         ...
# 2022-04-14  234.038276  207.768728
# 2022-04-18  234.365791  206.869212
# 2022-04-19  234.100933  207.716070
# 2022-04-20  235.989939  204.204064
# 2022-04-21  239.911938  197.743065
#
# [1259 rows x 12 columns]

# %% [markdown]
# ## Plot with Bollinger Bands

# %%
def plot_with_boll_bands(ticker):
    save_to_csv_from_yahoo("/Users/oppoudel/dev/Python4Finance/Stocks/", ticker)

    df = get_stock_df_from_csv(ticker)

    add_bollinger_bands(df)
    
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
    high=df['High'], low=df['Low'],
    close=df['Close'], name="Candlestick")

    upper_line = go.Scatter(x=df.index, y=df['upper_band'], 
    line=dict(color='rgba(250, 0, 0, 0.75)', 
    width=1), name="Upper Band")

    mid_line = go.Scatter(x=df.index, y=df['middle_band'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=0.7), name="Middle Band")

    lower_line = go.Scatter(x=df.index, y=df['lower_band'], 
    line=dict(color='rgba(0, 250, 0, 0.75)', 
    width=1), name="Lower Band")

    fig.add_trace(candle)
    fig.add_trace(upper_line)
    fig.add_trace(mid_line)
    fig.add_trace(lower_line)

    fig.update_xaxes(title="Date", rangeslider_visible=True)
    fig.update_yaxes(title="Price")
    fig.update_layout(title=ticker + " Bollinger Bands", 
    height=800, width=1300, showlegend=True)
    fig.show()

# %%
plot_with_boll_bands("AMD")
# Out:
# Get Data for :  AMD
# /Users/oppoudel/dev/Python4Finance/Stocks/AMD.csv  Saved
# <div>                            <div id="2e6304d7-6e23-44b4-8d88-24f5a54f2d00" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e6304d7-6e23-44b4-8d88-24f5a54f2d00")) {                    Plotly.newPlot(                        "2e6304d7-6e23-44b4-8d88-24f5a54f2d00",                        [{"close":[13.130000114440918,13.489999771118164,13.40999984741211,13.619999885559082,13.300000190734863,13.619999885559082,10.31999969482422,10.390000343322754,10.100000381469728,10.1899995803833,10.039999961853027,10.18000030517578,10.789999961853027,11.06999969482422,11.260000228881836,11.420000076293944,12.75,11.199999809265137,11.279999732971191,11.40999984741211,11.039999961853027,10.890000343322754,10.890000343322754,10.979999542236328,11.0,11.119999885559082,11.1899995803833,10.93000030517578,10.899999618530272,11.239999771118164,12.029999732971191,12.380000114440918,12.899999618530272,12.279999732971191,12.09000015258789,11.960000038146973,11.770000457763672,11.5,11.4399995803833,11.93000030517578,12.640000343322754,13.979999542236328,14.380000114440918,14.170000076293944,14.079999923706056,13.399999618530272,13.229999542236328,12.600000381469728,12.479999542236328,12.149999618530272,13.1899995803833,13.020000457763672,13.359999656677246,13.8100004196167,13.890000343322754,14.289999961853027,13.529999732971191,13.920000076293944,13.800000190734863,13.479999542236328,13.550000190734863,13.800000190734863,13.880000114440918,14.15999984741211,14.109999656677246,14.760000228881836,14.119999885559082,13.949999809265137,13.609999656677246,13.710000038146973,13.369999885559082,13.239999771118164,13.119999885559082,13.43000030517578,13.109999656677246,12.829999923706056,12.119999885559082,12.229999542236328,12.760000228881836,13.020000457763672,12.630000114440918,12.34000015258789,12.369999885559082,12.050000190734863,12.170000076293944,12.479999542236328,12.5,12.43000030517578,12.229999542236328,12.149999618530272,12.670000076293944,13.0,13.1899995803833,12.920000076293944,12.859999656677246,12.630000114440918,12.25,12.550000190734863,12.300000190734863,12.220000267028809,12.260000228881836,12.520000457763672,13.079999923706056,13.119999885559082,13.739999771118164,13.40999984741211,13.300000190734863,12.609999656677246,12.449999809265137,12.739999771118164,12.739999771118164,12.75,12.710000038146973,13.420000076293944,13.3100004196167,13.34000015258789,13.229999542236328,13.470000267028809,13.699999809265137,13.880000114440918,14.199999809265137,14.220000267028809,14.260000228881836,14.15999984741211,14.06999969482422,13.949999809265137,13.8100004196167,14.100000381469728,14.25,12.329999923706056,12.010000228881836,11.84000015258789,10.890000343322754,10.989999771118164,10.800000190734863,10.850000381469728,11.119999885559082,11.93000030517578,12.050000190734863,11.710000038146973,11.119999885559082,11.260000228881836,11.09000015258789,11.119999885559082,11.06999969482422,11.25,11.380000114440918,11.34000015258789,11.399999618530272,11.369999885559082,11.380000114440918,11.550000190734863,11.170000076293944,10.829999923706056,10.890000343322754,10.729999542236328,10.029999732971191,9.90999984741211,10.0,10.039999961853027,9.9399995803833,10.15999984741211,9.899999618530272,10.109999656677246,10.130000114440918,10.289999961853027,10.979999542236328,10.949999809265137,10.979999542236328,10.890000343322754,10.539999961853027,10.460000038146973,10.529999732971191,10.550000190734863,10.279999732971191,10.979999542236328,11.550000190734863,12.119999885559082,11.880000114440918,12.279999732971191,11.81999969482422,11.960000038146973,12.140000343322754,12.020000457763672,11.90999984741211,12.18000030517578,12.470000267028809,12.59000015258789,12.649999618530272,12.9399995803833,12.710000038146973,12.4099998474 ...

# %% [markdown]
# ## Support & Resistance

# %% [markdown]
# We normally use multiple moving averages to develop our support and resistance lines. 50 day for medium, 100 for long and 200 for very long terms are commonly used.

# %% [markdown]
# ## Download S&P Data for 5 years

# %%
save_to_csv_from_yahoo(PATH, "^GSPC")
gspc_df = get_stock_df_from_csv("^GSPC")
gspc_df
# Out:
# Get Data for :  ^GSPC
# /Users/oppoudel/dev/Python4Finance/Stocks/^GSPC.csv  Saved
#                    Open         High          Low        Close      Volume  \
# Date
# 2017-04-24  2370.330078  2376.979980  2369.189941  2374.149902  3690650000
# 2017-04-25  2381.510010  2392.479980  2381.149902  2388.610107  3995240000
# 2017-04-26  2388.979980  2398.159912  2386.780029  2387.449951  4105920000
# 2017-04-27  2389.699951  2392.100098  2382.679932  2388.770020  4098460000
# 2017-04-28  2393.679932  2393.679932  2382.360107  2384.199951  3718270000
# ...                 ...          ...          ...          ...         ...
# 2022-04-14  4449.120117  4460.459961  4390.770020  4392.589844  3634740000
# 2022-04-18  4385.629883  4410.310059  4370.299805  4391.689941  3509340000
# 2022-04-19  4390.629883  4471.029785  4390.629883  4462.209961  3197930000
# 2022-04-20  4472.259766  4488.290039  4448.759766  4459.450195  3678040000
# 2022-04-21  4489.169922  4512.939941  4384.470215  4393.660156  2637237000
#
#             Dividends  Stock Splits
# Date
# 2017-04-24          0             0
# 2017-04-25          0             0
# 2017-04-26          0             0
# 2017-04-27          0             0
# 2017-04-28          0             0
# ...               ...           ...
# 2022-04-14          0             0
# 2022-04-18          0             0
# 2022-04-19          0             0
# 2022-04-20          0             0
# 2022-04-21          0             0
#
# [1259 rows x 7 columns]

# %% [markdown]
# ## Calculate Moving Averages

# %% [markdown]
# Moving averages are used to mitigate short term flucuations in a stock price. We create them by calculating the mean of a set of prices over a specified number of time periods. The Simple moving average (SMA) is just a simple mean. An Exponential Moving Average (EMA) is a weighted average that put more emphasis on more recent data.

# %%
# SMA
gspc_df['MA50'] = gspc_df['Close'].rolling(50).mean()
gspc_df['MA100'] = gspc_df['Close'].rolling(100).mean()

# EMA If we set adjust to False the weighted function is calculated recursively
gspc_df['EMA20'] = gspc_df['Close'].ewm(span=20, adjust=False).mean()
gspc_df['EMA50'] = gspc_df['Close'].ewm(span=50, adjust=False).mean()
gspc_df['EMA100'] = gspc_df['Close'].ewm(span=100, adjust=False).mean()

gspc_df
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2017-04-24  2370.330078  2376.979980  2369.189941  2374.149902  3690650000
# 2017-04-25  2381.510010  2392.479980  2381.149902  2388.610107  3995240000
# 2017-04-26  2388.979980  2398.159912  2386.780029  2387.449951  4105920000
# 2017-04-27  2389.699951  2392.100098  2382.679932  2388.770020  4098460000
# 2017-04-28  2393.679932  2393.679932  2382.360107  2384.199951  3718270000
# ...                 ...          ...          ...          ...         ...
# 2022-04-14  4449.120117  4460.459961  4390.770020  4392.589844  3634740000
# 2022-04-18  4385.629883  4410.310059  4370.299805  4391.689941  3509340000
# 2022-04-19  4390.629883  4471.029785  4390.629883  4462.209961  3197930000
# 2022-04-20  4472.259766  4488.290039  4448.759766  4459.450195  3678040000
# 2022-04-21  4489.169922  4512.939941  4384.470215  4393.660156  2637237000
#
#             Dividends  Stock Splits         MA50        MA100        EMA20  \
# Date
# 2017-04-24          0             0          NaN          NaN  2374.149902
# 2017-04-25          0             0          NaN          NaN  2375.527065
# 2017-04-26          0             0          NaN          NaN  2376.662578
# 2017-04-27          0             0          NaN          NaN  2377.815667
# 2017-04-28          0             0          NaN          NaN  2378.423694
# ...               ...           ...          ...          ...          ...
# 2022-04-14          0             0  4418.384600  4522.684502  4461.339525
# 2022-04-18          0             0  4416.669600  4519.772002  4454.706232
# 2022-04-19          0             0  4415.903203  4517.487100  4455.420873
# 2022-04-20          0             0  4415.414805  4515.067002  4455.804618
# 2022-04-21          0             0  4412.857207  4513.057402  4449.886098
#
#                   EMA50       EMA100
# Date
# 2017-04-24  2374.149902  2374.149902
# 2017-04-25  2374.716969  2374.436243
# 2017-04-26  2375.216302  2374.693940
# 2017-04-27  2375.747820  2374.972674
# 2017-04-28  2376.079276  2375.155393
# ...                 ...          ...
# 2022-04-14  4458.158233  4474.011658
# 2022-04-18  4455.551633  4472.381525
# 2022-04-19  4455.812744  4472.180108
# 2022-04-20  4455.955389  4471.928030
# 2022-04-21  4453.512439  4470.378172
#
# [1259 rows x 12 columns]

# %% [markdown]
# ## Plotting Moving Averages

# %%
fig = go.Figure()

candle = go.Candlestick(x=gspc_df.index, open=gspc_df['Open'],
    high=gspc_df['High'], low=gspc_df['Low'],
    close=gspc_df['Close'], name="Candlestick")

ema50_line = go.Scatter(x=gspc_df.index, y=gspc_df['EMA50'], 
    line=dict(color='rgba(250, 0, 0, 0.75)', 
    width=1), name="EMA50")

ema100_line = go.Scatter(x=gspc_df.index, y=gspc_df['EMA100'], 
    line=dict(color='rgba(0, 250, 0, 0.75)', 
    width=1), name="EMA100")

fig.add_trace(candle)
# 1st support line
fig.add_trace(ema50_line)
# 2nd support line
fig.add_trace(ema100_line)

fig.show()

# What we see with the support line is that if we hit it the market bounces back. When candles are green that means we have more buyers than sellers and vice versa.
# Support levels are good indicators and the market normally only breaks support when an event occurs that is external to the market.
# Out:
# <div>                            <div id="fd5913ea-355d-45dd-b7d7-d1f610109781" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd5913ea-355d-45dd-b7d7-d1f610109781")) {                    Plotly.newPlot(                        "fd5913ea-355d-45dd-b7d7-d1f610109781",                        [{"close":[2249.260009765625,2238.830078125,2257.830078125,2270.75,2269.0,2276.97998046875,2268.89990234375,2268.89990234375,2275.320068359375,2270.43994140625,2274.639892578125,2267.889892578125,2271.889892578125,2263.68994140625,2271.31005859375,2265.199951171875,2280.070068359375,2298.3701171875,2296.679931640625,2294.68994140625,2280.89990234375,2278.8701171875,2279.550048828125,2280.85009765625,2297.419921875,2292.56005859375,2293.080078125,2294.669921875,2307.8701171875,2316.10009765625,2328.25,2337.580078125,2349.25,2347.219970703125,2351.159912109375,2365.3798828125,2362.820068359375,2363.81005859375,2367.340087890625,2369.75,2363.639892578125,2395.9599609375,2381.919921875,2383.1201171875,2375.31005859375,2368.389892578125,2362.97998046875,2364.8701171875,2372.60009765625,2373.469970703125,2365.449951171875,2385.260009765625,2381.3798828125,2378.25,2373.469970703125,2344.02001953125,2348.449951171875,2345.9599609375,2343.97998046875,2341.590087890625,2358.570068359375,2361.1298828125,2368.06005859375,2362.719970703125,2358.840087890625,2360.159912109375,2352.949951171875,2357.489990234375,2355.5400390625,2357.159912109375,2353.780029296875,2344.929931640625,2328.949951171875,2349.010009765625,2342.18994140625,2338.169921875,2355.840087890625,2348.68994140625,2374.14990234375,2388.610107421875,2387.449951171875,2388.77001953125,2384.199951171875,2388.330078125,2391.169921875,2388.1298828125,2389.52001953125,2399.2900390625,2399.3798828125,2396.919921875,2399.6298828125,2394.43994140625,2390.89990234375,2402.320068359375,2400.669921875,2357.030029296875,2365.719970703125,2381.72998046875,2394.02001953125,2398.419921875,2404.389892578125,2415.070068359375,2415.820068359375,2412.909912109375,2411.800048828125,2430.06005859375,2439.070068359375,2436.10009765625,2429.330078125,2433.139892578125,2433.7900390625,2431.77001953125,2429.389892578125,2440.35009765625,2437.919921875,2432.4599609375,2433.14990234375,2453.4599609375,2437.030029296875,2435.610107421875,2434.5,2438.300048828125,2439.070068359375,2419.3798828125,2440.68994140625,2419.699951171875,2423.409912109375,2429.010009765625,2432.5400390625,2409.75,2425.179931640625,2427.429931640625,2425.530029296875,2443.25,2447.830078125,2459.27001953125,2459.139892578125,2460.610107421875,2473.830078125,2473.449951171875,2472.5400390625,2469.909912109375,2477.1298828125,2477.830078125,2475.419921875,2472.10009765625,2470.300048828125,2476.35009765625,2477.570068359375,2472.159912109375,2476.830078125,2480.909912109375,2474.919921875,2474.02001953125,2438.2099609375,2441.320068359375,2465.840087890625,2464.610107421875,2468.110107421875,2430.010009765625,2425.550048828125,2428.3701171875,2452.510009765625,2444.0400390625,2438.969970703125,2443.050048828125,2444.239990234375,2446.300048828125,2457.590087890625,2471.64990234375,2476.550048828125,2457.85009765625,2465.5400390625,2465.10009765625,2461.429931640625,2488.110107421875,2496.47998046875,2498.3701171875,2495.6201171875,2500.22998046875,2503.8701171875,2506.64990234375,2508.239990234375,2500.60009765625,2502.219970703125,2496.659912109375,2496.840087890625,2507.0400390625,2510.06005859375,2519.360107421875,2529.1201171875,2534.580078125,2537.739990234375,2552.070068359375,2549.330078125,2544.72998046875,2550.639892578125,2555.239990234375,2550.929931640625,2553.169921875,2557.639892578125,2559.360107421875,2561.260009765625,2562.10009765625,2575.2099609375,2564.97998046875,2569.1298828125,2557.149902 ...

# %% [markdown]
# ## Analyzing Bitcoin

# %%
btc_df = yf.download(tickers='BTC-USD', period='3d', interval='15m')
btc_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2022-04-19 00:00:00+00:00  40828.175781  40906.359375  40825.128906
# 2022-04-19 00:15:00+00:00  41022.519531  41022.519531  40911.394531
# 2022-04-19 00:30:00+00:00  40936.355469  41146.886719  40936.355469
# 2022-04-19 00:45:00+00:00  41036.046875  41036.046875  40933.039062
# 2022-04-19 01:00:00+00:00  40931.214844  40931.214844  40894.179688
# ...                                 ...           ...           ...
# 2022-04-21 22:30:00+00:00  40688.503906  40688.503906  40063.828125
# 2022-04-21 22:45:00+00:00  40310.593750  40443.187500  40310.593750
# 2022-04-21 23:00:00+00:00  40397.136719  40463.800781  40397.136719
# 2022-04-21 23:15:00+00:00  40459.761719  40459.761719  40370.968750
# 2022-04-21 23:30:00+00:00  40420.929688  40420.929688  40420.929688
#
#                                   Close     Adj Close     Volume
# Datetime
# 2022-04-19 00:00:00+00:00  40904.992188  40904.992188  131694592
# 2022-04-19 00:15:00+00:00  40934.261719  40934.261719  208801792
# 2022-04-19 00:30:00+00:00  41036.796875  41036.796875  401954816
# 2022-04-19 00:45:00+00:00  40939.136719  40939.136719   50886656
# 2022-04-19 01:00:00+00:00  40906.390625  40906.390625   11370496
# ...                                 ...           ...        ...
# 2022-04-21 22:30:00+00:00  40288.910156  40288.910156  994777088
# 2022-04-21 22:45:00+00:00  40400.535156  40400.535156  616816640
# 2022-04-21 23:00:00+00:00  40463.800781  40463.800781  281980928
# 2022-04-21 23:15:00+00:00  40416.406250  40416.406250  205160448
# 2022-04-21 23:30:00+00:00  40420.929688  40420.929688          0
#
# [287 rows x 6 columns]

# %%
# We'll create a short term moving average using 5 periods
# and another using 20 periods
# When the longterm MA goes above the short term that is a sell sign
# and vice versa
btc_df['MA5'] = btc_df['Close'].rolling(5).mean()
btc_df['MA20'] = btc_df['Close'].rolling(20).mean()

# %% [markdown]
# ## Plot

# %%
fig = go.Figure()

candle = go.Candlestick(x=btc_df.index, open=btc_df['Open'],
    high=btc_df['High'], low=btc_df['Low'],
    close=btc_df['Close'], name="Candlestick")

ma5_line = go.Scatter(x=btc_df.index, y=btc_df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

ma20_line = go.Scatter(x=btc_df.index, y=btc_df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

fig.add_trace(candle)
fig.add_trace(ma5_line)
fig.add_trace(ma20_line)

fig.show()

# When the MA20 (Blue) crosses above the MA5 (Orange) that is a Death Cross (Sell)
# When the MA5 (Orange) crosses above the MA20 (Blue)that is a Golden Cross (Buy)
# Out:
# <div>                            <div id="0b71b167-125c-42fb-9b3a-4d0df7885f2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b71b167-125c-42fb-9b3a-4d0df7885f2b")) {                    Plotly.newPlot(                        "0b71b167-125c-42fb-9b3a-4d0df7885f2b",                        [{"close":[40904.9921875,40934.26171875,41036.796875,40939.13671875,40906.390625,40883.515625,40839.0625,40780.4140625,40733.96484375,40736.87890625,40729.57421875,40664.1640625,40723.578125,40731.3515625,40715.15625,40712.375,40734.0859375,40788.3515625,40797.05859375,40844.91015625,40824.140625,40728.875,40721.38671875,40691.16015625,40722.6953125,40771.19921875,40748.765625,40732.9765625,40727.00390625,40700.015625,40664.50390625,40674.91015625,40756.1484375,40807.71484375,40797.45703125,40752.8984375,40746.140625,40636.62890625,40671.4375,40655.78125,40718.05078125,40739.28125,40747.27734375,40787.6015625,40766.7734375,40808.52734375,40776.31640625,40771.2890625,40854.83984375,40901.4921875,41032.79296875,40964.3046875,40890.70703125,40970.03125,41035.3671875,41392.67578125,41569.36328125,41531.21875,41543.1484375,41604.74609375,41672.9609375,41525.734375,41489.79296875,41477.109375,41497.671875,41507.96484375,41298.58984375,41353.2734375,41288.26171875,41259.828125,41304.1015625,41337.62890625,41334.05859375,41380.1953125,41428.078125,41409.0625,41468.42578125,41498.34375,41460.140625,41419.31640625,41321.0703125,41318.5234375,41265.21875,41293.83984375,41283.4375,41288.890625,41318.67578125,41316.453125,41353.8046875,41348.12890625,41427.30078125,41401.296875,41444.38671875,41456.07421875,41485.33203125,41502.28125,41510.55859375,41295.7578125,41347.9921875,41340.625,41304.1015625,41344.33984375,41347.21875,41362.2734375,41384.2265625,41333.9453125,41345.7890625,41364.94921875,41381.08203125,41368.765625,41323.140625,41377.24609375,41368.65625,41328.34375,41291.58203125,41318.58203125,41316.48828125,41368.59375,41408.44921875,41440.80859375,41435.9296875,41407.7421875,41411.44140625,41441.25390625,41507.796875,41362.11328125,41352.44140625,41356.51953125,41379.3046875,41396.72265625,41457.453125,41476.15625,41499.9765625,41544.234375,41567.0625,41535.62890625,41505.37109375,41751.125,41792.73046875,41795.54296875,41767.28515625,41848.7265625,41997.1953125,42074.328125,42008.0390625,42018.04296875,42111.1171875,42119.33984375,42015.99609375,42043.41796875,41747.2890625,41583.46484375,41656.421875,41646.05859375,41637.453125,41581.796875,41327.2578125,41158.55078125,41223.00390625,41273.13671875,41232.515625,41092.66796875,41333.37890625,41370.9375,41367.05859375,41335.2109375,41335.23828125,41339.578125,41337.51171875,41204.05078125,41005.91796875,40961.09765625,41095.67578125,41196.90234375,41204.41796875,41205.27734375,41231.0078125,41187.4765625,41304.92578125,41405.28125,41402.9453125,41519.84765625,41460.33984375,41493.87890625,41495.25,41532.46484375,41546.640625,41494.30078125,41370.20703125,41414.4609375,41367.4609375,41377.84375,41465.96484375,41425.3984375,41510.58984375,41539.38671875,41521.56640625,41605.65625,41702.359375,41671.0,41703.25,41690.17578125,41607.234375,41639.07421875,41632.2890625,41632.18359375,41643.52734375,41688.98828125,41700.234375,41659.640625,41572.00390625,41610.90625,41651.26953125,41628.60546875,41529.3125,41476.47265625,41503.6796875,41501.31640625,41531.84765625,41536.8203125,41500.29296875,41601.82421875,41633.13671875,41793.26953125,41799.41015625,41823.82421875,41896.55859375,41921.4296875,41880.50390625,41869.48046875,41796.58984375,41817.05078125,41879.97265625,42217.1015625,42253.609375,42283.92578125,42334.15625,42390.65625,42506.93359375,42432.4609375,42485.18359375,42479.81640625,42594.04296875,42709.74609375,42654.59765625,42811.23046875,42768.43359375, ...

# %% [markdown]
# ## Longterm Bitcoin

# %%
# btcl_df = yf.download(tickers='BTC-USD', period='3mo', interval='1d')
# btcl_df

# %%
# btcl_df['MA5'] = btcl_df['Close'].rolling(5).mean()
# btcl_df['MA20'] = btcl_df['Close'].rolling(20).mean()

# %%
# fig = go.Figure()

# candle = go.Candlestick(x=btcl_df.index, open=btcl_df['Open'],
#     high=btcl_df['High'], low=btcl_df['Low'],
#     close=btcl_df['Close'], name="Candlestick")

# ma5_line = go.Scatter(x=btcl_df.index, y=btcl_df['MA5'], 
#     line=dict(color='rgba(255,165,0, 0.75)', 
#     width=1), name="MA5")

# ma20_line = go.Scatter(x=btcl_df.index, y=btcl_df['MA20'], 
#     line=dict(color='rgba(0, 0, 250, 0.75)', 
#     width=1), name="MA20")

# fig.add_trace(candle)
# fig.add_trace(ma5_line)
# fig.add_trace(ma20_line)

# fig.show()

# We see here that we are in a down trend long term

# %% [markdown]
# ## Short Term Plot Function

# %%
def get_short_ma(ticker):
    df = yf.download(tickers=ticker, period='3d', interval='15m')
    df['MA5'] = df['Close'].rolling(5).mean()
    df['MA20'] = df['Close'].rolling(20).mean()
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
        high=df['High'], low=df['Low'],
        close=df['Close'], name="Candlestick")

    ma5_line = go.Scatter(x=df.index, y=df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

    ma20_line = go.Scatter(x=df.index, y=df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

    fig.add_trace(candle)
    fig.add_trace(ma5_line)
    fig.add_trace(ma20_line)

    fig.show()

# %% [markdown]
# ## Long Term Plot Function

# %%
def get_long_ma(ticker):
    df = yf.download(tickers=ticker, period='3mo', interval='1d')
    df['MA5'] = df['Close'].rolling(5).mean()
    df['MA20'] = df['Close'].rolling(20).mean()
    fig = go.Figure()

    candle = go.Candlestick(x=df.index, open=df['Open'],
        high=df['High'], low=df['Low'],
        close=df['Close'], name="Candlestick")

    ma5_line = go.Scatter(x=df.index, y=df['MA5'], 
    line=dict(color='rgba(255,165,0, 0.75)', 
    width=1), name="MA5")

    ma20_line = go.Scatter(x=df.index, y=df['MA20'], 
    line=dict(color='rgba(0, 0, 250, 0.75)', 
    width=1), name="MA20")

    fig.add_trace(candle)
    fig.add_trace(ma5_line)
    fig.add_trace(ma20_line)

    fig.show()

# %% [markdown]
# ## Long Term Ethereum Plot

# %%
get_long_ma('ETH-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="76be1388-24d8-4afa-864c-71506d084265" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76be1388-24d8-4afa-864c-71506d084265")) {                    Plotly.newPlot(                        "76be1388-24d8-4afa-864c-71506d084265",                        [{"close":[2405.18115234375,2535.0390625,2440.352294921875,2455.93505859375,2468.0302734375,2423.001220703125,2547.092041015625,2597.084716796875,2603.466552734375,2688.27880859375,2792.1171875,2682.85400390625,2679.16259765625,2983.5869140625,3014.648193359375,3057.47607421875,3142.470703125,3122.608642578125,3239.45703125,3077.482177734375,2927.383544921875,2917.36279296875,2883.46337890625,2933.47900390625,3179.877197265625,3127.830078125,2881.48193359375,2785.7275390625,2763.701171875,2628.6484375,2573.816162109375,2639.29931640625,2590.359619140625,2598.067138671875,2764.53564453125,2781.11181640625,2621.8017578125,2919.201171875,2972.485107421875,2950.118408203125,2834.468994140625,2617.156005859375,2664.8310546875,2555.037353515625,2497.771240234375,2576.74755859375,2729.783447265625,2608.048583984375,2559.56298828125,2574.754150390625,2518.944580078125,2590.696044921875,2620.149658203125,2772.0556640625,2814.8544921875,2945.343017578125,2946.257080078125,2860.459228515625,2897.9765625,2973.131103515625,3031.067138671875,3108.06201171875,3106.67138671875,3143.178955078125,3291.57763671875,3336.634521484375,3401.98779296875,3385.157958984375,3281.642822265625,3449.55224609375,3445.059326171875,3522.83349609375,3521.2412109375,3411.79248046875,3171.69189453125,3233.274658203125,3192.073974609375,3261.916259765625,3211.866943359375,2981.05224609375,3030.37646484375,3118.34423828125,3019.909423828125,3040.91650390625,3062.310302734375,2993.4033203125,3057.606689453125,3104.1064453125,3077.745849609375,2988.209228515625],"high":[2615.247314453125,2542.144775390625,2537.20849609375,2498.507080078125,2705.7841796875,2510.45166015625,2548.778564453125,2627.609375,2631.408447265625,2697.7353515625,2802.3154296875,2802.212158203125,2712.482666015625,2983.5869140625,3054.130126953125,3061.26123046875,3182.5283203125,3219.47265625,3263.15576171875,3271.316162109375,3127.45068359375,2980.079345703125,2947.776611328125,2957.963623046875,3185.520751953125,3181.616943359375,3154.615234375,2937.30859375,2826.347900390625,2763.756591796875,2752.45849609375,2648.916748046875,2741.368408203125,2689.047607421875,2821.972412109375,2849.424072265625,2831.12548828125,2929.180419921875,3029.651611328125,3026.8681640625,2964.67333984375,2835.17626953125,2679.1025390625,2673.63720703125,2639.943115234375,2618.166015625,2761.79638671875,2729.116455078125,2664.55859375,2606.438720703125,2594.5498046875,2604.034423828125,2662.32958984375,2781.30712890625,2826.16064453125,2973.6162109375,2979.987060546875,2956.965576171875,2954.556640625,3040.3828125,3036.752197265625,3118.3876953125,3183.9580078125,3146.825439453125,3291.57763671875,3424.019287109375,3470.186279296875,3435.2861328125,3435.12841796875,3467.555908203125,3521.28466796875,3573.960205078125,3535.148193359375,3546.706787109375,3411.672119140625,3263.474609375,3301.607421875,3261.963134765625,3303.003173828125,3214.4619140625,3077.45263671875,3123.575439453125,3139.9287109375,3044.287353515625,3074.886962890625,3075.77587890625,3062.52099609375,3125.084228515625,3157.8857421875,3172.4091796875],"low":[2330.247314453125,2381.51513671875,2172.30126953125,2359.384765625,2417.68310546875,2328.4521484375,2367.833740234375,2526.98974609375,2550.4609375,2489.072265625,2682.621826171875,2630.120361328125,2587.783447265625,2675.44384765625,2966.781005859375,2965.429931640625,3002.927001953125,3038.3779296875,3063.16015625,3070.378173828125,2888.707763671875,2870.177001953125,284 ...

# %% [markdown]
# ## Short Term Ethereum Plot

# %%
get_short_ma('ETH-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="8d577a0a-8595-4980-927f-500f89befddc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d577a0a-8595-4980-927f-500f89befddc")) {                    Plotly.newPlot(                        "8d577a0a-8595-4980-927f-500f89befddc",                        [{"close":[3101.76220703125,3077.6103515625,3081.089599609375,3080.3662109375,3076.62353515625,3080.15576171875,3084.08837890625,3089.265625,3088.553955078125,3085.030517578125,3085.275146484375,3086.431884765625,3088.169677734375,3084.79541015625,3081.42236328125,3089.1962890625,3088.91748046875,3085.411376953125,3082.941162109375,3084.0576171875,3083.6845703125,3086.6416015625,3090.44873046875,3096.060791015625,3102.013427734375,3098.117431640625,3097.46728515625,3100.169677734375,3106.111083984375,3095.0830078125,3094.1708984375,3091.835205078125,3094.0244140625,3097.732666015625,3100.197265625,3099.8046875,3101.577392578125,3108.4501953125,3108.218017578125,3104.910400390625,3100.89306640625,3113.595458984375,3122.74609375,3122.227294921875,3119.93359375,3124.57763671875,3130.634033203125,3148.73193359375,3141.875,3146.50146484375,3154.540283203125,3157.793212890625,3146.51416015625,3147.93212890625,3122.85302734375,3101.4931640625,3105.798828125,3106.80126953125,3105.923095703125,3102.87548828125,3082.561767578125,3062.865966796875,3065.71337890625,3069.542236328125,3068.006591796875,3060.4765625,3078.56298828125,3081.259033203125,3078.841064453125,3077.04443359375,3076.71142578125,3079.0703125,3077.415283203125,3064.326416015625,3046.75146484375,3047.58837890625,3057.990966796875,3068.559814453125,3072.5869140625,3071.051025390625,3069.22119140625,3064.669189453125,3073.32568359375,3082.920166015625,3080.597900390625,3083.931640625,3080.834228515625,3082.84765625,3083.810791015625,3090.573974609375,3091.762939453125,3087.477294921875,3075.86572265625,3080.36279296875,3076.254638671875,3077.703857421875,3084.728759765625,3075.881591796875,3082.140869140625,3086.388671875,3083.997314453125,3091.138671875,3097.56396484375,3097.701171875,3101.6005859375,3098.617919921875,3092.974853515625,3092.221923828125,3090.147216796875,3089.886962890625,3091.805419921875,3095.75830078125,3100.548828125,3095.361083984375,3085.109130859375,3086.54248046875,3089.4140625,3089.115234375,3082.879150390625,3075.0400390625,3075.617431640625,3075.6015625,3078.8935546875,3078.624267578125,3076.257080078125,3084.230712890625,3087.905029296875,3097.8232421875,3097.89599609375,3097.438720703125,3098.01171875,3099.887939453125,3098.041015625,3097.68017578125,3089.9091796875,3089.860107421875,3095.798095703125,3118.010009765625,3126.8193359375,3128.786376953125,3136.562744140625,3137.9951171875,3151.656005859375,3149.34521484375,3153.43798828125,3147.476318359375,3152.58837890625,3165.899169921875,3157.269287109375,3164.67041015625,3164.14111328125,3158.21533203125,3151.27099609375,3149.417724609375,3147.074462890625,3146.453125,3148.52587890625,3148.098388671875,3125.2041015625,3112.85986328125,3101.243896484375,3099.50390625,3096.824462890625,3088.408935546875,3080.90966796875,3083.949462890625,3069.779541015625,3068.291259765625,3064.632080078125,3069.407470703125,3070.512939453125,3063.207763671875,3053.947021484375,3055.84912109375,3053.553466796875,3035.2138671875,3025.463134765625,3028.25927734375,3005.232666015625,3001.83740234375,3007.99658203125,3005.556884765625,2987.480712890625],"high":[3103.93505859375,3103.6162109375,3083.044677734375,3085.180908203125,3081.0771484375,3080.26806640625,3084.08837890625,3089.706787109375,3088.553955078125,3088.800048828125,3086.7607421875,3086.431884765625,3088.1875,3087.719970703125,3085.534912109375,3089.1962890625,3090.272705078125,3089.640869140625,3085.18408203125,3085.23681640625 ...

# %% [markdown]
# ## Long Term Litecoin

# %%
get_long_ma('LTC-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="41f0ee22-bd87-49e1-8bc3-fb05e7b6e2ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41f0ee22-bd87-49e1-8bc3-fb05e7b6e2ed")) {                    Plotly.newPlot(                        "41f0ee22-bd87-49e1-8bc3-fb05e7b6e2ed",                        [{"close":[108.42849731445312,112.08950805664062,109.59159851074219,108.06637573242188,107.28218078613281,106.9535140991211,109.43273162841797,110.82367706298828,108.79985809326172,109.58769989013672,115.4020004272461,108.55602264404297,110.28700256347656,120.91803741455078,121.91674041748047,127.44550323486328,137.10739135742188,133.99124145507812,140.17160034179688,135.08839416503906,126.03115844726562,126.68367767333984,126.20421600341797,124.80005645751953,131.7626190185547,128.1608428955078,116.30241394042969,115.19709014892578,115.7090072631836,110.83203887939453,103.45049285888672,107.52279663085938,105.96595001220703,104.2304916381836,109.26631164550781,108.24365997314453,103.10559844970703,113.47457885742188,112.5440444946289,110.35135650634766,111.35211944580078,101.39179992675781,104.97718811035156,101.59391784667969,98.8692626953125,100.61764526367188,106.94209289550781,102.65550994873047,104.9653549194336,105.8323974609375,102.11479949951172,105.67365264892578,106.98857116699219,111.35919189453125,110.31023406982422,112.1158676147461,116.3732681274414,114.82913970947266,116.15872955322266,122.92796325683594,122.47541809082031,126.5812759399414,124.06736755371094,124.88133239746094,129.39747619628906,127.93861389160156,130.0612335205078,131.16934204101562,123.71601104736328,124.8831787109375,124.9234848022461,128.9462127685547,124.86170196533203,123.21317291259766,112.46133422851562,114.23019409179688,110.88206481933594,112.77727508544922,111.17377471923828,102.60739135742188,104.82841491699219,110.48245239257812,107.41104125976562,111.10934448242188,114.43070983886719,109.04278564453125,111.22614288330078,113.81208801269531,111.97969055175781,106.99688720703125],"high":[116.67909240722656,112.39445495605469,112.19467163085938,109.68234252929688,115.78300476074219,109.46898651123047,109.83932495117188,111.85406494140625,112.042724609375,110.9894027709961,116.3658218383789,115.88226318359375,110.28700256347656,120.92221069335938,123.39488220214844,127.44550323486328,139.24339294433594,142.35386657714844,140.7852020263672,143.23289489746094,135.0928497314453,127.5803451538086,128.6428985595703,126.63776397705078,132.11190795898438,131.76744079589844,128.73141479492188,121.5430679321289,116.9888687133789,115.70782470703125,114.31229400634766,107.60649871826172,110.81077575683594,106.20594024658203,110.33592987060547,113.2392578125,109.87517547607422,113.47457885742188,115.579833984375,114.24375915527344,112.50371551513672,112.35623168945312,105.35140991210938,105.60908508300781,103.66204071044922,102.16033172607422,109.04586029052734,106.97227478027344,106.56657409667969,107.76637268066406,107.20188903808594,105.77667236328125,108.43423461914062,111.36539459228516,111.42870330810547,112.78976440429688,116.3732681274414,117.76000213623047,116.62821197509766,123.14498901367188,124.09307098388672,127.2931900024414,127.09410095214844,125.3609390258789,129.39747619628906,132.4124755859375,131.78604125976562,133.9067840576172,132.77642822265625,125.9663314819336,128.0952911376953,129.3058319091797,128.90708923339844,127.07330322265625,123.24894714355469,114.8778305053711,115.08161926269531,112.78964233398438,114.36927032470703,111.15314483642578,105.67218780517578,110.66858673095703,112.1144790649414,112.62550354003906,114.53565216064453,114.96900939941406,111.32576751708984,113.99000549316406,113.92158508300781,114.19917297363281],"low":[99.7610092163086,106.59941864013672,98.66522216796875,106.33942413 ...

# %% [markdown]
# ## Long Term Cardano

# %%
get_long_ma('ADA-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="f981cdc9-ae30-46ec-9c69-bc1403ee6f4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f981cdc9-ae30-46ec-9c69-bc1403ee6f4a")) {                    Plotly.newPlot(                        "f981cdc9-ae30-46ec-9c69-bc1403ee6f4a",                        [{"close":[1.066715955734253,1.122370958328247,1.0665980577468872,1.0435739755630493,1.0790469646453857,1.0435329675674438,1.0506060123443604,1.0595699548721313,1.0374729633331299,1.0523029565811157,1.0886240005493164,1.028905987739563,1.0564440488815308,1.1356240510940552,1.1273449659347534,1.1445469856262207,1.1973069906234741,1.1787199974060059,1.1948100328445435,1.1524779796600342,1.080346941947937,1.0581990480422974,1.0458190441131592,1.050266981124878,1.1075860261917114,1.0849809646606445,1.0198949575424194,0.9971129894256592,0.9977030158042908,0.9329019784927368,0.8582360148429871,0.8890169858932495,0.8691689968109131,0.8534250259399414,0.8980270028114319,0.8879179954528809,0.858335018157959,0.9598280191421509,0.9623460173606873,0.9386619925498962,0.902658998966217,0.8428890109062195,0.8656719923019409,0.8237519860267639,0.7973790168762207,0.8012499809265137,0.8492929935455322,0.8063160181045532,0.7901250123977661,0.7906739711761475,0.7909950017929077,0.8039169907569885,0.8000059723854065,0.8383740186691284,0.8367840051651001,0.8534330129623413,0.9010990262031555,0.8770920038223267,0.916782021522522,0.9764400124549866,1.1074819564819336,1.130010962486267,1.0978879928588867,1.1505939960479736,1.1821479797363281,1.1701840162277222,1.1911120414733887,1.1903849840164185,1.1418509483337402,1.1654249429702759,1.1560070514678955,1.1859409809112549,1.2129449844360352,1.170801043510437,1.052770972251892,1.0918940305709839,1.0263259410858154,1.0450149774551392,1.0308849811553955,0.92044997215271,0.955145001411438,0.9746959805488586,0.9324120283126831,0.9547169804573059,0.9526399970054626,0.9174659848213196,0.9367300271987915,0.9533330202102661,0.9373409748077393,0.9104743599891663],"high":[1.1521949768066406,1.1648730039596558,1.1243380308151245,1.0720239877700806,1.1496479511260986,1.0787349939346313,1.0583430528640747,1.0806139707565308,1.0753459930419922,1.0576039552688599,1.09231698513031,1.1002399921417236,1.057224988937378,1.1356240510940552,1.1728849411010742,1.1478029489517212,1.206853985786438,1.257815957069397,1.2121570110321045,1.2186670303344727,1.162572979927063,1.0914069414138794,1.0709439516067505,1.0527809858322144,1.1133660078048706,1.1105409860610962,1.0915119647979736,1.0413110256195068,1.0178539752960205,0.9976289868354797,0.9862470030784607,0.8937559723854065,0.9554309844970703,0.8823419809341431,0.9065409898757935,0.9282960295677185,0.9126759767532349,0.9676129817962646,1.0054030418395996,0.9736289978027344,0.9440789818763733,0.9030500054359436,0.8809400200843811,0.87049800157547,0.845475971698761,0.8191480040550232,0.8614310026168823,0.8505759835243225,0.8171470165252686,0.8008009791374207,0.8190249800682068,0.8120750188827515,0.8156219720840454,0.8386319875717163,0.8558800220489502,0.8588799834251404,0.9129210114479065,0.9146029949188232,0.9275990128517151,0.9850329756736755,1.1074819564819336,1.185750961303711,1.1638150215148926,1.1572309732437134,1.1833950281143188,1.242864966392517,1.2393579483032227,1.216668963432312,1.2263200283050537,1.1729730367660522,1.193843960762024,1.1985429525375366,1.2403579950332642,1.2173930406570435,1.1716070175170898,1.0984690189361572,1.097432017326355,1.0450750589370728,1.0680299997329712,1.0306710004806519,0.9808549880981445,0.9781529903411865,0.9836239814758301,0.9579880237579346,0.9610810279846191,0.96151202917099,0.9373679757118225,0.954662024974823,0.9747350215911865,0.969402551651001],"low":[0.9333969950675964,1.056931972503662,0.959124028682708 ...

# %% [markdown]
# ## Get Stock File Names in a List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers
# tickers.remove('.ds_Store')
tickers.sort()
len(tickers)
# Out:
# 2908

# %% [markdown]
# ## Add Daily & Cumulative Return to All Stock Data

# %%
for x in tickers:
    try:
        print("Working on :", x)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df, x)
        new_df = add_cum_return_to_df(new_df, x)
        new_df.to_csv(PATH + x + '.csv')
    except Exception as ex:
        print(ex)
# Out:
# Working on : A
# File Doesn't Exist
# 'NoneType' object is not subscriptable
# Working on : AA
# 'Close'
# Working on : AAL
# 'Close'
# Working on : AAME
# 'Close'
# Working on : AAOI
# 'Close'
# Working on : AAON
# 'Close'
# Working on : AAP
# 'Close'
# Working on : AAPL
# Working on : AAT
# 'Close'
# Working on : AAWW
# 'Close'
# Working on : ABBV
# 'Close'
# Working on : ABC
# 'Close'
# Working on : ABCB
# 'Close'
# Working on : ABEO
# 'Close'
# Working on : ABG
# 'Close'
# Working on : ABIO
# 'Close'
# Working on : ABM
# 'Close'
# Working on : ABMD
# 'Close'
# Working on : ABR
# 'Close'
# Working on : ABT
# 'Close'
# Working on : ABTX
# 'Close'
# Working on : AC
# 'Close'
# Working on : ACAD
# 'Close'
# Working on : ACBI
# 'Close'
# Working on : ACC
# 'Close'
# Working on : ACCO
# 'Close'
# Working on : ACER
# 'Close'
# Working on : ACGL
# 'Close'
# Working on : ACHC
# 'Close'
# Working on : ACHV
# 'Close'
# Working on : ACIW
# 'Close'
# Working on : ACLS
# 'Close'
# Working on : ACM
# 'Close'
# Working on : ACMR
# 'Close'
# Working on : ACN
# 'Close'
# Working on : ACNB
# 'Close'
# Working on : ACOR
# 'Close'
# Working on : ACRE
# 'Close'
# Working on : ACRS
# 'Close'
# Working on : ACRX
# 'Close'
# Working on : ACTG
# 'Close'
# Working on : ACU
# 'Close'
# Working on : ACY
# 'Close'
# Working on : ADBE
# 'Close'
# Working on : ADC
# 'Close'
# Working on : ADES
# 'Close'
# Working on : ADI
# 'Close'
# Working on : ADM
# 'Close'
# Working on : ADMA
# 'Close'
# Working on : ADMP
# 'Close'
# Working on : ADMS
# 'Close'
# Working on : ADNT
# 'Close'
# Working on : ADP
# 'Close'
# Working on : ADS
# 'Close'
# Working on : ADSK
# 'Close'
# Working on : ADTN
# 'Close'
# Working on : ADUS
# 'Close'
# Working on : ADVM
# 'Close'
# Working on : ADXS
# 'Close'
# Working on : AE
# 'Close'
# Working on : AEE
# 'Close'
# Working on : AEHR
# 'Close'
# Working on : AEIS
# 'Close'
# Working on : AEL
# 'Close'
# Working on : AEMD
# 'Close'
# Working on : AEO
# 'Close'
# Working on : AEP
# 'Close'
# Working on : AERI
# 'Close'
# Working on : AES
# 'Close'
# Working on : AEY
# 'Close'
# Working on : AFG
# 'Close'
# Working on : AFI
# 'Close'
# Working on : AFL
# 'Close'
# Working on : AGCO
# 'Close'
# Working on : AGEN
# 'Close'
# Working on : AGFS
# 'Close'
# Working on : AGIO
# 'Close'
# Working on : AGLE
# 'Close'
# Working on : AGM
# 'Close'
# Working on : AGNC
# 'Close'
# Working on : AGO
# 'Close'
# Working on : AGR
# 'Close'
# Working on : AGRX
# 'Close'
# Working on : AGTC
# 'Close'
# Working on : AGX
# 'Close'
# Working on : AGYS
# 'Close'
# Working on : AHH
# 'Close'
# Working on : AHT
# 'Close'
# Working on : AIG
# 'Close'
# Working on : AIMC
# 'Close'
# Working on : AIN
# 'Close'
# Working on : AINC
# 'Close'
# Working on : AIR
# 'Close'
# Working on : AIRG
# 'Close'
# Working on : AIRI
# 'Close'
# Working on : AIRT
# 'Close'
# Working on : AIT
# 'Close'
# Working on : AIV
# 'Close'
# Working on : AIZ
# 'Close'
# Working on : AJG
# 'Close'
# Working on : AJRD
# 'Close'
# Working on : AJX
# 'Close'
# Working on : AKAM
# 'Close'
# Working on : AKBA
# 'Close'
# Working on : AKR
# 'Close'
# Working on : AKTS
# 'Close'
# Working on : AL
# 'Close'
# Working on : ALB
# 'Close'
# Working on : ALBO
# 'Close'
# Working on : ALCO
# 'Close'
# Working on : ALDX
# 'Close'
# Working on : ALE
# 'Close'
# Working on : ALEX
# 'Close'
# Working on : ALG
# 'Close'
# Working on : ALGN
# 'Close'
# Working on : ALGT
# 'Close'
# Working on : ALJJ
# 'Close'
# Working on : ALK
# 'Close'
# Working on : ALKS
# 'Close'
# Working on : ALL
# 'Close'
# Working on : ALLE
# 'Close'
# Working on : ALLY
# 'Close'
# Working on : ALNA
# 'Close'
# Working on : ALNY
# 'Close'
# Working on : ALOT
# 'Close'
# Working on : ALPN
# 'Close'
# Working on : ALRM
# 'Close'
# Working on : ALSN
# 'Close'
# Working on : ALT
# 'Close'
# Working on : ALTR
# 'Close'
# Working on : ALV
# 'Close'
# Working on : ALX
# 'Close'
# Working on : ALXN
# 'Close'
# Working on : AM
# 'Close'
# Working on : AMAT
# 'Close'
# Working on : AMBC
# 'Close'
# Working on : AMC
# 'Close'
# Working on : AMCX
# 'Close'
# Working on : AMD
# Working on : AME
# 'Close'
# Working on : AMED
# 'Close'
# Working on : AMG
# 'Close'
# Working on : AMGN
# 'Close'
# Working on : AMH
# 'Close'
# Working on : AMKR
# 'Close'
# Working on : AMN
# 'Close'
# Working on : AMNB
# 'Close'
# Working on : AMOT
# 'Close'
# Working on : AMP
# 'Close'
# Working on : AMPE
# 'Close'
# Working on : AMPH
# 'Close'
# Working on : AMRC
# 'Close'
# Working on : AMRK
# 'Close'
# Working on : AMRS
# 'Close'
# Working on : AMS
# 'Close'
# Working on : AMSC
# 'Close'
# Working on : AMSF
# 'Close'
# Working on : AMSWA
# 'Close'
# Working on : AMT
# 'Close'
# Working on : AMTX
# 'Close'
# Working on : AMWD
# 'Close'
# Working on : AMZN
# Working on : AN
# 'Close'
# Working on : ANAB
# 'Close'
# Working on : ANAT
# 'Close'
# Working on : ANDE
# 'Close'
# Working on : ANET
# 'Close'
# Working on : ANF
# 'Close'
# Working on : ANGI
# 'Close'
# Working on : ANGO
# 'Close'
# Working on : ANIK
# 'Close'
# Working on : ANIP
# 'Close'
# Working on : ANIX
# 'Close'
# Working on : ANSS
# 'Close'
# Working on : ANTM
# 'Close'
# Working on : AON
# 'Close'
# Working on : AOS
# 'Close'
# Working on : AOSL
# 'Close'
# Working on : AP
# 'Close'
# Working on : APA
# 'Close'
# Working on : APAM
# 'Close'
# Working on : APD
# 'Close'
# Working on : APDN
# 'Close'
# Working on : APEI
# 'Close'
# Working on : APEN
# 'Close'
# Working on : APH
# 'Close'
# Working on : APLE
# 'Close'
# Working on : APLS
# 'Close'
# Working on : APOG
# 'Close'
# Working on : APPF
# 'Close'
# Working on : APPN
# 'Close'
# Working on : APPS
# 'Close'
# Working on : APRN
# 'Close'
# Working on : APT
# 'Close'
# Working on : APTS
# 'Close'
# Working on : APTV
# 'Close'
# Working on : APVO
# 'Close'
# Working on : AQB
# 'Close'
# Working on : AQMS
# 'Close'
# Working on : AQUA
# 'Close'
# Working on : AR
# 'Close'
# Working on : ARAV
# 'Close'
# Working on : ARAY
# 'Close'
# Working on : ARC
# 'Close'
# Working on : ARCB
# 'Close'
# Working on : ARCH
# 'Close'
# Working on : ARDX
# 'Close'
# Working on : ARE
# 'Close'
# Working on : ARES
# 'Close'
# Working on : ARGO
# 'Close'
# Working on : ARI
# 'Close'
# Working on : ARKR
# 'Close'
# Working on : ARL
# 'Close'
# Working on : ARMK
# 'Close'
# Working on : ARNA
# 'Close'
# Working on : AROC
# 'Close'
# Working on : AROW
# 'Close'
# Working on : ARR
# 'Close'
# Working on : ARTNA
# 'Close'
# Working on : ARTW
# 'Close'
# Working on : ARW
# 'Close'
# Working on : ARWR
# 'Close'
# Working on : ASB
# 'Close'
# Working on : ASGN
# 'Close'
# Working on : ASH
# 'Close'
# Working on : ASIX
# 'Close'
# Working on : ASMB
# 'Close'
# Working on : ASPN
# 'Close'
# Working on : ASPS
# 'Close'
# Working on : ASRT
# 'Close'
# Working on : ASRV
# 'Close'
# Working on : ASTC
# 'Close'
# Working on : ASTE
# 'Close'
# Working on : ASUR
# 'Close'
# Working on : ASYS
# 'Close'
# Working on : ATEC
# 'Close'
# Working on : ATEN
# 'Close'
# Working on : ATGE
# 'Close'
# Working on : ATH
# 'Close'
# Working on : ATHX
# 'Close'
# Working on : ATI
# 'Close'
# Working on : ATKR
# 'Close'
# Working on : ATLC
# 'Close'
# Working on : ATLO
# 'Close'
# Working on : ATNI
# 'Close'
# Working on : ATNM
# 'Close'
# Working on : ATNX
# 'Close'
# Working on : ATO
# 'Close'
# Working on : ATOS
# 'Close'
# Working on : ATR
# 'Close'
# Working on : ATRA
# 'Close'
# Working on : ATRC
# 'Close'
# Working on : ATRI
# 'Close'
# Working on : ATRO
# 'Close'
# Working on : ATRS
# 'Close'
# Working on : ATSG
# 'Close'
# Working on : ATUS
# 'Close'
# Working on : ATVI
# 'Close'
# Working on : AUBN
# 'Close'
# Working on : AUMN
# 'Close'
# Working on : AUTO
# 'Close'
# Working on : AVA
# 'Close'
# Working on : AVAV
# 'Close'
# Working on : AVB
# 'Close'
# Working on : AVD
# 'Close'
# Working on : AVEO
# 'Close'
# Working on : AVGO
# 'Close'
# Working on : AVGR
# 'Close'
# Working on : AVID
# 'Close'
# Working on : AVNS
# 'Close'
# Working on : AVNW
# 'Close'
# Working on : AVT
# 'Close'
# Working on : AVXL
# 'Close'
# Working on : AVY
# 'Close'
# Working on : AVYA
# 'Close'
# Working on : AWI
# 'Close'
# Working on : AWK
# 'Close'
# Working on : AWR
# 'Close'
# Working on : AWRE
# 'Close'
# Working on : AX
# 'Close'
# Working on : AXAS
# 'Close'
# Working on : AXDX
# 'Close'
# Working on : AXGN
# 'Close'
# Working on : AXL
# 'Close'
# Working on : AXP
# 'Close'
# Working on : AXR
# 'Close'
# Working on : AXS
# 'Close'
# Working on : AXSM
# 'Close'
# Working on : AXTA
# 'Close'
# Working on : AXTI
# 'Close'
# Working on : AYI
# 'Close'
# Working on : AYX
# 'Close'
# Working on : AZO
# 'Close'
# Working on : AZPN
# 'Close'
# Working on : AZZ
# 'Close'
# Working on : B
# 'Close'
# Working on : BA
# 'Close'
# Working on : BAC
# 'Close'
# Working on : BAH
# 'Close'
# Working on : BANC
# 'Close'
# Working on : BAND
# 'Close'
# Working on : BANF
# 'Close'
# Working on : BANR
# 'Close'
# Working on : BATRA
# 'Close'
# Working on : BATRK
# 'Close'
# Working on : BAX
# 'Close'
# Working on : BBBY
# 'Close'
# Working on : BBCP
# 'Close'
# Working on : BBGI
# 'Close'
# Working on : BBSI
# 'Close'
# Working on : BBW
# 'Close'
# Working on : BBY
# 'Close'
# Working on : BC
# 'Close'
# Working on : BCBP
# 'Close'
# Working on : BCC
# 'Close'
# Working on : BCEI
# 'Close'
# Working on : BCLI
# 'Close'
# Working on : BCO
# 'Close'
# Working on : BCOR
# 'Close'
# Working on : BCOV
# 'Close'
# Working on : BCPC
# 'Close'
# Working on : BCRX
# 'Close'
# Working on : BDC
# 'Close'
# Working on : BDL
# 'Close'
# Working on : BDN
# 'Close'
# Working on : BDSI
# 'Close'
# Working on : BDX
# 'Close'
# Working on : BECN
# 'Close'
# Working on : BELFA
# 'Close'
# Working on : BELFB
# 'Close'
# Working on : BEN
# 'Close'
# Working on : BERY
# 'Close'
# Working on : BFAM
# 'Close'
# Working on : BFIN
# 'Close'
# Working on : BFS
# 'Close'
# Working on : BG
# 'Close'
# Working on : BGCP
# 'Close'
# Working on : BGFV
# 'Close'
# Working on : BGS
# 'Close'
# Working on : BGSF
# 'Close'
# Working on : BH
# 'Close'
# Working on : BHB
# 'Close'
# Working on : BHE
# 'Close'
# Working on : BHF
# 'Close'
# Working on : BHLB
# 'Close'
# Working on : BHR
# 'Close'
# Working on : BHVN
# 'Close'
# Working on : BIG
# 'Close'
# Working on : BIIB
# 'Close'
# Working on : BIO
# 'Close'
# Working on : BIOC
# 'Close'
# Working on : BIOL
# 'Close'
# Working on : BJRI
# 'Close'
# Working on : BK
# 'Close'
# Working on : BKD
# 'Close'
# Working on : BKE
# 'Close'
# Working on : BKH
# 'Close'
# Working on : BKI
# 'Close'
# Working on : BKNG
# 'Close'
# Working on : BKSC
# 'Close'
# Working on : BKTI
# 'Close'
# Working on : BKU
# 'Close'
# Working on : BL
# 'Close'
# Working on : BLBD
# 'Close'
# Working on : BLCM
# 'Close'
# Working on : BLD
# 'Close'
# Working on : BLDR
# 'Close'
# Working on : BLFS
# 'Close'
# Working on : BLK
# 'Close'
# Working on : BLKB
# 'Close'
# Working on : BLL
# 'Close'
# Working on : BLMN
# 'Close'
# Working on : BLUE
# 'Close'
# Working on : BMI
# 'Close'
# Working on : BMRC
# 'Close'
# Working on : BMRN
# 'Close'
# Working on : BMTC
# 'Close'
# Working on : BMY
# 'Close'
# Working on : BNED
# 'Close'
# Working on : BNFT
# 'Close'
# Working on : BOCH
# 'Close'
# Working on : BOH
# 'Close'
# Working on : BOKF
# 'Close'
# Working on : BOMN
# 'Close'
# Working on : BOOM
# 'Close'
# Working on : BOOT
# 'Close'
# Working on : BOTJ
# 'Close'
# Working on : BOX
# 'Close'
# Working on : BPFH
# 'Close'
# Working on : BPMC
# 'Close'
# Working on : BPOP
# 'Close'
# Working on : BPRN
# 'Close'
# Working on : BPTH
# 'Close'
# Working on : BR
# 'Close'
# Working on : BRC
# 'Close'
# Working on : BRG
# 'Close'
# Working on : BRID
# 'Close'
# Working on : BRKL
# 'Close'
# Working on : BRKR
# 'Close'
# Working on : BRKS
# 'Close'
# Working on : BRN
# 'Close'
# Working on : BRO
# 'Close'
# Working on : BRT
# 'Close'
# Working on : BRX
# 'Close'
# Working on : BSET
# 'Close'
# Working on : BSGM
# 'Close'
# Working on : BSQR
# 'Close'
# Working on : BSRR
# 'Close'
# Working on : BSX
# 'Close'
# Working on : BTN
# 'Close'
# Working on : BTU
# 'Close'
# Working on : BURL
# 'Close'
# Working on : BUSE
# 'Close'
# Working on : BW
# 'Close'
# Working on : BWA
# 'Close'
# Working on : BWEN
# 'Close'
# Working on : BWFG
# 'Close'
# Working on : BWXT
# 'Close'
# Working on : BXC
# 'Close'
# Working on : BXMT
# 'Close'
# Working on : BXP
# 'Close'
# Working on : BXS
# 'Close'
# Working on : BY
# 'Close'
# Working on : BYD
# 'Close'
# Working on : BYFC
# 'Close'
# Working on : BZH
# 'Close'
# Working on : C
# 'Close'
# Working on : CABO
# 'Close'
# Working on : CAC
# 'Close'
# Working on : CACC
# 'Close'
# Working on : CACI
# 'Close'
# Working on : CADE
# 'Close'
# Working on : CAG
# 'Close'
# Working on : CAH
# 'Close'
# Working on : CAI
# 'Close'
# Working on : CAKE
# 'Close'
# Working on : CAL
# 'Close'
# Working on : CALA
# 'Close'
# Working on : CALM
# 'Close'
# Working on : CALX
# 'Close'
# Working on : CAMP
# 'Close'
# Working on : CAPR
# 'Close'
# Working on : CAR
# 'Close'
# Working on : CARA
# 'Close'
# Working on : CARG
# 'Close'
# Working on : CARS
# 'Close'
# Working on : CASA
# 'Close'
# Working on : CASH
# 'Close'
# Working on : CASI
# 'Close'
# Working on : CASS
# 'Close'
# Working on : CASY
# 'Close'
# Working on : CAT
# 'Close'
# Working on : CATB
# 'Close'
# Working on : CATC
# 'Close'
# Working on : CATO
# 'Close'
# Working on : CATY
# 'Close'
# Working on : CB
# 'Close'
# Working on : CBAN
# 'Close'
# Working on : CBAY
# 'Close'
# Working on : CBB
# 'Close'
# Working on : CBFV
# 'Close'
# Working on : CBIO
# 'Close'
# Working on : CBLI
# 'Close'
# Working on : CBOE
# 'Close'
# Working on : CBRE
# 'Close'
# Working on : CBRL
# 'Close'
# Working on : CBSH
# 'Close'
# Working on : CBT
# 'Close'
# Working on : CBTX
# 'Close'
# Working on : CBU
# 'Close'
# Working on : CBZ
# 'Close'
# Working on : CC
# 'Close'
# Working on : CCBG
# 'Close'
# Working on : CCF
# 'Close'
# Working on : CCI
# 'Close'
# Working on : CCK
# 'Close'
# Working on : CCL
# 'Close'
# Working on : CCMP
# 'Close'
# Working on : CCNE
# 'Close'
# Working on : CCO
# 'Close'
# Working on : CCOI
# 'Close'
# Working on : CCRN
# 'Close'
# Working on : CCS
# 'Close'
# Working on : CCXI
# 'Close'
# Working on : CDE
# 'Close'
# Working on : CDEV
# 'Close'
# Working on : CDK
# 'Close'
# Working on : CDMO
# 'Close'
# Working on : CDNA
# 'Close'
# Working on : CDNS
# 'Close'
# Working on : CDR
# 'Close'
# Working on : CDTX
# 'Close'
# Working on : CDW
# 'Close'
# Working on : CDXC
# 'Close'
# Working on : CDXS
# 'Close'
# Working on : CDZI
# 'Close'
# Working on : CE
# 'Close'
# Working on : CECE
# 'Close'
# Working on : CEI
# 'Close'
# Working on : CEIX
# 'Close'
# Working on : CELC
# 'Close'
# Working on : CELH
# 'Close'
# Working on : CEMI
# 'Close'
# Working on : CENT
# 'Close'
# Working on : CENTA
# 'Close'
# Working on : CENX
# 'Close'
# Working on : CERC
# 'Close'
# Working on : CERN
# 'Close'
# Working on : CERS
# 'Close'
# Working on : CETX
# 'Close'
# Working on : CEVA
# 'Close'
# Working on : CF
# 'Close'
# Working on : CFBK
# 'Close'
# Working on : CFFI
# 'Close'
# Working on : CFFN
# 'Close'
# Working on : CFG
# 'Close'
# Working on : CFMS
# 'Close'
# Working on : CFR
# 'Close'
# Working on : CFX
# 'Close'
# Working on : CGNX
# 'Close'
# Working on : CHCI
# 'Close'
# Working on : CHCO
# 'Close'
# Working on : CHCT
# 'Close'
# Working on : CHD
# 'Close'
# Working on : CHDN
# 'Close'
# Working on : CHE
# 'Close'
# Working on : CHEF
# 'Close'
# Working on : CHGG
# 'Close'
# Working on : CHH
# 'Close'
# Working on : CHMA
# 'Close'
# Working on : CHMG
# 'Close'
# Working on : CHMI
# 'Close'
# Working on : CHRS
# 'Close'
# Working on : CHRW
# 'Close'
# Working on : CHS
# 'Close'
# Working on : CHTR
# 'Close'
# Working on : CHUY
# 'Close'
# Working on : CI
# 'Close'
# Working on : CIA
# 'Close'
# Working on : CIDM
# 'Close'
# Working on : CIEN
# 'Close'
# Working on : CIM
# 'Close'
# Working on : CINF
# 'Close'
# Working on : CIO
# 'Close'
# Working on : CIR
# 'Close'
# Working on : CIT
# 'Close'
# Working on : CIVB
# 'Close'
# Working on : CIX
# 'Close'
# Working on : CIZN
# 'Close'
# Working on : CKX
# 'Close'
# Working on : CL
# 'Close'
# Working on : CLAR
# 'Close'
# Working on : CLB
# 'Close'
# Working on : CLBS
# 'Close'
# Working on : CLDR
# 'Close'
# Working on : CLDT
# 'Close'
# Working on : CLDX
# 'Close'
# Working on : CLF
# 'Close'
# Working on : CLFD
# 'Close'
# Working on : CLH
# 'Close'
# Working on : CLI
# 'Close'
# Working on : CLIR
# 'Close'
# Working on : CLNE
# 'Close'
# Working on : CLPR
# 'Close'
# Working on : CLR
# 'Close'
# Working on : CLRB
# 'Close'
# Working on : CLRO
# 'Close'
# Working on : CLSN
# 'Close'
# Working on : CLVS
# 'Close'
# Working on : CLW
# 'Close'
# Working on : CLX
# 'Close'
# Working on : CLXT
# 'Close'
# Working on : CMA
# 'Close'
# Working on : CMC
# 'Close'
# Working on : CMCO
# 'Close'
# Working on : CMCSA
# 'Close'
# Working on : CMCT
# 'Close'
# Working on : CME
# 'Close'
# Working on : CMG
# 'Close'
# Working on : CMI
# 'Close'
# Working on : CMO
# 'Close'
# Working on : CMP
# 'Close'
# Working on : CMRX
# 'Close'
# Working on : CMS
# 'Close'
# Working on : CMT
# 'Close'
# Working on : CMTL
# 'Close'
# Working on : CNA
# 'Close'
# Working on : CNBKA
# 'Close'
# Working on : CNC
# 'Close'
# Working on : CNCE
# 'Close'
# Working on : CNDT
# 'Close'
# Working on : CNFR
# 'Close'
# Working on : CNK
# 'Close'
# Working on : CNMD
# 'Close'
# Working on : CNNE
# 'Close'
# Working on : CNO
# 'Close'
# Working on : CNOB
# 'Close'
# Working on : CNP
# 'Close'
# Working on : CNS
# 'Close'
# Working on : CNSL
# 'Close'
# Working on : CNTY
# 'Close'
# Working on : CNX
# 'Close'
# Working on : CNXN
# 'Close'
# Working on : CODA
# 'Close'
# Working on : COF
# 'Close'
# Working on : COG
# 'Close'
# Working on : COHN
# 'Close'
# Working on : COHR
# 'Close'
# Working on : COHU
# 'Close'
# Working on : COKE
# 'Close'
# Working on : COLB
# 'Close'
# Working on : COLL
# 'Close'
# Working on : COLM
# 'Close'
# Working on : COMM
# 'Close'
# Working on : CONE
# 'Close'
# Working on : CONN
# 'Close'
# Working on : COO
# 'Close'
# Working on : COOP
# 'Close'
# Working on : COP
# 'Close'
# Working on : COR
# 'Close'
# Working on : CORE
# 'Close'
# Working on : CORR
# 'Close'
# Working on : CORT
# 'Close'
# Working on : COST
# 'Close'
# Working on : COTY
# 'Close'
# Working on : COUP
# 'Close'
# Working on : COWN
# 'Close'
# Working on : CPB
# 'Close'
# Working on : CPE
# 'Close'
# Working on : CPF
# 'Close'
# Working on : CPHC
# 'Close'
# Working on : CPIX
# 'Close'
# Working on : CPK
# 'Close'
# Working on : CPRI
# 'Close'
# Working on : CPRT
# 'Close'
# Working on : CPRX
# 'Close'
# Working on : CPS
# 'Close'
# Working on : CPSH
# 'Close'
# Working on : CPSI
# 'Close'
# Working on : CPSS
# 'Close'
# Working on : CPT
# 'Close'
# Working on : CR
# 'Close'
# Working on : CRAI
# 'Close'
# Working on : CRBP
# 'Close'
# Working on : CREE
# 'Close'
# Working on : CRI
# 'Close'
# Working on : CRIS
# 'Close'
# Working on : CRK
# 'Close'
# Working on : CRL
# 'Close'
# Working on : CRM
# 'Close'
# Working on : CRMD
# 'Close'
# Working on : CRMT
# 'Close'
# Working on : CROX
# 'Close'
# Working on : CRS
# 'Close'
# Working on : CRUS
# 'Close'
# Working on : CRVL
# 'Close'
# Working on : CRVS
# 'Close'
# Working on : CRWS
# 'Close'
# Working on : CRY
# 'Close'
# Working on : CSCO
# 'Close'
# Working on : CSGP
# 'Close'
# Working on : CSGS
# 'Close'
# Working on : CSII
# 'Close'
# Working on : CSL
# 'Close'
# Working on : CSLT
# 'Close'
# Working on : CSOD
# 'Close'
# Working on : CSPI
# 'Close'
# Working on : CSTR
# 'Close'
# Working on : CSU
# 'Close'
# Working on : CSV
# 'Close'
# Working on : CSWI
# 'Close'
# Working on : CSX
# 'Close'
# Working on : CTAS
# 'Close'
# Working on : CTBI
# 'Close'
# Working on : CTG
# 'Close'
# Working on : CTHR
# 'Close'
# Working on : CTIB
# 'Close'
# Working on : CTIC
# 'Close'
# Working on : CTLT
# 'Close'
# Working on : CTMX
# 'Close'
# Working on : CTO
# 'Close'
# Working on : CTRE
# 'Close'
# Working on : CTRN
# 'Close'
# Working on : CTS
# 'Close'
# Working on : CTSH
# 'Close'
# Working on : CTSO
# 'Close'
# Working on : CTT
# 'Close'
# Working on : CTXS
# 'Close'
# Working on : CUBE
# 'Close'
# Working on : CUBI
# 'Close'
# Working on : CULP
# 'Close'
# Working on : CURO
# 'Close'
# Working on : CUTR
# 'Close'
# Working on : CUZ
# 'Close'
# Working on : CVA
# 'Close'
# Working on : CVBF
# 'Close'
# Working on : CVCO
# 'Close'
# Working on : CVCY
# 'Close'
# Working on : CVGI
# 'Close'
# Working on : CVGW
# 'Close'
# Working on : CVI
# 'Close'
# Working on : CVLT
# 'Close'
# Working on : CVLY
# 'Close'
# Working on : CVM
# 'Close'
# Working on : CVNA
# 'Close'
# Working on : CVR
# 'Close'
# Working on : CVS
# 'Close'
# Working on : CVU
# 'Close'
# Working on : CVV
# 'Close'
# Working on : CVX
# 'Close'
# Working on : CW
# 'Close'
# Working on : CWBC
# 'Close'
# Working on : CWBR
# 'Close'
# Working on : CWEN
# 'Close'
# Working on : CWH
# 'Close'
# Working on : CWST
# 'Close'
# Working on : CWT
# 'Close'
# Working on : CXP
# 'Close'
# Working on : CXW
# 'Close'
# Working on : CYAN
# 'Close'
# Working on : CYBE
# 'Close'
# Working on : CYCC
# 'Close'
# Working on : CYH
# 'Close'
# Working on : CYRX
# 'Close'
# Working on : CYTK
# 'Close'
# Working on : CYTR
# 'Close'
# Working on : CZNC
# 'Close'
# Working on : CZR
# 'Close'
# Working on : CZWI
# 'Close'
# Working on : D
# 'Close'
# Working on : DAIO
# 'Close'
# Working on : DAKT
# 'Close'
# Working on : DAL
# 'Close'
# Working on : DAN
# 'Close'
# Working on : DAR
# 'Close'
# Working on : DARE
# 'Close'
# Working on : DBD
# 'Close'
# Working on : DBI
# 'Close'
# Working on : DCI
# 'Close'
# Working on : DCO
# 'Close'
# Working on : DCOM
# 'Close'
# Working on : DCPH
# 'Close'
# Working on : DD
# 'Close'
# Working on : DDD
# 'Close'
# Working on : DDS
# 'Close'
# Working on : DE
# 'Close'
# Working on : DEA
# 'Close'
# Working on : DECK
# 'Close'
# Working on : DEI
# 'Close'
# Working on : DELL
# 'Close'
# Working on : DENN
# 'Close'
# Working on : DFIN
# 'Close'
# Working on : DFS
# 'Close'
# Working on : DG
# 'Close'
# Working on : DGICA
# 'Close'
# Working on : DGII
# 'Close'
# Working on : DGLY
# 'Close'
# Working on : DGX
# 'Close'
# Working on : DHI
# 'Close'
# Working on : DHIL
# 'Close'
# Working on : DHR
# 'Close'
# Working on : DHX
# 'Close'
# Working on : DIN
# 'Close'
# Working on : DIOD
# 'Close'
# Working on : DIS
# 'Close'
# Working on : DISCA
# 'Close'
# Working on : DISCK
# 'Close'
# Working on : DISH
# 'Close'
# Working on : DIT
# 'Close'
# Working on : DJCO
# 'Close'
# Working on : DK
# 'Close'
# Working on : DKS
# 'Close'
# Working on : DLA
# 'Close'
# Working on : DLB
# 'Close'
# Working on : DLHC
# 'Close'
# Working on : DLR
# 'Close'
# Working on : DLTH
# 'Close'
# Working on : DLTR
# 'Close'
# Working on : DLX
# 'Close'
# Working on : DMRC
# 'Close'
# Working on : DNLI
# 'Close'
# Working on : DNOW
# 'Close'
# Working on : DOC
# 'Close'
# Working on : DOOR
# 'Close'
# Working on : DORM
# 'Close'
# Working on : DOV
# 'Close'
# Working on : DPZ
# 'Close'
# Working on : DRE
# 'Close'
# Working on : DRH
# 'Close'
# Working on : DRI
# 'Close'
# Working on : DRNA
# 'Close'
# Working on : DRQ
# 'Close'
# Working on : DRRX
# 'Close'
# Working on : DS
# 'Close'
# Working on : DSKE
# 'Close'
# Working on : DSPG
# 'Close'
# Working on : DSS
# 'Close'
# Working on : DTE
# 'Close'
# Working on : DUK
# 'Close'
# Working on : DVA
# 'Close'
# Working on : DVAX
# 'Close'
# Working on : DVD
# 'Close'
# Working on : DVN
# 'Close'
# Working on : DWSN
# 'Close'
# Working on : DX
# 'Close'
# Working on : DXC
# 'Close'
# Working on : DXCM
# 'Close'
# Working on : DXLG
# 'Close'
# Working on : DXPE
# 'Close'
# Working on : DXYN
# 'Close'
# Working on : DY
# 'Close'
# Working on : DZSI
# 'Close'
# Working on : EA
# 'Close'
# Working on : EARN
# 'Close'
# Working on : EAT
# 'Close'
# Working on : EBAY
# 'Close'
# Working on : EBF
# 'Close'
# Working on : EBIX
# 'Close'
# Working on : EBMT
# 'Close'
# Working on : EBS
# 'Close'
# Working on : EBSB
# 'Close'
# Working on : EBTC
# 'Close'
# Working on : ECHO
# 'Close'
# Working on : ECL
# 'Close'
# Working on : ECOL
# 'Close'
# Working on : ECOM
# 'Close'
# Working on : ECPG
# 'Close'
# Working on : ED
# 'Close'
# Working on : EDIT
# 'Close'
# Working on : EDUC
# 'Close'
# Working on : EEFT
# 'Close'
# Working on : EEX
# 'Close'
# Working on : EFC
# 'Close'
# Working on : EFOI
# 'Close'
# Working on : EFSC
# 'Close'
# Working on : EFX
# 'Close'
# Working on : EGAN
# 'Close'
# Working on : EGBN
# 'Close'
# Working on : EGHT
# 'Close'
# Working on : EGLE
# 'Close'
# Working on : EGP
# 'Close'
# Working on : EGRX
# 'Close'
# Working on : EGY
# 'Close'
# Working on : EHC
# 'Close'
# Working on : EHTH
# 'Close'
# Working on : EIG
# 'Close'
# Working on : EIGR
# 'Close'
# Working on : EIX
# 'Close'
# Working on : EKSO
# 'Close'
# Working on : EL
# 'Close'
# Working on : ELF
# 'Close'
# Working on : ELMD
# 'Close'
# Working on : ELOX
# 'Close'
# Working on : ELS
# 'Close'
# Working on : ELSE
# 'Close'
# Working on : ELVT
# 'Close'
# Working on : ELY
# 'Close'
# Working on : EMAN
# 'Close'
# Working on : EMCF
# 'Close'
# Working on : EME
# 'Close'
# Working on : EMKR
# 'Close'
# Working on : EML
# 'Close'
# Working on : EMMS
# 'Close'
# Working on : EMN
# 'Close'
# Working on : EMR
# 'Close'
# Working on : ENDP
# 'Close'
# Working on : ENG
# 'Close'
# Working on : ENPH
# 'Close'
# Working on : ENR
# 'Close'
# Working on : ENS
# 'Close'
# Working on : ENSG
# 'Close'
# Working on : ENSV
# 'Close'
# Working on : ENTA
# 'Close'
# Working on : ENTG
# 'Close'
# Working on : ENV
# 'Close'
# Working on : ENVA
# 'Close'
# Working on : ENZ
# 'Close'
# Working on : EOG
# 'Close'
# Working on : EPAM
# 'Close'
# Working on : EPAY
# 'Close'
# Working on : EPC
# 'Close'
# Working on : EPM
# 'Close'
# Working on : EPR
# 'Close'
# Working on : EPZM
# 'Close'
# Working on : EQBK
# 'Close'
# Working on : EQC
# 'Close'
# Working on : EQIX
# 'Close'
# Working on : EQR
# 'Close'
# Working on : EQT
# 'Close'
# Working on : ERIE
# 'Close'
# Working on : ERII
# 'Close'
# Working on : ES
# 'Close'
# Working on : ESBK
# 'Close'
# Working on : ESCA
# 'Close'
# Working on : ESE
# 'Close'
# Working on : ESGR
# 'Close'
# Working on : ESNT
# 'Close'
# Working on : ESP
# 'Close'
# Working on : ESPR
# 'Close'
# Working on : ESRT
# 'Close'
# Working on : ESS
# 'Close'
# Working on : ESSA
# 'Close'
# Working on : ESTE
# 'Close'
# Working on : ESXB
# 'Close'
# Working on : ETH
# 'Close'
# Working on : ETN
# 'Close'
# Working on : ETR
# 'Close'
# Working on : ETSY
# 'Close'
# Working on : EVBG
# 'Close'
# Working on : EVBN
# 'Close'
# Working on : EVC
# 'Close'
# Working on : EVFM
# 'Close'
# Working on : EVH
# 'Close'
# Working on : EVI
# 'Close'
# Working on : EVOK
# 'Close'
# Working on : EVOL
# 'Close'
# Working on : EVR
# 'Close'
# Working on : EVRG
# 'Close'
# Working on : EVRI
# 'Close'
# Working on : EVTC
# 'Close'
# Working on : EW
# 'Close'
# Working on : EWBC
# 'Close'
# Working on : EXAS
# 'Close'
# Working on : EXC
# 'Close'
# Working on : EXEL
# 'Close'
# Working on : EXLS
# 'Close'
# Working on : EXP
# 'Close'
# Working on : EXPD
# 'Close'
# Working on : EXPE
# 'Close'
# Working on : EXPO
# 'Close'
# Working on : EXPR
# 'Close'
# Working on : EXR
# 'Close'
# Working on : EXTN
# 'Close'
# Working on : EXTR
# 'Close'
# Working on : EYE
# 'Close'
# Working on : EYEG
# 'Close'
# Working on : EYES
# 'Close'
# Working on : EYPT
# 'Close'
# Working on : EZPW
# 'Close'
# Working on : F
# 'Close'
# Working on : FAF
# 'Close'
# Working on : FANG
# 'Close'
# Working on : FARM
# 'Close'
# Working on : FARO
# 'Close'
# Working on : FAST
# 'Close'
# Working on : FATE
# 'Close'
# Working on : FB
# Working on : FBC
# 'Close'
# Working on : FBHS
# 'Close'
# Working on : FBIO
# 'Close'
# Working on : FBIZ
# 'Close'
# Working on : FBK
# 'Close'
# Working on : FBMS
# 'Close'
# Working on : FBNC
# 'Close'
# Working on : FBP
# 'Close'
# Working on : FC
# 'Close'
# Working on : FCAP
# 'Close'
# Working on : FCBC
# 'Close'
# Working on : FCBP
# 'Close'
# Working on : FCCO
# 'Close'
# Working on : FCCY
# 'Close'
# Working on : FCEL
# 'Close'
# Working on : FCF
# 'Close'
# Working on : FCFS
# 'Close'
# Working on : FCN
# 'Close'
# Working on : FCNCA
# 'Close'
# Working on : FCPT
# 'Close'
# Working on : FCX
# 'Close'
# Working on : FDBC
# 'Close'
# Working on : FDP
# 'Close'
# Working on : FDS
# 'Close'
# Working on : FDX
# 'Close'
# Working on : FE
# 'Close'
# Working on : FEIM
# 'Close'
# Working on : FELE
# 'Close'
# Working on : FET
# 'Close'
# Working on : FEYE
# 'Close'
# Working on : FF
# 'Close'
# Working on : FFBC
# 'Close'
# Working on : FFIC
# 'Close'
# Working on : FFIN
# 'Close'
# Working on : FFIV
# 'Close'
# Working on : FFNW
# 'Close'
# Working on : FFWM
# 'Close'
# Working on : FGBI
# 'Close'
# Working on : FGEN
# 'Close'
# Working on : FHB
# 'Close'
# Working on : FHN
# 'Close'
# Working on : FI
# 'Close'
# Working on : FIBK
# 'Close'
# Working on : FICO
# 'Close'
# Working on : FIS
# 'Close'
# Working on : FISI
# 'Close'
# Working on : FISV
# 'Close'
# Working on : FITB
# 'Close'
# Working on : FIVE
# 'Close'
# Working on : FIVN
# 'Close'
# Working on : FIX
# 'Close'
# Working on : FIZZ
# 'Close'
# Working on : FL
# 'Close'
# Working on : FLDM
# 'Close'
# Working on : FLIC
# 'Close'
# Working on : FLL
# 'Close'
# Working on : FLMN
# 'Close'
# Working on : FLNT
# 'Close'
# Working on : FLO
# 'Close'
# Working on : FLOW
# 'Close'
# Working on : FLR
# 'Close'
# Working on : FLS
# 'Close'
# Working on : FLT
# 'Close'
# Working on : FLWS
# 'Close'
# Working on : FLXN
# 'Close'
# Working on : FLXS
# 'Close'
# Working on : FMAO
# 'Close'
# Working on : FMBH
# 'Close'
# Working on : FMBI
# 'Close'
# Working on : FMC
# 'Close'
# Working on : FMNB
# 'Close'
# Working on : FN
# 'Close'
# Working on : FNB
# 'Close'
# Working on : FNCB
# 'Close'
# Working on : FND
# 'Close'
# Working on : FNF
# 'Close'
# Working on : FNHC
# 'Close'
# Working on : FNKO
# 'Close'
# Working on : FNLC
# 'Close'
# Working on : FNWB
# 'Close'
# Working on : FOE
# 'Close'
# Working on : FOLD
# 'Close'
# Working on : FONR
# 'Close'
# Working on : FOR
# 'Close'
# Working on : FORD
# 'Close'
# Working on : FORM
# 'Close'
# Working on : FORR
# 'Close'
# Working on : FOSL
# 'Close'
# Working on : FOXF
# 'Close'
# Working on : FPI
# 'Close'
# Working on : FR
# 'Close'
# Working on : FRBA
# 'Close'
# Working on : FRBK
# 'Close'
# Working on : FRC
# 'Close'
# Working on : FRD
# 'Close'
# Working on : FRGI
# 'Close'
# Working on : FRME
# 'Close'
# Working on : FRPH
# 'Close'
# Working on : FRPT
# 'Close'
# Working on : FRT
# 'Close'
# Working on : FRTA
# 'Close'
# Working on : FSBW
# 'Close'
# Working on : FSFG
# 'Close'
# Working on : FSLR
# 'Close'
# Working on : FSP
# 'Close'
# Working on : FSS
# 'Close'
# Working on : FSTR
# 'Close'
# Working on : FTEK
# 'Close'
# Working on : FTI
# 'Close'
# Working on : FTK
# 'Close'
# Working on : FTNT
# 'Close'
# Working on : FTV
# 'Close'
# Working on : FUL
# 'Close'
# Working on : FULT
# 'Close'
# Working on : FUNC
# 'Close'
# Working on : FUSB
# 'Close'
# Working on : FVE
# 'Close'
# Working on : FWONA
# 'Close'
# Working on : FWONK
# 'Close'
# Working on : FWRD
# 'Close'
# Working on : G
# 'Close'
# Working on : GABC
# 'Close'
# Working on : GAIA
# 'Close'
# Working on : GALT
# 'Close'
# Working on : GATX
# 'Close'
# Working on : GBCI
# 'Close'
# Working on : GBL
# 'Close'
# Working on : GBLI
# 'Close'
# Working on : GBT
# 'Close'
# Working on : GBX
# 'Close'
# Working on : GCBC
# 'Close'
# Working on : GCI
# 'Close'
# Working on : GCO
# 'Close'
# Working on : GCP
# 'Close'
# Working on : GD
# 'Close'
# Working on : GDDY
# 'Close'
# Working on : GDEN
# 'Close'
# Working on : GDOT
# 'Close'
# Working on : GDP
# 'Close'
# Working on : GE
# 'Close'
# Working on : GEF
# 'Close'
# Working on : GENC
# 'Close'
# Working on : GEO
# 'Close'
# Working on : GEOS
# 'Close'
# Working on : GERN
# 'Close'
# Working on : GES
# 'Close'
# Working on : GEVO
# 'Close'
# Working on : GFED
# 'Close'
# Working on : GFF
# 'Close'
# Working on : GGG
# 'Close'
# Working on : GHC
# 'Close'
# Working on : GHL
# 'Close'
# Working on : GHM
# 'Close'
# Working on : GIFI
# 'Close'
# Working on : GIII
# 'Close'
# Working on : GILD
# 'Close'
# Working on : GIS
# 'Close'
# Working on : GKOS
# 'Close'
# Working on : GLBZ
# 'Close'
# Working on : GLDD
# 'Close'
# Working on : GLPI
# 'Close'
# Working on : GLRE
# 'Close'
# Working on : GLT
# 'Close'
# Working on : GLW
# 'Close'
# Working on : GLYC
# 'Close'
# Working on : GM
# 'Close'
# Working on : GME
# 'Close'
# Working on : GMED
# 'Close'
# Working on : GMRE
# 'Close'
# Working on : GMS
# 'Close'
# Working on : GNCA
# 'Close'
# Working on : GNE
# 'Close'
# Working on : GNK
# 'Close'
# Working on : GNL
# 'Close'
# Working on : GNRC
# 'Close'
# Working on : GNTX
# 'Close'
# Working on : GNTY
# 'Close'
# Working on : GNW
# 'Close'
# Working on : GOGO
# 'Close'
# Working on : GOLF
# 'Close'
# Working on : GOOD
# 'Close'
# Working on : GOOG
# Working on : GOOGL
# 'Close'
# Working on : GORO
# 'Close'
# Working on : GPC
# 'Close'
# Working on : GPI
# 'Close'
# Working on : GPK
# 'Close'
# Working on : GPMT
# 'Close'
# Working on : GPN
# 'Close'
# Working on : GPRE
# 'Close'
# Working on : GPRO
# 'Close'
# Working on : GPS
# 'Close'
# Working on : GPX
# 'Close'
# Working on : GRA
# 'Close'
# Working on : GRBK
# 'Close'
# Working on : GRC
# 'Close'
# Working on : GRMN
# 'Close'
# Working on : GROW
# 'Close'
# Working on : GRPN
# 'Close'
# Working on : GS
# 'Close'
# Working on : GSAT
# 'Close'
# Working on : GSBC
# 'Close'
# Working on : GSIT
# 'Close'
# Working on : GT
# 'Close'
# Working on : GTHX
# 'Close'
# Working on : GTIM
# 'Close'
# Working on : GTLS
# 'Close'
# Working on : GTN
# 'Close'
# Working on : GTS
# 'Close'
# Working on : GTT
# 'Close'
# Working on : GTY
# 'Close'
# Working on : GTYH
# 'Close'
# Working on : GVA
# 'Close'
# Working on : GVP
# 'Close'
# Working on : GWB
# 'Close'
# Working on : GWGH
# 'Close'
# Working on : GWRE
# 'Close'
# Working on : GWRS
# 'Close'
# Working on : GWW
# 'Close'
# Working on : H
# 'Close'
# Working on : HA
# 'Close'
# Working on : HAE
# 'Close'
# Working on : HAFC
# 'Close'
# Working on : HAIN
# 'Close'
# Working on : HAL
# 'Close'
# Working on : HALL
# 'Close'
# Working on : HALO
# 'Close'
# Working on : HAS
# 'Close'
# Working on : HASI
# 'Close'
# Working on : HAYN
# 'Close'
# Working on : HBAN
# 'Close'
# Working on : HBB
# 'Close'
# Working on : HBCP
# 'Close'
# Working on : HBI
# 'Close'
# Working on : HBIO
# 'Close'
# Working on : HBMD
# 'Close'
# Working on : HBNC
# 'Close'
# Working on : HBP
# 'Close'
# Working on : HCA
# 'Close'
# Working on : HCC
# 'Close'
# Working on : HCCI
# 'Close'
# Working on : HCHC
# 'Close'
# Working on : HCI
# 'Close'
# Working on : HCKT
# 'Close'
# Working on : HCSG
# 'Close'
# Working on : HD
# 'Close'
# Working on : HDSN
# 'Close'
# Working on : HE
# 'Close'
# Working on : HEAR
# 'Close'
# Working on : HEES
# 'Close'
# Working on : HEI
# 'Close'
# Working on : HELE
# 'Close'
# Working on : HES
# 'Close'
# Working on : HFBL
# 'Close'
# Working on : HFC
# 'Close'
# Working on : HFWA
# 'Close'
# Working on : HGV
# 'Close'
# Working on : HHC
# 'Close'
# Working on : HI
# 'Close'
# Working on : HIBB
# 'Close'
# Working on : HIFS
# 'Close'
# Working on : HIG
# 'Close'
# Working on : HII
# 'Close'
# Working on : HIL
# 'Close'
# Working on : HIW
# 'Close'
# Working on : HL
# 'Close'
# Working on : HLF
# 'Close'
# Working on : HLI
# 'Close'
# Working on : HLIT
# 'Close'
# Working on : HLNE
# 'Close'
# Working on : HLT
# 'Close'
# Working on : HLX
# 'Close'
# Working on : HMHC
# 'Close'
# Working on : HMN
# 'Close'
# Working on : HMNF
# 'Close'
# Working on : HMST
# 'Close'
# Working on : HMTV
# 'Close'
# Working on : HNI
# 'Close'
# Working on : HNRG
# 'Close'
# Working on : HOFT
# 'Close'
# Working on : HOG
# 'Close'
# Working on : HOLX
# 'Close'
# Working on : HOMB
# 'Close'
# Working on : HOME
# 'Close'
# Working on : HON
# 'Close'
# Working on : HONE
# 'Close'
# Working on : HOPE
# 'Close'
# Working on : HOV
# 'Close'
# Working on : HP
# 'Close'
# Working on : HPE
# 'Close'
# Working on : HPP
# 'Close'
# Working on : HPQ
# 'Close'
# Working on : HQY
# 'Close'
# Working on : HR
# 'Close'
# Working on : HRB
# 'Close'
# Working on : HRC
# 'Close'
# Working on : HRI
# 'Close'
# Working on : HRL
# 'Close'
# Working on : HROW
# 'Close'
# Working on : HRTG
# 'Close'
# Working on : HRTX
# 'Close'
# Working on : HSC
# 'Close'
# Working on : HSIC
# 'Close'
# Working on : HSII
# 'Close'
# Working on : HSKA
# 'Close'
# Working on : HSON
# 'Close'
# Working on : HST
# 'Close'
# Working on : HSTM
# 'Close'
# Working on : HSY
# 'Close'
# Working on : HT
# 'Close'
# Working on : HTA
# 'Close'
# Working on : HTBI
# 'Close'
# Working on : HTBK
# 'Close'
# Working on : HTBX
# 'Close'
# Working on : HTGM
# 'Close'
# Working on : HTH
# 'Close'
# Working on : HTLD
# 'Close'
# Working on : HTLF
# 'Close'
# Working on : HUBB
# 'Close'
# Working on : HUBG
# 'Close'
# Working on : HUBS
# 'Close'
# Working on : HUM
# 'Close'
# Working on : HUN
# 'Close'
# Working on : HURC
# 'Close'
# Working on : HURN
# 'Close'
# Working on : HUSA
# 'Close'
# Working on : HVT
# 'Close'
# Working on : HWBK
# 'Close'
# Working on : HWC
# 'Close'
# Working on : HWKN
# 'Close'
# Working on : HXL
# 'Close'
# Working on : HY
# 'Close'
# Working on : HZN
# 'Close'
# Working on : HZNP
# 'Close'
# Working on : HZO
# 'Close'
# Working on : IAC
# 'Close'
# Working on : IART
# 'Close'
# Working on : IBCP
# 'Close'
# Working on : IBIO
# 'Close'
# Working on : IBKR
# 'Close'
# Working on : IBM
# 'Close'
# Working on : IBOC
# 'Close'
# Working on : IBP
# 'Close'
# Working on : IBTX
# 'Close'
# Working on : ICAD
# 'Close'
# Working on : ICBK
# 'Close'
# Working on : ICCC
# 'Close'
# Working on : ICD
# 'Close'
# Working on : ICE
# 'Close'
# Working on : ICFI
# 'Close'
# Working on : ICHR
# 'Close'
# Working on : ICON
# 'Close'
# Working on : ICPT
# 'Close'
# Working on : ICUI
# 'Close'
# Working on : IDA
# 'Close'
# Working on : IDCC
# 'Close'
# Working on : IDN
# 'Close'
# Working on : IDRA
# 'Close'
# Working on : IDT
# 'Close'
# Working on : IDXG
# 'Close'
# Working on : IDXX
# 'Close'
# Working on : IEC
# 'Close'
# Working on : IESC
# 'Close'
# Working on : IEX
# 'Close'
# Working on : IFF
# 'Close'
# Working on : IHC
# 'Close'
# Working on : III
# 'Close'
# Working on : IIIN
# 'Close'
# Working on : IIN
# 'Close'
# Working on : IIPR
# 'Close'
# Working on : IIVI
# 'Close'
# Working on : IKNX
# 'Close'
# Working on : ILMN
# 'Close'
# Working on : IMGN
# 'Close'
# Working on : IMH
# 'Close'
# Working on : IMKTA
# 'Close'
# Working on : IMMR
# 'Close'
# Working on : IMXI
# 'Close'
# Working on : INBK
# 'Close'
# Working on : INCY
# 'Close'
# Working on : INDB
# 'Close'
# Working on : INFI
# 'Close'
# Working on : INFN
# 'Close'
# Working on : INFO
# 'Close'
# Working on : INFU
# 'Close'
# Working on : INGN
# 'Close'
# Working on : INGR
# 'Close'
# Working on : INN
# 'Close'
# Working on : INO
# 'Close'
# Working on : INOD
# 'Close'
# Working on : INOV
# 'Close'
# Working on : INPX
# 'Close'
# Working on : INS
# 'Close'
# Working on : INSE
# 'Close'
# Working on : INSG
# 'Close'
# Working on : INSM
# 'Close'
# Working on : INSW
# 'Close'
# Working on : INT
# 'Close'
# Working on : INTC
# 'Close'
# Working on : INTG
# 'Close'
# Working on : INTT
# 'Close'
# Working on : INTU
# 'Close'
# Working on : INUV
# 'Close'
# Working on : INVA
# 'Close'
# Working on : INVE
# 'Close'
# Working on : INVH
# 'Close'
# Working on : IO
# 'Close'
# Working on : IONS
# 'Close'
# Working on : IOR
# 'Close'
# Working on : IOSP
# 'Close'
# Working on : IOVA
# 'Close'
# Working on : IP
# 'Close'
# Working on : IPAR
# 'Close'
# Working on : IPG
# 'Close'
# Working on : IPGP
# 'Close'
# Working on : IPI
# 'Close'
# Working on : IPWR
# 'Close'
# Working on : IQV
# 'Close'
# Working on : IR
# 'Close'
# Working on : IRBT
# 'Close'
# Working on : IRDM
# 'Close'
# Working on : IRIX
# 'Close'
# Working on : IRM
# 'Close'
# Working on : IRMD
# 'Close'
# Working on : IROQ
# 'Close'
# Working on : IRT
# 'Close'
# Working on : IRTC
# 'Close'
# Working on : IRWD
# 'Close'
# Working on : ISBC
# 'Close'
# Working on : ISDR
# 'Close'
# Working on : ISIG
# 'Close'
# Working on : ISNS
# 'Close'
# Working on : ISR
# 'Close'
# Working on : ISRG
# 'Close'
# Working on : ISSC
# 'Close'
# Working on : ISTR
# 'Close'
# Working on : IT
# 'Close'
# Working on : ITCI
# 'Close'
# Working on : ITGR
# 'Close'
# Working on : ITI
# 'Close'
# Working on : ITIC
# 'Close'
# Working on : ITRI
# 'Close'
# Working on : ITT
# 'Close'
# Working on : ITW
# 'Close'
# Working on : IVAC
# 'Close'
# Working on : IVC
# 'Close'
# Working on : IVR
# 'Close'
# Working on : IVZ
# 'Close'
# Working on : IZEA
# 'Close'
# Working on : JACK
# 'Close'
# Working on : JAGX
# 'Close'
# Working on : JAKK
# 'Close'
# Working on : JAX
# 'Close'
# Working on : JAZZ
# 'Close'
# Working on : JBGS
# 'Close'
# Working on : JBHT
# 'Close'
# Working on : JBL
# 'Close'
# Working on : JBLU
# 'Close'
# Working on : JBSS
# 'Close'
# Working on : JBT
# 'Close'
# Working on : JCI
# 'Close'
# Working on : JCOM
# 'Close'
# Working on : JCS
# 'Close'
# Working on : JCTCF
# 'Close'
# Working on : JEF
# 'Close'
# Working on : JELD
# 'Close'
# Working on : JHG
# 'Close'
# Working on : JILL
# 'Close'
# Working on : JJSF
# 'Close'
# Working on : JKHY
# 'Close'
# Working on : JLL
# 'Close'
# Working on : JNCE
# 'Close'
# Working on : JNJ
# 'Close'
# Working on : JNPR
# 'Close'
# Working on : JOB
# 'Close'
# Working on : JOE
# 'Close'
# Working on : JOUT
# 'Close'
# Working on : JPM
# 'Close'
# Working on : JRVR
# 'Close'
# Working on : JVA
# 'Close'
# Working on : JWN
# 'Close'
# Working on : JYNT
# 'Close'
# Working on : K
# 'Close'
# Working on : KAI
# 'Close'
# Working on : KALA
# 'Close'
# Working on : KALU
# 'Close'
# Working on : KALV
# 'Close'
# Working on : KAMN
# 'Close'
# Working on : KAR
# 'Close'
# Working on : KBAL
# 'Close'
# Working on : KBH
# 'Close'
# Working on : KBR
# 'Close'
# Working on : KDMN
# 'Close'
# Working on : KDP
# 'Close'
# Working on : KE
# 'Close'
# Working on : KELYA
# 'Close'
# Working on : KEQU
# 'Close'
# Working on : KEX
# 'Close'
# Working on : KEY
# 'Close'
# Working on : KEYS
# 'Close'
# Working on : KFFB
# 'Close'
# Working on : KFRC
# 'Close'
# Working on : KFY
# 'Close'
# Working on : KHC
# 'Close'
# Working on : KIDS
# 'Close'
# Working on : KIM
# 'Close'
# Working on : KIN
# 'Close'
# Working on : KINS
# 'Close'
# Working on : KIRK
# 'Close'
# Working on : KKR
# 'Close'
# Working on : KLAC
# 'Close'
# Working on : KLIC
# 'Close'
# Working on : KMB
# 'Close'
# Working on : KMI
# 'Close'
# Working on : KMPH
# 'Close'
# Working on : KMPR
# 'Close'
# Working on : KMT
# 'Close'
# Working on : KMX
# 'Close'
# Working on : KN
# 'Close'
# Working on : KNL
# 'Close'
# Working on : KNSL
# 'Close'
# Working on : KNX
# 'Close'
# Working on : KO
# 'Close'
# Working on : KODK
# 'Close'
# Working on : KOP
# 'Close'
# Working on : KOPN
# 'Close'
# Working on : KOS
# 'Close'
# Working on : KPTI
# 'Close'
# Working on : KR
# 'Close'
# Working on : KRA
# 'Close'
# Working on : KRC
# 'Close'
# Working on : KREF
# 'Close'
# Working on : KRG
# 'Close'
# Working on : KRNY
# 'Close'
# Working on : KRO
# 'Close'
# Working on : KRYS
# 'Close'
# Working on : KSS
# 'Close'
# Working on : KSU
# 'Close'
# Working on : KTCC
# 'Close'
# Working on : KTOS
# 'Close'
# Working on : KURA
# 'Close'
# Working on : KVHI
# 'Close'
# Working on : KW
# 'Close'
# Working on : KWR
# 'Close'
# Working on : L
# 'Close'
# Working on : LAD
# 'Close'
# Working on : LADR
# 'Close'
# Working on : LAKE
# 'Close'
# Working on : LAMR
# 'Close'
# Working on : LANC
# 'Close'
# Working on : LAND
# 'Close'
# Working on : LARK
# 'Close'
# Working on : LAUR
# 'Close'
# Working on : LAWS
# 'Close'
# Working on : LAZ
# 'Close'
# Working on : LB
# 'Close'
# Working on : LBAI
# 'Close'
# Working on : LBC
# 'Close'
# Working on : LBRDA
# 'Close'
# Working on : LBRDK
# 'Close'
# Working on : LBTYA
# 'Close'
# Working on : LBTYK
# 'Close'
# Working on : LC
# 'Close'
# Working on : LCI
# 'Close'
# Working on : LCII
# 'Close'
# Working on : LCNB
# 'Close'
# Working on : LCUT
# 'Close'
# Working on : LDL
# 'Close'
# Working on : LDOS
# 'Close'
# Working on : LE
# 'Close'
# Working on : LEA
# 'Close'
# Working on : LECO
# 'Close'
# Working on : LEE
# 'Close'
# Working on : LEG
# 'Close'
# Working on : LEN
# 'Close'
# Working on : LEU
# 'Close'
# Working on : LFUS
# 'Close'
# Working on : LFVN
# 'Close'
# Working on : LGIH
# 'Close'
# Working on : LGL
# 'Close'
# Working on : LGND
# 'Close'
# Working on : LH
# 'Close'
# Working on : LHCG
# 'Close'
# Working on : LIFE
# 'Close'
# Working on : LII
# 'Close'
# Working on : LILA
# 'Close'
# Working on : LILAK
# 'Close'
# Working on : LIN
# 'Close'
# Working on : LINC
# 'Close'
# Working on : LIND
# 'Close'
# Working on : LIQT
# 'Close'
# Working on : LITE
# 'Close'
# Working on : LIVE
# 'Close'
# Working on : LIVN
# 'Close'
# Working on : LIVX
# 'Close'
# Working on : LJPC
# 'Close'
# Working on : LKFN
# 'Close'
# Working on : LKQ
# 'Close'
# Working on : LL
# 'Close'
# Working on : LLNW
# 'Close'
# Working on : LLY
# 'Close'
# Working on : LMAT
# 'Close'
# Working on : LMFA
# 'Close'
# Working on : LMNR
# 'Close'
# Working on : LMNX
# 'Close'
# Working on : LMT
# 'Close'
# Working on : LNC
# 'Close'
# Working on : LNDC
# 'Close'
# Working on : LNG
# 'Close'
# Working on : LNN
# 'Close'
# Working on : LNT
# 'Close'
# Working on : LNTH
# 'Close'
# Working on : LOAN
# 'Close'
# Working on : LOB
# 'Close'
# Working on : LOCO
# 'Close'
# Working on : LODE
# 'Close'
# Working on : LOOP
# 'Close'
# Working on : LOPE
# 'Close'
# Working on : LORL
# 'Close'
# Working on : LOW
# 'Close'
# Working on : LPCN
# 'Close'
# Working on : LPG
# 'Close'
# Working on : LPI
# 'Close'
# Working on : LPLA
# 'Close'
# Working on : LPSN
# 'Close'
# Working on : LPTH
# 'Close'
# Working on : LPX
# 'Close'
# Working on : LQDT
# 'Close'
# Working on : LRCX
# 'Close'
# Working on : LRN
# 'Close'
# Working on : LSBK
# 'Close'
# Working on : LSCC
# 'Close'
# Working on : LSI
# 'Close'
# Working on : LSTR
# 'Close'
# Working on : LSXMA
# 'Close'
# Working on : LSXMK
# 'Close'
# Working on : LTBR
# 'Close'
# Working on : LTC
# 'Close'
# Working on : LTRPA
# 'Close'
# Working on : LTRX
# 'Close'
# Working on : LUB
# 'Close'
# Working on : LULU
# 'Close'
# Working on : LUNA
# 'Close'
# Working on : LUV
# 'Close'
# Working on : LVS
# 'Close'
# Working on : LW
# 'Close'
# Working on : LWAY
# 'Close'
# Working on : LXP
# 'Close'
# Working on : LXRX
# 'Close'
# Working on : LXU
# 'Close'
# Working on : LYB
# 'Close'
# Working on : LYTS
# 'Close'
# Working on : LYV
# 'Close'
# Working on : LZB
# 'Close'
# Working on : M
# 'Close'
# Working on : MA
# 'Close'
# Working on : MAA
# 'Close'
# Working on : MAC
# 'Close'
# Working on : MACK
# 'Close'
# Working on : MAN
# 'Close'
# Working on : MANH
# 'Close'
# Working on : MANT
# 'Close'
# Working on : MAR
# 'Close'
# Working on : MARA
# 'Close'
# Working on : MARK
# 'Close'
# Working on : MAS
# 'Close'
# Working on : MASI
# 'Close'
# Working on : MAT
# 'Close'
# Working on : MATW
# 'Close'
# Working on : MATX
# 'Close'
# Working on : MAYS
# 'Close'
# Working on : MBCN
# 'Close'
# Working on : MBI
# 'Close'
# Working on : MBII
# 'Close'
# Working on : MBIN
# 'Close'
# Working on : MBIO
# 'Close'
# Working on : MBOT
# 'Close'
# Working on : MBUU
# 'Close'
# Working on : MBWM
# 'Close'
# Working on : MC
# 'Close'
# Working on : MCB
# 'Close'
# Working on : MCBC
# 'Close'
# Working on : MCD
# 'Close'
# Working on : MCF
# 'Close'
# Working on : MCFT
# 'Close'
# Working on : MCHP
# 'Close'
# Working on : MCHX
# 'Close'
# Working on : MCK
# 'Close'
# Working on : MCO
# 'Close'
# Working on : MCRB
# 'Close'
# Working on : MCRI
# 'Close'
# Working on : MCS
# 'Close'
# Working on : MCY
# 'Close'
# Working on : MD
# 'Close'
# Working on : MDB
# 'Close'
# Working on : MDC
# 'Close'
# Working on : MDGL
# 'Close'
# Working on : MDLY
# 'Close'
# Working on : MDLZ
# 'Close'
# Working on : MDP
# 'Close'
# Working on : MDRX
# 'Close'
# Working on : MDT
# 'Close'
# Working on : MDU
# 'Close'
# Working on : MED
# 'Close'
# Working on : MEDP
# 'Close'
# Working on : MEI
# 'Close'
# Working on : MEIP
# 'Close'
# Working on : MERC
# 'Close'
# Working on : MET
# 'Close'
# Working on : MFA
# 'Close'
# Working on : MFNC
# 'Close'
# Working on : MG
# 'Close'
# Working on : MGEE
# 'Close'
# Working on : MGI
# 'Close'
# Working on : MGLN
# 'Close'
# Working on : MGM
# 'Close'
# Working on : MGNX
# 'Close'
# Working on : MGPI
# 'Close'
# Working on : MGRC
# 'Close'
# Working on : MGY
# 'Close'
# Working on : MGYR
# 'Close'
# Working on : MHH
# 'Close'
# Working on : MHK
# 'Close'
# Working on : MHLD
# 'Close'
# Working on : MHO
# 'Close'
# Working on : MIC
# 'Close'
# Working on : MICR
# 'Close'
# Working on : MICT
# 'Close'
# Working on : MIDD
# 'Close'
# Working on : MIND
# 'Close'
# Working on : MITK
# 'Close'
# Working on : MITT
# 'Close'
# Working on : MKC
# 'Close'
# Working on : MKL
# 'Close'
# Working on : MKSI
# 'Close'
# Working on : MKTX
# 'Close'
# Working on : MLAB
# 'Close'
# Working on : MLHR
# 'Close'
# Working on : MLI
# 'Close'
# Working on : MLM
# 'Close'
# Working on : MLND
# 'Close'
# Working on : MLP
# 'Close'
# Working on : MLR
# 'Close'
# Working on : MLSS
# 'Close'
# Working on : MLVF
# 'Close'
# Working on : MMAC
# 'Close'
# Working on : MMC
# 'Close'
# Working on : MMI
# 'Close'
# Working on : MMM
# 'Close'
# Working on : MMS
# 'Close'
# Working on : MMSI
# 'Close'
# Working on : MN
# 'Close'
# Working on : MNKD
# 'Close'
# Working on : MNOV
# 'Close'
# Working on : MNR
# 'Close'
# Working on : MNRO
# 'Close'
# Working on : MNST
# 'Close'
# Working on : MNTX
# 'Close'
# Working on : MO
# 'Close'
# Working on : MOBL
# 'Close'
# Working on : MOD
# 'Close'
# Working on : MODN
# 'Close'
# Working on : MOFG
# 'Close'
# Working on : MOH
# 'Close'
# Working on : MORN
# 'Close'
# Working on : MOS
# 'Close'
# Working on : MOSY
# 'Close'
# Working on : MOV
# 'Close'
# Working on : MPAA
# 'Close'
# Working on : MPB
# 'Close'
# Working on : MPC
# 'Close'
# Working on : MPW
# 'Close'
# Working on : MPWR
# 'Close'
# Working on : MPX
# 'Close'
# Working on : MRAM
# 'Close'
# Working on : MRC
# 'Close'
# Working on : MRCY
# 'Close'
# Working on : MRIN
# 'Close'
# Working on : MRK
# 'Close'
# Working on : MRKR
# 'Close'
# Working on : MRLN
# 'Close'
# Working on : MRNS
# 'Close'
# Working on : MRO
# 'Close'
# Working on : MRSN
# 'Close'
# Working on : MRTN
# 'Close'
# Working on : MRTX
# 'Close'
# Working on : MRVL
# 'Close'
# Working on : MS
# 'Close'
# Working on : MSA
# 'Close'
# Working on : MSBI
# 'Close'
# Working on : MSCI
# 'Close'
# Working on : MSEX
# 'Close'
# Working on : MSFT
# 'Close'
# Working on : MSGN
# 'Close'
# Working on : MSI
# 'Close'
# Working on : MSM
# 'Close'
# Working on : MSN
# 'Close'
# Working on : MSON
# 'Close'
# Working on : MSTR
# 'Close'
# Working on : MTB
# 'Close'
# Working on : MTCH
# 'Close'
# Working on : MTD
# 'Close'
# Working on : MTDR
# 'Close'
# Working on : MTEM
# 'Close'
# Working on : MTEX
# 'Close'
# Working on : MTG
# 'Close'
# Working on : MTH
# 'Close'
# Working on : MTN
# 'Close'
# Working on : MTNB
# 'Close'
# Working on : MTOR
# 'Close'
# Working on : MTRN
# 'Close'
# Working on : MTRX
# 'Close'
# Working on : MTSI
# 'Close'
# Working on : MTW
# 'Close'
# Working on : MTX
# 'Close'
# Working on : MTZ
# 'Close'
# Working on : MU
# 'Close'
# Working on : MUR
# 'Close'
# Working on : MUSA
# 'Close'
# Working on : MUX
# 'Close'
# Working on : MVBF
# 'Close'
# Working on : MVIS
# 'Close'
# Working on : MWA
# 'Close'
# Working on : MXIM
# 'Close'
# Working on : MXL
# 'Close'
# Working on : MYE
# 'Close'
# Working on : MYGN
# 'Close'
# Working on : MYRG
# 'Close'
# Working on : NAII
# 'Close'
# Working on : NATH
# 'Close'
# Working on : NATI
# 'Close'
# Working on : NATR
# 'Close'
# Working on : NAV
# 'Close'
# Working on : NAVB
# 'Close'
# Working on : NAVI
# 'Close'
# Working on : NBEV
# 'Close'
# Working on : NBHC
# 'Close'
# Working on : NBIX
# 'Close'
# Working on : NBN
# 'Close'
# Working on : NBR
# 'Close'
# Working on : NBTB
# 'Close'
# Working on : NBY
# 'Close'
# Working on : NC
# 'Close'
# Working on : NCBS
# 'Close'
# Working on : NCLH
# 'Close'
# Working on : NCMI
# 'Close'
# Working on : NCR
# 'Close'
# Working on : NCSM
# 'Close'
# Working on : NDAQ
# 'Close'
# Working on : NDLS
# 'Close'
# Working on : NDSN
# 'Close'
# Working on : NEE
# 'Close'
# Working on : NEM
# 'Close'
# Working on : NEO
# 'Close'
# Working on : NEOG
# 'Close'
# Working on : NEON
# 'Close'
# Working on : NERV
# 'Close'
# Working on : NETE
# 'Close'
# Working on : NEU
# 'Close'
# Working on : NEWR
# 'Close'
# Working on : NFBK
# 'Close'
# Working on : NFG
# 'Close'
# Working on : NFLX
# Working on : NGS
# 'Close'
# Working on : NGVC
# 'Close'
# Working on : NGVT
# 'Close'
# Working on : NHC
# 'Close'
# Working on : NHI
# 'Close'
# Working on : NHTC
# 'Close'
# Working on : NI
# 'Close'
# Working on : NICK
# 'Close'
# Working on : NJR
# 'Close'
# Working on : NKE
# 'Close'
# Working on : NKSH
# 'Close'
# Working on : NKTR
# 'Close'
# Working on : NL
# 'Close'
# Working on : NLS
# 'Close'
# Working on : NLSN
# 'Close'
# Working on : NLY
# 'Close'
# Working on : NMIH
# 'Close'
# Working on : NMRK
# 'Close'
# Working on : NNBR
# 'Close'
# Working on : NNI
# 'Close'
# Working on : NNN
# 'Close'
# Working on : NNVC
# 'Close'
# Working on : NOC
# 'Close'
# Working on : NODK
# 'Close'
# Working on : NOG
# 'Close'
# Working on : NOV
# 'Close'
# Working on : NOVT
# 'Close'
# Working on : NOW
# 'Close'
# Working on : NP
# 'Close'
# Working on : NPK
# 'Close'
# Working on : NPO
# 'Close'
# Working on : NPTN
# 'Close'
# Working on : NR
# 'Close'
# Working on : NRC
# 'Close'
# Working on : NRG
# 'Close'
# Working on : NRIM
# 'Close'
# Working on : NRZ
# 'Close'
# Working on : NSA
# 'Close'
# Working on : NSC
# 'Close'
# Working on : NSEC
# 'Close'
# Working on : NSIT
# 'Close'
# Working on : NSP
# 'Close'
# Working on : NSSC
# 'Close'
# Working on : NSTG
# 'Close'
# Working on : NTAP
# 'Close'
# Working on : NTCT
# 'Close'
# Working on : NTGR
# 'Close'
# Working on : NTIC
# 'Close'
# Working on : NTIP
# 'Close'
# Working on : NTLA
# 'Close'
# Working on : NTNX
# 'Close'
# Working on : NTRA
# 'Close'
# Working on : NTRS
# 'Close'
# Working on : NTWK
# 'Close'
# Working on : NUAN
# 'Close'
# Working on : NUE
# 'Close'
# Working on : NURO
# 'Close'
# Working on : NUS
# 'Close'
# Working on : NUVA
# 'Close'
# Working on : NVAX
# 'Close'
# Working on : NVDA
# 'Close'
# Working on : NVEC
# 'Close'
# Working on : NVEE
# 'Close'
# Working on : NVFY
# 'Close'
# Working on : NVIV
# 'Close'
# Working on : NVR
# 'Close'
# Working on : NVRO
# 'Close'
# Working on : NVTA
# 'Close'
# ...
# 'Close'
# Working on : SANM
# 'Close'
# Working on : SANW
# 'Close'
# Working on : SASR
# 'Close'
# Working on : SATS
# 'Close'
# Working on : SAVE
# 'Close'
# Working on : SBAC
# 'Close'
# Working on : SBCF
# 'Close'
# Working on : SBFG
# 'Close'
# Working on : SBGI
# 'Close'
# Working on : SBH
# 'Close'
# Working on : SBNY
# 'Close'
# Working on : SBOW
# 'Close'
# Working on : SBRA
# 'Close'
# Working on : SBSI
# 'Close'
# Working on : SBT
# 'Close'
# Working on : SBUX
# 'Close'
# Working on : SC
# 'Close'
# Working on : SCHL
# 'Close'
# Working on : SCHN
# 'Close'
# Working on : SCHW
# 'Close'
# Working on : SCI
# 'Close'
# Working on : SCL
# 'Close'
# Working on : SCON
# 'Close'
# Working on : SCOR
# 'Close'
# Working on : SCS
# 'Close'
# Working on : SCSC
# 'Close'
# Working on : SCVL
# 'Close'
# Working on : SCWX
# 'Close'
# Working on : SCX
# 'Close'
# Working on : SCYX
# 'Close'
# Working on : SD
# 'Close'
# Working on : SDPI
# 'Close'
# Working on : SEAC
# 'Close'
# Working on : SEAS
# 'Close'
# Working on : SEB
# 'Close'
# Working on : SEDG
# 'Close'
# Working on : SEE
# 'Close'
# Working on : SEIC
# 'Close'
# Working on : SELB
# 'Close'
# Working on : SELF
# 'Close'
# Working on : SEM
# 'Close'
# Working on : SENEA
# 'Close'
# Working on : SENEB
# 'Close'
# Working on : SENS
# 'Close'
# Working on : SESN
# 'Close'
# Working on : SF
# 'Close'
# Working on : SFBC
# 'Close'
# Working on : SFBS
# 'Close'
# Working on : SFE
# 'Close'
# Working on : SFIX
# 'Close'
# Working on : SFM
# 'Close'
# Working on : SFNC
# 'Close'
# Working on : SFST
# 'Close'
# Working on : SGA
# 'Close'
# Working on : SGC
# 'Close'
# Working on : SGEN
# 'Close'
# Working on : SGH
# 'Close'
# Working on : SGMA
# 'Close'
# Working on : SGMO
# 'Close'
# Working on : SGMS
# 'Close'
# Working on : SGRP
# 'Close'
# Working on : SGRY
# 'Close'
# Working on : SHAK
# 'Close'
# Working on : SHBI
# 'Close'
# Working on : SHEN
# 'Close'
# Working on : SHO
# 'Close'
# Working on : SHOO
# 'Close'
# Working on : SHSP
# 'Close'
# Working on : SHW
# 'Close'
# Working on : SIEB
# 'Close'
# Working on : SIEN
# 'Close'
# Working on : SIF
# 'Close'
# Working on : SIG
# 'Close'
# Working on : SIGA
# 'Close'
# Working on : SIGI
# 'Close'
# Working on : SINT
# 'Close'
# Working on : SIRI
# 'Close'
# Working on : SITC
# 'Close'
# Working on : SITE
# 'Close'
# Working on : SIVB
# 'Close'
# Working on : SIX
# 'Close'
# Working on : SJI
# 'Close'
# Working on : SJM
# 'Close'
# Working on : SJW
# 'Close'
# Working on : SKT
# 'Close'
# Working on : SKX
# 'Close'
# Working on : SKY
# 'Close'
# Working on : SKYW
# 'Close'
# Working on : SLAB
# 'Close'
# Working on : SLB
# 'Close'
# Working on : SLCA
# 'Close'
# Working on : SLCT
# 'Close'
# Working on : SLG
# 'Close'
# Working on : SLGN
# 'Close'
# Working on : SLM
# 'Close'
# Working on : SLNO
# 'Close'
# Working on : SLP
# 'Close'
# Working on : SLS
# 'Close'
# Working on : SM
# 'Close'
# Working on : SMBC
# 'Close'
# Working on : SMBK
# 'Close'
# Working on : SMED
# 'Close'
# Working on : SMG
# 'Close'
# Working on : SMIT
# 'Close'
# Working on : SMMF
# 'Close'
# Working on : SMP
# 'Close'
# Working on : SMPL
# 'Close'
# Working on : SMSI
# 'Close'
# Working on : SMTC
# 'Close'
# Working on : SNA
# 'Close'
# Working on : SNAP
# 'Close'
# Working on : SNBR
# 'Close'
# Working on : SNCR
# 'Close'
# Working on : SND
# 'Close'
# Working on : SNDR
# 'Close'
# Working on : SNDX
# 'Close'
# Working on : SNFCA
# 'Close'
# Working on : SNOA
# 'Close'
# Working on : SNPS
# 'Close'
# Working on : SNR
# 'Close'
# Working on : SNV
# 'Close'
# Working on : SNX
# 'Close'
# Working on : SO
# 'Close'
# Working on : SOHO
# 'Close'
# Working on : SOI
# 'Close'
# Working on : SON
# 'Close'
# Working on : SP
# 'Close'
# Working on : SPB
# 'Close'
# Working on : SPG
# 'Close'
# Working on : SPGI
# 'Close'
# Working on : SPKE
# 'Close'
# Working on : SPLK
# 'Close'
# Working on : SPNE
# 'Close'
# Working on : SPOK
# 'Close'
# Working on : SPPI
# 'Close'
# Working on : SPR
# 'Close'
# Working on : SPRO
# 'Close'
# Working on : SPRT
# 'Close'
# Working on : SPSC
# 'Close'
# Working on : SPTN
# 'Close'
# Working on : SPWH
# 'Close'
# Working on : SPWR
# 'Close'
# Working on : SPXC
# 'Close'
# Working on : SQ
# 'Close'
# Working on : SQBG
# 'Close'
# Working on : SR
# 'Close'
# Working on : SRC
# 'Close'
# Working on : SRCE
# 'Close'
# Working on : SRCL
# 'Close'
# Working on : SRDX
# 'Close'
# Working on : SRE
# 'Close'
# Working on : SREV
# 'Close'
# Working on : SRG
# 'Close'
# Working on : SRI
# 'Close'
# Working on : SRNE
# 'Close'
# Working on : SRPT
# 'Close'
# Working on : SRT
# 'Close'
# Working on : SRTS
# 'Close'
# Working on : SSB
# 'Close'
# Working on : SSBI
# 'Close'
# Working on : SSD
# 'Close'
# Working on : SSKN
# 'Close'
# Working on : SSNC
# 'Close'
# Working on : SSP
# 'Close'
# Working on : SSTI
# 'Close'
# Working on : SSTK
# 'Close'
# Working on : ST
# 'Close'
# Working on : STAA
# 'Close'
# Working on : STAG
# 'Close'
# Working on : STAR
# 'Close'
# Working on : STBA
# 'Close'
# Working on : STC
# 'Close'
# Working on : STCN
# 'Close'
# Working on : STE
# 'Close'
# Working on : STFC
# 'Close'
# Working on : STKS
# 'Close'
# Working on : STL
# 'Close'
# Working on : STLD
# 'Close'
# Working on : STMP
# 'Close'
# Working on : STOR
# 'Close'
# Working on : STRA
# 'Close'
# Working on : STRL
# 'Close'
# Working on : STRM
# 'Close'
# Working on : STRS
# 'Close'
# Working on : STRT
# 'Close'
# Working on : STT
# 'Close'
# Working on : STWD
# 'Close'
# Working on : STX
# 'Close'
# Working on : STZ
# 'Close'
# Working on : SUI
# 'Close'
# Working on : SUM
# 'Close'
# Working on : SUMR
# 'Close'
# Working on : SUNW
# 'Close'
# Working on : SUP
# 'Close'
# Working on : SUPN
# 'Close'
# Working on : SVBI
# 'Close'
# Working on : SVRA
# 'Close'
# Working on : SVT
# 'Close'
# Working on : SWCH
# 'Close'
# Working on : SWK
# 'Close'
# Working on : SWKS
# 'Close'
# Working on : SWM
# 'Close'
# Working on : SWN
# 'Close'
# Working on : SWX
# 'Close'
# Working on : SXC
# 'Close'
# Working on : SXI
# 'Close'
# Working on : SXT
# 'Close'
# Working on : SYBT
# 'Close'
# Working on : SYBX
# 'Close'
# Working on : SYF
# 'Close'
# Working on : SYK
# 'Close'
# Working on : SYKE
# 'Close'
# Working on : SYN
# 'Close'
# Working on : SYNA
# 'Close'
# Working on : SYNH
# 'Close'
# Working on : SYNL
# 'Close'
# Working on : SYPR
# 'Close'
# Working on : SYRS
# 'Close'
# Working on : SYX
# 'Close'
# Working on : SYY
# 'Close'
# Working on : T
# 'Close'
# Working on : TACO
# 'Close'
# Working on : TACT
# 'Close'
# Working on : TAIT
# 'Close'
# Working on : TAP
# 'Close'
# Working on : TAST
# 'Close'
# Working on : TAYD
# 'Close'
# Working on : TBBK
# 'Close'
# Working on : TBI
# 'Close'
# Working on : TBK
# 'Close'
# Working on : TBNK
# 'Close'
# Working on : TBPH
# 'Close'
# Working on : TCBI
# 'Close'
# Working on : TCBK
# 'Close'
# Working on : TCFC
# 'Close'
# Working on : TCI
# 'Close'
# Working on : TCMD
# 'Close'
# Working on : TCON
# 'Close'
# Working on : TCS
# 'Close'
# Working on : TDC
# 'Close'
# Working on : TDG
# 'Close'
# Working on : TDOC
# 'Close'
# Working on : TDS
# 'Close'
# Working on : TDW
# 'Close'
# Working on : TDY
# 'Close'
# Working on : TECH
# 'Close'
# Working on : TEL
# 'Close'
# Working on : TELL
# 'Close'
# Working on : TEN
# 'Close'
# Working on : TENX
# 'Close'
# Working on : TER
# 'Close'
# Working on : TESS
# 'Close'
# Working on : TEUM
# 'Close'
# Working on : TEX
# 'Close'
# Working on : TFSL
# 'Close'
# Working on : TFX
# 'Close'
# Working on : TG
# 'Close'
# Working on : TGEN
# 'Close'
# Working on : TGI
# 'Close'
# Working on : TGLS
# 'Close'
# Working on : TGNA
# 'Close'
# Working on : TGT
# 'Close'
# Working on : TGTX
# 'Close'
# Working on : THC
# 'Close'
# Working on : THFF
# 'Close'
# Working on : THG
# 'Close'
# Working on : THO
# 'Close'
# Working on : THR
# 'Close'
# Working on : THRM
# 'Close'
# Working on : THS
# 'Close'
# Working on : TILE
# 'Close'
# Working on : TIPT
# 'Close'
# Working on : TISI
# 'Close'
# Working on : TITN
# 'Close'
# Working on : TJX
# 'Close'
# Working on : TKR
# 'Close'
# Working on : TLGT
# 'Close'
# Working on : TLYS
# 'Close'
# Working on : TMHC
# 'Close'
# Working on : TMO
# 'Close'
# Working on : TMP
# 'Close'
# Working on : TMST
# 'Close'
# Working on : TMUS
# 'Close'
# Working on : TNC
# 'Close'
# Working on : TNDM
# 'Close'
# Working on : TNET
# 'Close'
# Working on : TNXP
# 'Close'
# Working on : TOL
# 'Close'
# Working on : TOWN
# 'Close'
# Working on : TPB
# 'Close'
# Working on : TPC
# 'Close'
# Working on : TPH
# 'Close'
# Working on : TPHS
# 'Close'
# Working on : TPIC
# 'Close'
# Working on : TPR
# 'Close'
# Working on : TPX
# 'Close'
# Working on : TR
# 'Close'
# Working on : TRC
# 'Close'
# Working on : TRCH
# 'Close'
# Working on : TREC
# 'Close'
# Working on : TREE
# 'Close'
# Working on : TREX
# 'Close'
# Working on : TRGP
# 'Close'
# Working on : TRHC
# 'Close'
# Working on : TRIP
# 'Close'
# Working on : TRMB
# 'Close'
# Working on : TRMK
# 'Close'
# Working on : TRN
# 'Close'
# Working on : TRNO
# 'Close'
# Working on : TRNS
# 'Close'
# Working on : TROW
# 'Close'
# Working on : TROX
# 'Close'
# Working on : TRS
# 'Close'
# Working on : TRST
# 'Close'
# Working on : TRT
# 'Close'
# Working on : TRTN
# 'Close'
# Working on : TRTX
# 'Close'
# Working on : TRU
# 'Close'
# Working on : TRUP
# 'Close'
# Working on : TRV
# 'Close'
# Working on : TRVN
# 'Close'
# Working on : TSBK
# 'Close'
# Working on : TSC
# 'Close'
# Working on : TSCO
# 'Close'
# Working on : TSE
# 'Close'
# Working on : TSLA
# 'Close'
# Working on : TSN
# 'Close'
# Working on : TSQ
# 'Close'
# Working on : TTC
# 'Close'
# Working on : TTD
# 'Close'
# Working on : TTEC
# 'Close'
# Working on : TTEK
# 'Close'
# Working on : TTGT
# 'Close'
# Working on : TTI
# 'Close'
# Working on : TTMI
# 'Close'
# Working on : TTNP
# 'Close'
# Working on : TTOO
# 'Close'
# Working on : TTWO
# 'Close'
# Working on : TUP
# 'Close'
# Working on : TUSK
# 'Close'
# Working on : TVTY
# 'Close'
# Working on : TWI
# 'Close'
# Working on : TWIN
# 'Close'
# Working on : TWLO
# 'Close'
# Working on : TWNK
# 'Close'
# Working on : TWO
# 'Close'
# Working on : TWOU
# 'Close'
# Working on : TWTR
# 'Close'
# Working on : TXMD
# 'Close'
# Working on : TXN
# 'Close'
# Working on : TXRH
# 'Close'
# Working on : TXT
# 'Close'
# Working on : TYL
# 'Close'
# Working on : TYME
# 'Close'
# Working on : TZOO
# 'Close'
# Working on : UA
# 'Close'
# Working on : UAA
# 'Close'
# Working on : UAL
# 'Close'
# Working on : UAMY
# 'Close'
# Working on : UBA
# 'Close'
# Working on : UBCP
# 'Close'
# Working on : UBFO
# 'Close'
# Working on : UBOH
# 'Close'
# Working on : UBSI
# 'Close'
# Working on : UCBI
# 'Close'
# Working on : UCTT
# 'Close'
# Working on : UDR
# 'Close'
# Working on : UE
# 'Close'
# Working on : UEC
# 'Close'
# Working on : UEIC
# 'Close'
# Working on : UFAB
# 'Close'
# Working on : UFCS
# 'Close'
# Working on : UFI
# 'Close'
# Working on : UFPI
# 'Close'
# Working on : UFPT
# 'Close'
# Working on : UFS
# 'Close'
# Working on : UG
# 'Close'
# Working on : UGI
# 'Close'
# Working on : UHAL
# 'Close'
# Working on : UHS
# 'Close'
# Working on : UHT
# 'Close'
# Working on : UIHC
# 'Close'
# Working on : UIS
# 'Close'
# Working on : ULBI
# 'Close'
# Working on : ULH
# 'Close'
# Working on : ULTA
# 'Close'
# Working on : UMBF
# 'Close'
# Working on : UMH
# 'Close'
# Working on : UMPQ
# 'Close'
# Working on : UNAM
# 'Close'
# Working on : UNB
# 'Close'
# Working on : UNF
# 'Close'
# Working on : UNFI
# 'Close'
# Working on : UNH
# 'Close'
# Working on : UNIT
# 'Close'
# Working on : UNM
# 'Close'
# Working on : UNP
# 'Close'
# Working on : UNTY
# 'Close'
# Working on : UNVR
# 'Close'
# Working on : UONE
# 'Close'
# Working on : UONEK
# 'Close'
# Working on : UPLD
# 'Close'
# Working on : UPS
# 'Close'
# Working on : URBN
# 'Close'
# Working on : URI
# 'Close'
# Working on : USAK
# 'Close'
# Working on : USAP
# 'Close'
# Working on : USB
# 'Close'
# Working on : USCR
# 'Close'
# Working on : USEG
# 'Close'
# Working on : USFD
# 'Close'
# Working on : USIO
# 'Close'
# Working on : USLM
# 'Close'
# Working on : USM
# 'Close'
# Working on : USNA
# 'Close'
# Working on : USPH
# 'Close'
# Working on : UTHR
# 'Close'
# Working on : UTI
# 'Close'
# Working on : UTL
# 'Close'
# Working on : UTMD
# 'Close'
# Working on : UUU
# 'Close'
# Working on : UVE
# 'Close'
# Working on : UVSP
# 'Close'
# Working on : UVV
# 'Close'
# Working on : V
# 'Close'
# Working on : VAC
# 'Close'
# Working on : VALU
# 'Close'
# Working on : VBFC
# 'Close'
# Working on : VBIV
# 'Close'
# Working on : VBTX
# 'Close'
# Working on : VC
# 'Close'
# Working on : VCEL
# 'Close'
# Working on : VCRA
# 'Close'
# Working on : VCYT
# 'Close'
# Working on : VEC
# 'Close'
# Working on : VECO
# 'Close'
# Working on : VEEV
# 'Close'
# Working on : VER
# 'Close'
# Working on : VERI
# 'Close'
# Working on : VERU
# 'Close'
# Working on : VFC
# 'Close'
# Working on : VG
# 'Close'
# Working on : VGR
# 'Close'
# Working on : VHC
# 'Close'
# Working on : VIAV
# 'Close'
# Working on : VICR
# 'Close'
# Working on : VIRC
# 'Close'
# Working on : VIRT
# 'Close'
# Working on : VISL
# 'Close'
# Working on : VIVO
# 'Close'
# Working on : VKTX
# 'Close'
# Working on : VLGEA
# 'Close'
# Working on : VLO
# 'Close'
# Working on : VLY
# 'Close'
# Working on : VMC
# 'Close'
# Working on : VMI
# 'Close'
# Working on : VMW
# 'Close'
# Working on : VNCE
# 'Close'
# Working on : VNDA
# 'Close'
# Working on : VNO
# 'Close'
# Working on : VNRX
# 'Close'
# Working on : VNTR
# 'Close'
# Working on : VOXX
# 'Close'
# Working on : VOYA
# 'Close'
# Working on : VPG
# 'Close'
# Working on : VRA
# 'Close'
# Working on : VRAY
# 'Close'
# Working on : VREX
# 'Close'
# Working on : VRNS
# 'Close'
# Working on : VRNT
# 'Close'
# Working on : VRRM
# 'Close'
# Working on : VRS
# 'Close'
# Working on : VRSK
# 'Close'
# Working on : VRSN
# 'Close'
# Working on : VRTS
# 'Close'
# Working on : VRTV
# 'Close'
# Working on : VRTX
# 'Close'
# Working on : VSAT
# 'Close'
# Working on : VSEC
# 'Close'
# Working on : VSH
# 'Close'
# Working on : VST
# 'Close'
# Working on : VSTM
# 'Close'
# Working on : VSTO
# 'Close'
# Working on : VTNR
# 'Close'
# Working on : VTR
# 'Close'
# Working on : VTVT
# 'Close'
# Working on : VUZI
# 'Close'
# Working on : VVI
# 'Close'
# Working on : VVV
# 'Close'
# Working on : VXRT
# 'Close'
# Working on : VYGR
# 'Close'
# Working on : VZ
# 'Close'
# Working on : W
# 'Close'
# Working on : WAB
# 'Close'
# Working on : WABC
# 'Close'
# Working on : WAFD
# 'Close'
# Working on : WAL
# 'Close'
# Working on : WASH
# 'Close'
# Working on : WAT
# 'Close'
# Working on : WATT
# 'Close'
# Working on : WBA
# 'Close'
# Working on : WBS
# 'Close'
# Working on : WBT
# 'Close'
# Working on : WCC
# 'Close'
# Working on : WD
# 'Close'
# Working on : WDAY
# 'Close'
# Working on : WDC
# 'Close'
# Working on : WDFC
# 'Close'
# Working on : WEC
# 'Close'
# Working on : WELL
# 'Close'
# Working on : WEN
# 'Close'
# Working on : WERN
# 'Close'
# Working on : WETF
# 'Close'
# Working on : WEX
# 'Close'
# Working on : WEYS
# 'Close'
# Working on : WFC
# 'Close'
# Working on : WGO
# 'Close'
# Working on : WHG
# 'Close'
# Working on : WHLM
# 'Close'
# Working on : WHLR
# 'Close'
# Working on : WHR
# 'Close'
# Working on : WINA
# 'Close'
# Working on : WING
# 'Close'
# Working on : WIRE
# 'Close'
# Working on : WK
# 'Close'
# Working on : WKHS
# 'Close'
# Working on : WLDN
# 'Close'
# Working on : WLFC
# 'Close'
# Working on : WLK
# 'Close'
# Working on : WLL
# 'Close'
# Working on : WLTW
# 'Close'
# Working on : WM
# 'Close'
# Working on : WMB
# 'Close'
# Working on : WMC
# 'Close'
# Working on : WMK
# 'Close'
# Working on : WMS
# 'Close'
# Working on : WMT
# 'Close'
# Working on : WNC
# 'Close'
# Working on : WNEB
# 'Close'
# Working on : WOR
# 'Close'
# Working on : WOW
# 'Close'
# Working on : WPC
# 'Close'
# Working on : WPG
# 'Close'
# Working on : WRB
# 'Close'
# Working on : WRE
# 'Close'
# Working on : WRI
# 'Close'
# Working on : WRK
# 'Close'
# Working on : WRLD
# 'Close'
# Working on : WSBC
# 'Close'
# Working on : WSBF
# 'Close'
# Working on : WSC
# 'Close'
# Working on : WSFS
# 'Close'
# Working on : WSM
# 'Close'
# Working on : WSO
# 'Close'
# Working on : WSR
# 'Close'
# Working on : WST
# 'Close'
# Working on : WSTG
# 'Close'
# Working on : WSTL
# 'Close'
# Working on : WTBA
# 'Close'
# Working on : WTFC
# 'Close'
# Working on : WTI
# 'Close'
# Working on : WTM
# 'Close'
# Working on : WTRH
# 'Close'
# Working on : WTS
# 'Close'
# Working on : WTT
# 'Close'
# Working on : WTTR
# 'Close'
# Working on : WU
# 'Close'
# Working on : WVE
# 'Close'
# Working on : WVFC
# 'Close'
# Working on : WVVI
# 'Close'
# Working on : WW
# 'Close'
# Working on : WWD
# 'Close'
# Working on : WWE
# 'Close'
# Working on : WWR
# 'Close'
# Working on : WWW
# 'Close'
# Working on : WY
# 'Close'
# Working on : WYNN
# 'Close'
# Working on : WYY
# 'Close'
# Working on : X
# 'Close'
# Working on : XBIT
# 'Close'
# Working on : XEC
# 'Close'
# Working on : XEL
# 'Close'
# Working on : XELA
# 'Close'
# Working on : XELB
# 'Close'
# Working on : XENT
# 'Close'
# Working on : XFOR
# 'Close'
# Working on : XHR
# 'Close'
# Working on : XLNX
# 'Close'
# Working on : XLRN
# 'Close'
# Working on : XNCR
# 'Close'
# Working on : XOM
# 'Close'
# Working on : XOMA
# 'Close'
# Working on : XONE
# 'Close'
# Working on : XPER
# 'Close'
# Working on : XPL
# 'Close'
# Working on : XPO
# 'Close'
# Working on : XRAY
# 'Close'
# Working on : XRX
# 'Close'
# Working on : XSPA
# 'Close'
# Working on : XTNT
# 'Close'
# Working on : XXII
# 'Close'
# Working on : XYL
# 'Close'
# Working on : Y
# 'Close'
# Working on : YELP
# 'Close'
# Working on : YEXT
# 'Close'
# Working on : YORW
# 'Close'
# Working on : YTEN
# 'Close'
# Working on : YUM
# 'Close'
# Working on : Z
# 'Close'
# Working on : ZBH
# 'Close'
# Working on : ZBRA
# 'Close'
# Working on : ZDGE
# 'Close'
# Working on : ZEN
# 'Close'
# Working on : ZEUS
# 'Close'
# Working on : ZG
# 'Close'
# Working on : ZGNX
# 'Close'
# Working on : ZION
# 'Close'
# Working on : ZIOP
# 'Close'
# Working on : ZIXI
# 'Close'
# Working on : ZNGA
# 'Close'
# Working on : ZSAN
# 'Close'
# Working on : ZTS
# 'Close'
# Working on : ZUMZ
# 'Close'
# Working on : ZYNE
# 'Close'
# Working on : ZYXI
# 'Close'
# Working on : ^GSPC

# %% [markdown]
# ## 11 Stock Market Sectors

# %% [markdown]
# We want to invest in stocks that are not correlated with other stocks. This means we want stocks that tend to go down when the others go up. Because all our stocks are expected to do well over the course of the year, this smoothes out the performance of our portfolio.
#
# One way to easily find stocks that are not correlated is to create portfolios using stocks from different sectors of the market.
#
# **Technology** : Manufacturing of electronics, software, or related to information technology
#
# **Health Care** : Biotech, hospitals, medical devices, drugs
#
# **Financials** : Banks, investment funds, and insurance
#
# **Real Estate** : Residential, industrial, and retail real estate
#
# **Energy** : Production and supply of energy
#
# **Materials** : Mining, refining, chemical, and forestry
#
# **Consumer Discretionary** : Retailers, apparel, media, durables and services
#
# **Industrials** : Construction, machinery, fabrication, manufacturing, defense, and aerospace
#
# **Utilities** : Direct providers of electric, gas, and water
#
# **Consumer Staples** : Food, beverage as well as products consumers deem essential
#
# **Telecommunication** : Cable, internet providers, wireless, and satellite

# %% [markdown]
# ## Get Sector Stocks

# %%
sec_df = pd.read_csv("/Users/oppoudel/dev/Python4Finance/Original/stock_sectors.csv")
sec_df

indus_df = sec_df.loc[sec_df['Sector'] == "Industrials"]
health_df = sec_df.loc[sec_df['Sector'] == "Health Care"]
it_df = sec_df.loc[sec_df['Sector'] == "Information Technology"]
comm_df = sec_df.loc[sec_df['Sector'] == "Communication Services"]
staple_df = sec_df.loc[sec_df['Sector'] == "Consumer Staples"]
discretion_df = sec_df.loc[sec_df['Sector'] == "Consumer Discretionary"]
utility_df = sec_df.loc[sec_df['Sector'] == "Utilities"]
financial_df = sec_df.loc[sec_df['Sector'] == "Financials"]
material_df = sec_df.loc[sec_df['Sector'] == "Materials"]
restate_df = sec_df.loc[sec_df['Sector'] == "Real Estate"]
energy_df = sec_df.loc[sec_df['Sector'] == "Energy"]

# %% [markdown]
# ## Returns a DF with Cumulative Return for all Stocks

# %%
def get_cum_ret_for_stocks(stock_df):
    tickers = []
    cum_rets = []

    for index, row in stock_df.iterrows():
        df = get_stock_df_from_csv(row['Symbol'])
        if df is None:
            pass
        else:
            tickers.append(row['Symbol'])
            cum = df['cum_return'].iloc[-1]
            cum_rets.append(cum)
    return pd.DataFrame({'Ticker':tickers, 'CUM_RET':cum_rets})

# %%
industrial = get_cum_ret_for_stocks(indus_df)
health_care = get_cum_ret_for_stocks(health_df)
it = get_cum_ret_for_stocks(it_df)
commun = get_cum_ret_for_stocks(comm_df)
staple = get_cum_ret_for_stocks(staple_df)
discretion = get_cum_ret_for_stocks(discretion_df)
utility = get_cum_ret_for_stocks(utility_df)
finance = get_cum_ret_for_stocks(financial_df)
material = get_cum_ret_for_stocks(material_df)
restate = get_cum_ret_for_stocks(restate_df)
energy = get_cum_ret_for_stocks(energy_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cum_return'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/fr/tckd51lj45dgnrphw808c5j80000gn/T/ipykernel_3093/720080517.py in <module>
# ----> 1 industrial = get_cum_ret_for_stocks(indus_df)
#       2 health_care = get_cum_ret_for_stocks(health_df)
#       3 it = get_cum_ret_for_stocks(it_df)
#       4 commun = get_cum_ret_for_stocks(comm_df)
#       5 staple = get_cum_ret_for_stocks(staple_df)
#
# /var/folders/fr/tckd51lj45dgnrphw808c5j80000gn/T/ipykernel_3093/1063276496.py in get_cum_ret_for_stocks(stock_df)
#       9         else:
#      10             tickers.append(row['Symbol'])
# ---> 11             cum = df['cum_return'].iloc[-1]
#      12             cum_rets.append(cum)
#      13     return pd.DataFrame({'Ticker':tickers, 'CUM_RET':cum_rets})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'cum_return'

# %% [markdown]
# ## Ichimoku Kinko Hyo

# %% [markdown]
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
#  - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
#  - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
#  - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
#  - Leading Span B (Senkou B) : Other line used to identify suture support and resistance
#  - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
#  - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
#  - Lagging Span = Price shifted back 26 periods
#  - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
#  - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
#  - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
#  - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %% [markdown]
# ## Get Ichimoku Function

# %%
def get_fill_color(label):
    if label >= 1:
        return 'rgba(0,250,0,0.4)'
    else:
        return 'rgba(250,0,0,0.4)'

# %%
def get_Ichimoku(ticker):
    df = yf.download(tickers=ticker, period='1y', interval='1d')

    # Conversion
    hi_val = df['High'].rolling(window=9).max()
    low_val = df['Low'].rolling(window=9).min()
    df['Conversion'] = (hi_val + low_val) / 2

    # Baseline
    hi_val2 = df['High'].rolling(window=26).max()
    low_val2 = df['Low'].rolling(window=26).min()
    df['Baseline'] = (hi_val2 + low_val2) / 2

    # Spans
    df['SpanA'] = ((df['Conversion'] + df['Baseline']) / 2).shift(26)
    hi_val3 = df['High'].rolling(window=52).max()
    low_val3 = df['Low'].rolling(window=52).min()
    df['SpanB'] = ((hi_val3 + low_val3) / 2).shift(26)
    df['Lagging'] = df['Close'].shift(-26)

    candle = go.Candlestick(x=df.index, open=df['Open'],
    high=df['High'], low=df["Low"], close=df['Close'], name="Candlestick")

    df1 = df.copy()
    fig = go.Figure()
    df['label'] = np.where(df['SpanA'] > df['SpanB'], 1, 0)
    df['group'] = df['label'].ne(df['label'].shift()).cumsum()

    df = df.groupby('group')

    dfs = []
    for name, data in df:
        dfs.append(data)

    for df in dfs:
        fig.add_traces(go.Scatter(x=df.index, y=df.SpanA,
        line=dict(color='rgba(0,0,0,0)')))

        fig.add_traces(go.Scatter(x=df.index, y=df.SpanB,
        line=dict(color='rgba(0,0,0,0)'),
        fill='tonexty',
        fillcolor=get_fill_color(df['label'].iloc[0])))

    baseline = go.Scatter(x=df1.index, y=df1['Baseline'], 
    line=dict(color='pink', width=2), name="Baseline")

    conversion = go.Scatter(x=df1.index, y=df1['Conversion'], 
    line=dict(color='black', width=1), name="Conversion")

    lagging = go.Scatter(x=df1.index, y=df1['Lagging'], 
    line=dict(color='purple', width=2), name="Lagging")

    span_a = go.Scatter(x=df1.index, y=df1['SpanA'], 
    line=dict(color='green', width=2, dash='dot'), name="Span A")

    span_b = go.Scatter(x=df1.index, y=df1['SpanB'], 
    line=dict(color='red', width=1, dash='dot'), name="Span B")

    fig.add_trace(candle)
    fig.add_trace(baseline)
    fig.add_trace(conversion)
    fig.add_trace(lagging)
    fig.add_trace(span_a)
    fig.add_trace(span_b)
    
    fig.update_layout(height=800, width=1300, showlegend=True)

    fig.show()

# %% [markdown]
# ## What the Lines Mean

# %% [markdown]
#  - Lagging Span : When above the price it is bullish and when below bearish. It is used with other indicators because it is mainly a filter.
#  - Baseline : When below price this is considered support. When above price this is considered resistance. We are in an uptrend when the slope increases and vice versa. The slope of the curve tells us the strength of the trend.
#  - Conversion : We focus on its position versus the Baseline. When the Conversion crosses above the Baseline we are in an upward trend and vice versa. This is considered a strong indicator when above the Cloud and weak when below.
#  - Cloud : The thicker the Cloud, the stronger the trend and vice versa. When the Spans cross many times we are in a range. When they cross this is a sign of a reversal of trend.

# %% [markdown]
# ## Top Industrials

# %%
industrial.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 24   GNRC  8.172729
# 26     GE  6.217026
# 42   ODFL  6.137047
# 10   CPRT  5.350906
# 16    ETN  4.727456
# 9    CTAS  4.009012
# 13     DE  3.816768
# 30   INFO  3.775151
# 35    KSU  3.709996
# 55    TDY  3.444655

# %% [markdown]
# ## Analyze Best Performers with Ichimoku

# %%
get_Ichimoku('GE')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="33683bf1-053e-4630-bcfd-92b931ab8f2c" class="plotly-graph-div" style="height:800px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33683bf1-053e-4630-bcfd-92b931ab8f2c")) {                    Plotly.newPlot(                        "33683bf1-053e-4630-bcfd-92b931ab8f2c",                        [{"line":{"color":"rgba(0,0,0,0)"},"x":["2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00"],"y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,108.61999893188477,108.61999893188477,108.61999893188477,108.8799991607666,109.11999893188477,109.11999893188477,109.11999893188477,109.11999893188477,110.21999931335449,110.15999984741211,110.11999893188477,109.79999923706055,109.60000038146973,109.21999931335449,108.19999885559082,107.71999931335449,107.53999900817871,107.53999900817871,107.45999908447266,107.45999908447266,107.0999984741211,107.0999984741211,106.81999969482422,106.85999870300293,107.13999938964844,107.13999938964844,107.07999992370605,106.95999908447266,106.43999862670898,106.43999862670898,106.0999984741211,105.83999824523926,105.67999839782715,105.0999984741211,104.46000099182129,101.31999778747559,10 ...

# %% [markdown]
# ## Top Healthcare

# %%
health_care.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 25   DXCM  8.678003
# 4    ALGN  6.780879
# 59    WST  5.223830
# 33   IDXX  5.053621
# 16   CTLT  4.888889
# 19    CRL  4.766054
# 61    ZTS  4.687021
# 11   TECH  4.586297
# 54    TMO  4.488118
# 49    RMD  4.426924

# %% [markdown]
# ## Top Information Tech

# %%
it.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker     CUM_RET
# 21   ENPH  172.016003
# 2     AMD   12.785159
# 26   FTNT   11.098766
# 50   PAYC    9.118401
# 57    NOW    8.307653
# 70   ZBRA    7.422101
# 39   LRCX    7.366411
# 14   CDNS    7.123404
# 44   MPWR    6.569404
# 7    AAPL    6.523364

# %% [markdown]
# ## Top Communications

# %%
commun.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 15   NFLX  4.863241
# 14    LYV  4.160283
# 2    GOOG  3.723259
# 1   GOOGL  3.663857
# 20   TTWO  3.310014
# 10     FB  2.943717
# 22   TWTR  2.406762
# 4    CHTR  2.198079
# 19   TMUS  2.044718
# 16   NWSA  1.950593

# %% [markdown]
# ## Top Staples

# %%
staple.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 10     EL  4.850015
# 9    COST  3.904326
# 3     CHD  2.302912
# 30    WMT  2.189100
# 25     PG  2.105584
# 27    HSY  2.069291
# 22   MNST  2.022815
# 23    PEP  1.868988
# 18     LW  1.661314
# 4     CLX  1.647645

# %% [markdown]
# ## Top Discretionary

# %%
discretion.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker    CUM_RET
# 17   ETSY  18.495894
# 43   POOL   5.587690
# 7     CZR   5.561250
# 52   TSLA   5.285195
# 10    CMG   4.500627
# 1    AMZN   4.418258
# 11    DHI   3.989342
# 32    LOW   3.836499
# 51    TGT   3.567896
# 40    NVR   3.563927

# %% [markdown]
# ## Top Utilities

# %%
utility.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 20    NRG  3.344245
# 4     AWK  2.610672
# 0     AES  2.447139
# 2     AEE  1.951904
# 27    XEL  1.902183
# 26    WEC  1.879371
# 15     ES  1.864813
# 16    EXC  1.853503
# 1     LNT  1.839575
# 13    ETR  1.829929

# %% [markdown]
# ## Top Finance

# %%
finance.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 39   MSCI  8.216773
# 49   SPGI  4.377400
# 37    MCO  4.265219
# 51   SIVB  4.240737
# 6     AJG  3.696233
# 40   NDAQ  3.277685
# 45    PGR  3.157559
# 53   TROW  2.999332
# 4     AMP  2.910101
# 38     MS  2.774116

# %% [markdown]
# ## Top Materials

# %%
material.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 2     AVY  3.200383
# 1     ALB  3.093036
# 14    LIN  2.973870
# 11    FCX  2.594122
# 3     BLL  2.557432
# 5      CF  2.458485
# 10    FMC  2.295981
# 0     APD  2.235855
# 4      CE  2.148049
# 16    MLM  2.048859

# %% [markdown]
# ## Top Real Estate

# %%
restate.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 21   SBAC  3.659762
# 17    PLD  3.442297
# 11    EXR  3.331300
# 4    CBRE  3.205564
# 1     AMT  2.894263
# 7     DRE  2.720885
# 16    MAA  2.698131
# 5     CCI  2.652901
# 8    EQIX  2.448353
# 0     ARE  2.220472

# %% [markdown]
# ## Top Energy

# %%
energy.sort_values(by=['CUM_RET'], ascending=False).head(10)
# Out:
#    Ticker   CUM_RET
# 2     COP  1.632314
# 11    MPC  1.565467
# 14    OKE  1.515579
# 8     HES  1.382084
# 18    VLO  1.336799
# 1     CVX  1.262320
# 19    WMB  1.198860
# 4    FANG  1.131944
# 16    PXD  1.049206
# 3     DVN  1.035698
