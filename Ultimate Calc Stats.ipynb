# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "/Users/oppoudel/dev/Python4Finance/Stocks_DW/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Dataframe from CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Get all Stocks Downloaded in List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers
# tickers.remove('.ds_Store') MacOS Only
tickers.sort()
len(tickers)
# Out:
# 2907

# %% [markdown]
# ## Add Daily Returns

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df):
    df['daily_return'] = (df['Adj Close'] / df['Adj Close'].shift(1)) - 1
    # Save data to a CSV file
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Cumulative Returns

# %%
def add_cum_return_to_df(df):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Bollinger Bands

# %% [markdown]
# Bollinger Bands plot 2 lines using a moving average and the standard deviation defines how far apart the lines are. They also are used to define if prices are to high or low. When bands tighten it is believed a sharp price move in some direction. Prices tend to bounce off of the bands which provides potential market actions.
#
# A strong trend should be noted if the price moves outside the band. If prices go over the resistance line it is in overbought territory and if it breaks through support it is a sign of an oversold position.

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96 std),
# and lower band (20 days - 1.96 std)
def add_bollinger_bands(df):
    df['middle_band'] = df['Adj Close'].rolling(window=20).mean()
    df['upper_band'] = df['middle_band'] + 1.96 * df['Adj Close'].rolling(window=20).std()
    df['lower_band'] = df['middle_band'] - 1.96 * df['Adj Close'].rolling(window=20).std()
    #df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Ichimoku Data to Dataframe

# %% [markdown]
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
#  - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
#  - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
#  - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
#  - Leading Span B (Senkou B) : Other line used to identify suture support and resistance
#  - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
#  - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
#  - Lagging Span = Price shifted back 26 periods
#  - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
#  - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
#  - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
#  - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %%
def add_Ichimoku(df):
    # Conversion
    hi_val = df['High'].rolling(window=9).max()
    low_val = df['Low'].rolling(window=9).min()
    df['Conversion'] = (hi_val + low_val) / 2

    # Baseline
    hi_val2 = df['High'].rolling(window=26).max()
    low_val2 = df['Low'].rolling(window=26).min()
    df['Baseline'] = (hi_val2 + low_val2) / 2

    # Spans
    df['SpanA'] = ((df['Conversion'] + df['Baseline']) / 2).shift(26)
    hi_val3 = df['High'].rolling(window=52).max()
    low_val3 = df['Low'].rolling(window=52).min()
    df['SpanB'] = ((hi_val3 + low_val3) / 2).shift(26)
    df['Lagging'] = df['Close'].shift(-26)

    return df

# %% [markdown]
# ## Add Daily, Cumulative Bollinger Bands & Ichimoku to Dataframes

# %%
for x in tickers:
    try:
        print("Working on :", x)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df)
        new_df = add_cum_return_to_df(new_df)
        new_df = add_bollinger_bands(new_df)
        new_df = add_Ichimoku(new_df)
        new_df.to_csv(PATH + x + '.csv')
    except Exception as ex:
        print(ex)
# Out:
# Working on : A
# File Doesn't Exist
# 'NoneType' object is not subscriptable
# Working on : AA
# 'High'
# Working on : AAL
# 'High'
# Working on : AAME
# 'High'
# Working on : AAOI
# 'High'
# Working on : AAON
# 'High'
# Working on : AAP
# 'High'
# Working on : AAPL
# 'High'
# Working on : AAT
# 'High'
# Working on : AAWW
# 'High'
# Working on : ABBV
# 'High'
# Working on : ABC
# 'High'
# Working on : ABCB
# 'High'
# Working on : ABEO
# 'High'
# Working on : ABG
# 'High'
# Working on : ABIO
# 'High'
# Working on : ABM
# 'High'
# Working on : ABMD
# 'High'
# Working on : ABR
# 'High'
# Working on : ABT
# 'High'
# Working on : ABTX
# 'High'
# Working on : AC
# 'High'
# Working on : ACAD
# 'High'
# Working on : ACBI
# 'High'
# Working on : ACC
# 'High'
# Working on : ACCO
# 'High'
# Working on : ACER
# 'High'
# Working on : ACGL
# 'High'
# Working on : ACHC
# 'High'
# Working on : ACHV
# 'High'
# Working on : ACIW
# 'High'
# Working on : ACLS
# 'High'
# Working on : ACM
# 'High'
# Working on : ACMR
# 'High'
# Working on : ACN
# 'High'
# Working on : ACNB
# 'High'
# Working on : ACOR
# 'High'
# Working on : ACRE
# 'High'
# Working on : ACRS
# 'High'
# Working on : ACRX
# 'High'
# Working on : ACTG
# 'High'
# Working on : ACU
# 'High'
# Working on : ACY
# 'High'
# Working on : ADBE
# 'High'
# Working on : ADC
# 'High'
# Working on : ADES
# 'High'
# Working on : ADI
# 'High'
# Working on : ADM
# 'High'
# Working on : ADMA
# 'High'
# Working on : ADMP
# 'High'
# Working on : ADMS
# 'High'
# Working on : ADNT
# 'High'
# Working on : ADP
# 'High'
# Working on : ADS
# 'High'
# Working on : ADSK
# 'High'
# Working on : ADTN
# 'High'
# Working on : ADUS
# 'High'
# Working on : ADVM
# 'High'
# Working on : ADXS
# 'High'
# Working on : AE
# 'High'
# Working on : AEE
# 'High'
# Working on : AEHR
# 'High'
# Working on : AEIS
# 'High'
# Working on : AEL
# 'High'
# Working on : AEMD
# 'High'
# Working on : AEO
# 'High'
# Working on : AEP
# 'High'
# Working on : AERI
# 'High'
# Working on : AES
# 'High'
# Working on : AEY
# 'High'
# Working on : AFG
# 'High'
# Working on : AFI
# 'High'
# Working on : AFL
# 'High'
# Working on : AGCO
# 'High'
# Working on : AGEN
# 'High'
# Working on : AGFS
# 'High'
# Working on : AGIO
# 'High'
# Working on : AGLE
# 'High'
# Working on : AGM
# 'High'
# Working on : AGNC
# 'High'
# Working on : AGO
# 'High'
# Working on : AGR
# 'High'
# Working on : AGRX
# 'High'
# Working on : AGTC
# 'High'
# Working on : AGX
# 'High'
# Working on : AGYS
# 'High'
# Working on : AHH
# 'High'
# Working on : AHT
# 'High'
# Working on : AIG
# 'High'
# Working on : AIMC
# 'High'
# Working on : AIN
# 'High'
# Working on : AINC
# 'High'
# Working on : AIR
# 'High'
# Working on : AIRG
# 'High'
# Working on : AIRI
# 'High'
# Working on : AIRT
# 'High'
# Working on : AIT
# 'High'
# Working on : AIV
# 'High'
# Working on : AIZ
# 'High'
# Working on : AJG
# 'High'
# Working on : AJRD
# 'High'
# Working on : AJX
# 'High'
# Working on : AKAM
# 'High'
# Working on : AKBA
# 'High'
# Working on : AKR
# 'High'
# Working on : AKTS
# 'High'
# Working on : AL
# 'High'
# Working on : ALB
# 'High'
# Working on : ALBO
# 'High'
# Working on : ALCO
# 'High'
# Working on : ALDX
# 'High'
# Working on : ALE
# 'High'
# Working on : ALEX
# 'High'
# Working on : ALG
# 'High'
# Working on : ALGN
# 'High'
# Working on : ALGT
# 'High'
# Working on : ALJJ
# 'High'
# Working on : ALK
# 'High'
# Working on : ALKS
# 'High'
# Working on : ALL
# 'High'
# Working on : ALLE
# 'High'
# Working on : ALLY
# 'High'
# Working on : ALNA
# 'High'
# Working on : ALNY
# 'High'
# Working on : ALOT
# 'High'
# Working on : ALPN
# 'High'
# Working on : ALRM
# 'High'
# Working on : ALSN
# 'High'
# Working on : ALT
# 'High'
# Working on : ALTR
# 'High'
# Working on : ALV
# 'High'
# Working on : ALX
# 'High'
# Working on : ALXN
# 'High'
# Working on : AM
# 'High'
# Working on : AMAT
# 'High'
# Working on : AMBC
# 'High'
# Working on : AMC
# 'High'
# Working on : AMCX
# 'High'
# Working on : AMD
# 'High'
# Working on : AME
# 'High'
# Working on : AMED
# 'High'
# Working on : AMG
# 'High'
# Working on : AMGN
# 'High'
# Working on : AMH
# 'High'
# Working on : AMKR
# 'High'
# Working on : AMN
# 'High'
# Working on : AMNB
# 'High'
# Working on : AMOT
# 'High'
# Working on : AMP
# 'High'
# Working on : AMPE
# 'High'
# Working on : AMPH
# 'High'
# Working on : AMRC
# 'High'
# Working on : AMRK
# 'High'
# Working on : AMRS
# 'High'
# Working on : AMS
# 'High'
# Working on : AMSC
# 'High'
# Working on : AMSF
# 'High'
# Working on : AMSWA
# 'High'
# Working on : AMT
# 'High'
# Working on : AMTX
# 'High'
# Working on : AMWD
# 'High'
# Working on : AMZN
# 'High'
# Working on : AN
# 'High'
# Working on : ANAB
# 'High'
# Working on : ANAT
# 'High'
# Working on : ANDE
# 'High'
# Working on : ANET
# 'High'
# Working on : ANF
# 'High'
# Working on : ANGI
# 'High'
# Working on : ANGO
# 'High'
# Working on : ANIK
# 'High'
# Working on : ANIP
# 'High'
# Working on : ANIX
# 'High'
# Working on : ANSS
# 'High'
# Working on : ANTM
# 'High'
# Working on : AON
# 'High'
# Working on : AOS
# 'High'
# Working on : AOSL
# 'High'
# Working on : AP
# 'High'
# Working on : APA
# 'High'
# Working on : APAM
# 'High'
# Working on : APD
# 'High'
# Working on : APDN
# 'High'
# Working on : APEI
# 'High'
# Working on : APEN
# 'High'
# Working on : APH
# 'High'
# Working on : APLE
# 'High'
# Working on : APLS
# 'High'
# Working on : APOG
# 'High'
# Working on : APPF
# 'High'
# Working on : APPN
# 'High'
# Working on : APPS
# 'High'
# Working on : APRN
# 'High'
# Working on : APT
# 'High'
# Working on : APTS
# 'High'
# Working on : APTV
# 'High'
# Working on : APVO
# 'High'
# Working on : AQB
# 'High'
# Working on : AQMS
# 'High'
# Working on : AQUA
# 'High'
# Working on : AR
# 'High'
# Working on : ARAV
# 'High'
# Working on : ARAY
# 'High'
# Working on : ARC
# 'High'
# Working on : ARCB
# 'High'
# Working on : ARCH
# 'High'
# Working on : ARDX
# 'High'
# Working on : ARE
# 'High'
# Working on : ARES
# 'High'
# Working on : ARGO
# 'High'
# Working on : ARI
# 'High'
# Working on : ARKR
# 'High'
# Working on : ARL
# 'High'
# Working on : ARMK
# 'High'
# Working on : ARNA
# 'High'
# Working on : AROC
# 'High'
# Working on : AROW
# 'High'
# Working on : ARR
# 'High'
# Working on : ARTNA
# 'High'
# Working on : ARTW
# 'High'
# Working on : ARW
# 'High'
# Working on : ARWR
# 'High'
# Working on : ASB
# 'High'
# Working on : ASGN
# 'High'
# Working on : ASH
# 'High'
# Working on : ASIX
# 'High'
# Working on : ASMB
# 'High'
# Working on : ASPN
# 'High'
# Working on : ASPS
# 'High'
# Working on : ASRT
# 'High'
# Working on : ASRV
# 'High'
# Working on : ASTC
# 'High'
# Working on : ASTE
# 'High'
# Working on : ASUR
# 'High'
# Working on : ASYS
# 'High'
# Working on : ATEC
# 'High'
# Working on : ATEN
# 'High'
# Working on : ATGE
# 'High'
# Working on : ATH
# 'High'
# Working on : ATHX
# 'High'
# Working on : ATI
# 'High'
# Working on : ATKR
# 'High'
# Working on : ATLC
# 'High'
# Working on : ATLO
# 'High'
# Working on : ATNI
# 'High'
# Working on : ATNM
# 'High'
# Working on : ATNX
# 'High'
# Working on : ATO
# 'High'
# Working on : ATOS
# 'High'
# Working on : ATR
# 'High'
# Working on : ATRA
# 'High'
# Working on : ATRC
# 'High'
# Working on : ATRI
# 'High'
# Working on : ATRO
# 'High'
# Working on : ATRS
# 'High'
# Working on : ATSG
# 'High'
# Working on : ATUS
# 'High'
# Working on : ATVI
# 'High'
# Working on : AUBN
# 'High'
# Working on : AUMN
# 'High'
# Working on : AUTO
# 'High'
# Working on : AVA
# 'High'
# Working on : AVAV
# 'High'
# Working on : AVB
# 'High'
# Working on : AVD
# 'High'
# Working on : AVEO
# 'High'
# Working on : AVGO
# 'High'
# Working on : AVGR
# 'High'
# Working on : AVID
# 'High'
# Working on : AVNS
# 'High'
# Working on : AVNW
# 'High'
# Working on : AVT
# 'High'
# Working on : AVXL
# 'High'
# Working on : AVY
# 'High'
# Working on : AVYA
# 'High'
# Working on : AWI
# 'High'
# Working on : AWK
# 'High'
# Working on : AWR
# 'High'
# Working on : AWRE
# 'High'
# Working on : AX
# 'High'
# Working on : AXAS
# 'High'
# Working on : AXDX
# 'High'
# Working on : AXGN
# 'High'
# Working on : AXL
# 'High'
# Working on : AXP
# 'High'
# Working on : AXR
# 'High'
# Working on : AXS
# 'High'
# Working on : AXSM
# 'High'
# Working on : AXTA
# 'High'
# Working on : AXTI
# 'High'
# Working on : AYI
# 'High'
# Working on : AYX
# 'High'
# Working on : AZO
# 'High'
# Working on : AZPN
# 'High'
# Working on : AZZ
# 'High'
# Working on : B
# 'High'
# Working on : BA
# 'High'
# Working on : BAC
# 'High'
# Working on : BAH
# 'High'
# Working on : BANC
# 'High'
# Working on : BAND
# 'High'
# Working on : BANF
# 'High'
# Working on : BANR
# 'High'
# Working on : BATRA
# 'High'
# Working on : BATRK
# 'High'
# Working on : BAX
# 'High'
# Working on : BBBY
# 'High'
# Working on : BBCP
# 'High'
# Working on : BBGI
# 'High'
# Working on : BBSI
# 'High'
# Working on : BBW
# 'High'
# Working on : BBY
# 'High'
# Working on : BC
# 'High'
# Working on : BCBP
# 'High'
# Working on : BCC
# 'High'
# Working on : BCEI
# 'High'
# Working on : BCLI
# 'High'
# Working on : BCO
# 'High'
# Working on : BCOR
# 'High'
# Working on : BCOV
# 'High'
# Working on : BCPC
# 'High'
# Working on : BCRX
# 'High'
# Working on : BDC
# 'High'
# Working on : BDL
# 'High'
# Working on : BDN
# 'High'
# Working on : BDSI
# 'High'
# Working on : BDX
# 'High'
# Working on : BECN
# 'High'
# Working on : BELFA
# 'High'
# Working on : BELFB
# 'High'
# Working on : BEN
# 'High'
# Working on : BERY
# 'High'
# Working on : BFAM
# 'High'
# Working on : BFIN
# 'High'
# Working on : BFS
# 'High'
# Working on : BG
# 'High'
# Working on : BGCP
# 'High'
# Working on : BGFV
# 'High'
# Working on : BGS
# 'High'
# Working on : BGSF
# 'High'
# Working on : BH
# 'High'
# Working on : BHB
# 'High'
# Working on : BHE
# 'High'
# Working on : BHF
# 'High'
# Working on : BHLB
# 'High'
# Working on : BHR
# 'High'
# Working on : BHVN
# 'High'
# Working on : BIG
# 'High'
# Working on : BIIB
# 'High'
# Working on : BIO
# 'High'
# Working on : BIOC
# 'High'
# Working on : BIOL
# 'High'
# Working on : BJRI
# 'High'
# Working on : BK
# 'High'
# Working on : BKD
# 'High'
# Working on : BKE
# 'High'
# Working on : BKH
# 'High'
# Working on : BKI
# 'High'
# Working on : BKNG
# 'High'
# Working on : BKSC
# 'High'
# Working on : BKTI
# 'High'
# Working on : BKU
# 'High'
# Working on : BL
# 'High'
# Working on : BLBD
# 'High'
# Working on : BLCM
# 'High'
# Working on : BLD
# 'High'
# Working on : BLDR
# 'High'
# Working on : BLFS
# 'High'
# Working on : BLK
# 'High'
# Working on : BLKB
# 'High'
# Working on : BLL
# 'High'
# Working on : BLMN
# 'High'
# Working on : BLUE
# 'High'
# Working on : BMI
# 'High'
# Working on : BMRC
# 'High'
# Working on : BMRN
# 'High'
# Working on : BMTC
# 'High'
# Working on : BMY
# 'High'
# Working on : BNED
# 'High'
# Working on : BNFT
# 'High'
# Working on : BOCH
# 'High'
# Working on : BOH
# 'High'
# Working on : BOKF
# 'High'
# Working on : BOMN
# 'High'
# Working on : BOOM
# 'High'
# Working on : BOOT
# 'High'
# Working on : BOTJ
# 'High'
# Working on : BOX
# 'High'
# Working on : BPFH
# 'High'
# Working on : BPMC
# 'High'
# Working on : BPOP
# 'High'
# Working on : BPRN
# 'High'
# Working on : BPTH
# 'High'
# Working on : BR
# 'High'
# Working on : BRC
# 'High'
# Working on : BRG
# 'High'
# Working on : BRID
# 'High'
# Working on : BRKL
# 'High'
# Working on : BRKR
# 'High'
# Working on : BRKS
# 'High'
# Working on : BRN
# 'High'
# Working on : BRO
# 'High'
# Working on : BRT
# 'High'
# Working on : BRX
# 'High'
# Working on : BSET
# 'High'
# Working on : BSGM
# 'High'
# Working on : BSQR
# 'High'
# Working on : BSRR
# 'High'
# Working on : BSX
# 'High'
# Working on : BTN
# 'High'
# Working on : BTU
# 'High'
# Working on : BURL
# 'High'
# Working on : BUSE
# 'High'
# Working on : BW
# 'High'
# Working on : BWA
# 'High'
# Working on : BWEN
# 'High'
# Working on : BWFG
# 'High'
# Working on : BWXT
# 'High'
# Working on : BXC
# 'High'
# Working on : BXMT
# 'High'
# Working on : BXP
# 'High'
# Working on : BXS
# 'High'
# Working on : BY
# 'High'
# Working on : BYD
# 'High'
# Working on : BYFC
# 'High'
# Working on : BZH
# 'High'
# Working on : C
# 'High'
# Working on : CABO
# 'High'
# Working on : CAC
# 'High'
# Working on : CACC
# 'High'
# Working on : CACI
# 'High'
# Working on : CADE
# 'High'
# Working on : CAG
# 'High'
# Working on : CAH
# 'High'
# Working on : CAI
# 'High'
# Working on : CAKE
# 'High'
# Working on : CAL
# 'High'
# Working on : CALA
# 'High'
# Working on : CALM
# 'High'
# Working on : CALX
# 'High'
# Working on : CAMP
# 'High'
# Working on : CAPR
# 'High'
# Working on : CAR
# 'High'
# Working on : CARA
# 'High'
# Working on : CARG
# 'High'
# Working on : CARS
# 'High'
# Working on : CASA
# 'High'
# Working on : CASH
# 'High'
# Working on : CASI
# 'High'
# Working on : CASS
# 'High'
# Working on : CASY
# 'High'
# Working on : CAT
# 'High'
# Working on : CATB
# 'High'
# Working on : CATC
# 'High'
# Working on : CATO
# 'High'
# Working on : CATY
# 'High'
# Working on : CB
# 'High'
# Working on : CBAN
# 'High'
# Working on : CBAY
# 'High'
# Working on : CBB
# 'High'
# Working on : CBFV
# 'High'
# Working on : CBIO
# 'High'
# Working on : CBLI
# 'High'
# Working on : CBOE
# 'High'
# Working on : CBRE
# 'High'
# Working on : CBRL
# 'High'
# Working on : CBSH
# 'High'
# Working on : CBT
# 'High'
# Working on : CBTX
# 'High'
# Working on : CBU
# 'High'
# Working on : CBZ
# 'High'
# Working on : CC
# 'High'
# Working on : CCBG
# 'High'
# Working on : CCF
# 'High'
# Working on : CCI
# 'High'
# Working on : CCK
# 'High'
# Working on : CCL
# 'High'
# Working on : CCMP
# 'High'
# Working on : CCNE
# 'High'
# Working on : CCO
# 'High'
# Working on : CCOI
# 'High'
# Working on : CCRN
# 'High'
# Working on : CCS
# 'High'
# Working on : CCXI
# 'High'
# Working on : CDE
# 'High'
# Working on : CDEV
# 'High'
# Working on : CDK
# 'High'
# Working on : CDMO
# 'High'
# Working on : CDNA
# 'High'
# Working on : CDNS
# 'High'
# Working on : CDR
# 'High'
# Working on : CDTX
# 'High'
# Working on : CDW
# 'High'
# Working on : CDXC
# 'High'
# Working on : CDXS
# 'High'
# Working on : CDZI
# 'High'
# Working on : CE
# 'High'
# Working on : CECE
# 'High'
# Working on : CEI
# 'High'
# Working on : CEIX
# 'High'
# Working on : CELC
# 'High'
# Working on : CELH
# 'High'
# Working on : CEMI
# 'High'
# Working on : CENT
# 'High'
# Working on : CENTA
# 'High'
# Working on : CENX
# 'High'
# Working on : CERC
# 'High'
# Working on : CERN
# 'High'
# Working on : CERS
# 'High'
# Working on : CETX
# 'High'
# Working on : CEVA
# 'High'
# Working on : CF
# 'High'
# Working on : CFBK
# 'High'
# Working on : CFFI
# 'High'
# Working on : CFFN
# 'High'
# Working on : CFG
# 'High'
# Working on : CFMS
# 'High'
# Working on : CFR
# 'High'
# Working on : CFX
# 'High'
# Working on : CGNX
# 'High'
# Working on : CHCI
# 'High'
# Working on : CHCO
# 'High'
# Working on : CHCT
# 'High'
# Working on : CHD
# 'High'
# Working on : CHDN
# 'High'
# Working on : CHE
# 'High'
# Working on : CHEF
# 'High'
# Working on : CHGG
# 'High'
# Working on : CHH
# 'High'
# Working on : CHMA
# 'High'
# Working on : CHMG
# 'High'
# Working on : CHMI
# 'High'
# Working on : CHRS
# 'High'
# Working on : CHRW
# 'High'
# Working on : CHS
# 'High'
# Working on : CHTR
# 'High'
# Working on : CHUY
# 'High'
# Working on : CI
# 'High'
# Working on : CIA
# 'High'
# Working on : CIDM
# 'High'
# Working on : CIEN
# 'High'
# Working on : CIM
# 'High'
# Working on : CINF
# 'High'
# Working on : CIO
# 'High'
# Working on : CIR
# 'High'
# Working on : CIT
# 'High'
# Working on : CIVB
# 'High'
# Working on : CIX
# 'High'
# Working on : CIZN
# 'High'
# Working on : CKX
# 'High'
# Working on : CL
# 'High'
# Working on : CLAR
# 'High'
# Working on : CLB
# 'High'
# Working on : CLBS
# 'High'
# Working on : CLDR
# 'High'
# Working on : CLDT
# 'High'
# Working on : CLDX
# 'High'
# Working on : CLF
# 'High'
# Working on : CLFD
# 'High'
# Working on : CLH
# 'High'
# Working on : CLI
# 'High'
# Working on : CLIR
# 'High'
# Working on : CLNE
# 'High'
# Working on : CLPR
# 'High'
# Working on : CLR
# 'High'
# Working on : CLRB
# 'High'
# Working on : CLRO
# 'High'
# Working on : CLSN
# 'High'
# Working on : CLVS
# 'High'
# Working on : CLW
# 'High'
# Working on : CLX
# 'High'
# Working on : CLXT
# 'High'
# Working on : CMA
# 'High'
# Working on : CMC
# 'High'
# Working on : CMCO
# 'High'
# Working on : CMCSA
# 'High'
# Working on : CMCT
# 'High'
# Working on : CME
# 'High'
# Working on : CMG
# 'High'
# Working on : CMI
# 'High'
# Working on : CMO
# 'High'
# Working on : CMP
# 'High'
# Working on : CMRX
# 'High'
# Working on : CMS
# 'High'
# Working on : CMT
# 'High'
# Working on : CMTL
# 'High'
# Working on : CNA
# 'High'
# Working on : CNBKA
# 'High'
# Working on : CNC
# 'High'
# Working on : CNCE
# 'High'
# Working on : CNDT
# 'High'
# Working on : CNFR
# 'High'
# Working on : CNK
# 'High'
# Working on : CNMD
# 'High'
# Working on : CNNE
# 'High'
# Working on : CNO
# 'High'
# Working on : CNOB
# 'High'
# Working on : CNP
# 'High'
# Working on : CNS
# 'High'
# Working on : CNSL
# 'High'
# Working on : CNTY
# 'High'
# Working on : CNX
# 'High'
# Working on : CNXN
# 'High'
# Working on : CODA
# 'High'
# Working on : COF
# 'High'
# Working on : COG
# 'High'
# Working on : COHN
# 'High'
# Working on : COHR
# 'High'
# Working on : COHU
# 'High'
# Working on : COKE
# 'High'
# Working on : COLB
# 'High'
# Working on : COLL
# 'High'
# Working on : COLM
# 'High'
# Working on : COMM
# 'High'
# Working on : CONE
# 'High'
# Working on : CONN
# 'High'
# Working on : COO
# 'High'
# Working on : COOP
# 'High'
# Working on : COP
# 'High'
# Working on : COR
# 'High'
# Working on : CORE
# 'High'
# Working on : CORR
# 'High'
# Working on : CORT
# 'High'
# Working on : COST
# 'High'
# Working on : COTY
# 'High'
# Working on : COUP
# 'High'
# Working on : COWN
# 'High'
# Working on : CPB
# 'High'
# Working on : CPE
# 'High'
# Working on : CPF
# 'High'
# Working on : CPHC
# 'High'
# Working on : CPIX
# 'High'
# Working on : CPK
# 'High'
# Working on : CPRI
# 'High'
# Working on : CPRT
# 'High'
# Working on : CPRX
# 'High'
# Working on : CPS
# 'High'
# Working on : CPSH
# 'High'
# Working on : CPSI
# 'High'
# Working on : CPSS
# 'High'
# Working on : CPT
# 'High'
# Working on : CR
# 'High'
# Working on : CRAI
# 'High'
# Working on : CRBP
# 'High'
# Working on : CREE
# 'High'
# Working on : CRI
# 'High'
# Working on : CRIS
# 'High'
# Working on : CRK
# 'High'
# Working on : CRL
# 'High'
# Working on : CRM
# 'High'
# Working on : CRMD
# 'High'
# Working on : CRMT
# 'High'
# Working on : CROX
# 'High'
# Working on : CRS
# 'High'
# Working on : CRUS
# 'High'
# Working on : CRVL
# 'High'
# Working on : CRVS
# 'High'
# Working on : CRWS
# 'High'
# Working on : CRY
# 'High'
# Working on : CSCO
# 'High'
# Working on : CSGP
# 'High'
# Working on : CSGS
# 'High'
# Working on : CSII
# 'High'
# Working on : CSL
# 'High'
# Working on : CSLT
# 'High'
# Working on : CSOD
# 'High'
# Working on : CSPI
# 'High'
# Working on : CSTR
# 'High'
# Working on : CSU
# 'High'
# Working on : CSV
# 'High'
# Working on : CSWI
# 'High'
# Working on : CSX
# 'High'
# Working on : CTAS
# 'High'
# Working on : CTBI
# 'High'
# Working on : CTG
# 'High'
# Working on : CTHR
# 'High'
# Working on : CTIB
# 'High'
# Working on : CTIC
# 'High'
# Working on : CTLT
# 'High'
# Working on : CTMX
# 'High'
# Working on : CTO
# 'High'
# Working on : CTRE
# 'High'
# Working on : CTRN
# 'High'
# Working on : CTS
# 'High'
# Working on : CTSH
# 'High'
# Working on : CTSO
# 'High'
# Working on : CTT
# 'High'
# Working on : CTXS
# 'High'
# Working on : CUBE
# 'High'
# Working on : CUBI
# 'High'
# Working on : CULP
# 'High'
# Working on : CURO
# 'High'
# Working on : CUTR
# 'High'
# Working on : CUZ
# 'High'
# Working on : CVA
# 'High'
# Working on : CVBF
# 'High'
# Working on : CVCO
# 'High'
# Working on : CVCY
# 'High'
# Working on : CVGI
# 'High'
# Working on : CVGW
# 'High'
# Working on : CVI
# 'High'
# Working on : CVLT
# 'High'
# Working on : CVLY
# 'High'
# Working on : CVM
# 'High'
# Working on : CVNA
# 'High'
# Working on : CVR
# 'High'
# Working on : CVS
# 'High'
# Working on : CVU
# 'High'
# Working on : CVV
# 'High'
# Working on : CVX
# 'High'
# Working on : CW
# 'High'
# Working on : CWBC
# 'High'
# Working on : CWBR
# 'High'
# Working on : CWEN
# 'High'
# Working on : CWH
# 'High'
# Working on : CWST
# 'High'
# Working on : CWT
# 'High'
# Working on : CXP
# 'High'
# Working on : CXW
# 'High'
# Working on : CYAN
# 'High'
# Working on : CYBE
# 'High'
# Working on : CYCC
# 'High'
# Working on : CYH
# 'High'
# Working on : CYRX
# 'High'
# Working on : CYTK
# 'High'
# Working on : CYTR
# 'High'
# Working on : CZNC
# 'High'
# Working on : CZR
# 'High'
# Working on : CZWI
# 'High'
# Working on : D
# 'High'
# Working on : DAIO
# 'High'
# Working on : DAKT
# 'High'
# Working on : DAL
# 'High'
# Working on : DAN
# 'High'
# Working on : DAR
# 'High'
# Working on : DARE
# 'High'
# Working on : DBD
# 'High'
# Working on : DBI
# 'High'
# Working on : DCI
# 'High'
# Working on : DCO
# 'High'
# Working on : DCOM
# 'High'
# Working on : DCPH
# 'High'
# Working on : DD
# 'High'
# Working on : DDD
# 'High'
# Working on : DDS
# 'High'
# Working on : DE
# 'High'
# Working on : DEA
# 'High'
# Working on : DECK
# 'High'
# Working on : DEI
# 'High'
# Working on : DELL
# 'High'
# Working on : DENN
# 'High'
# Working on : DFIN
# 'High'
# Working on : DFS
# 'High'
# Working on : DG
# 'High'
# Working on : DGICA
# 'High'
# Working on : DGII
# 'High'
# Working on : DGLY
# 'High'
# Working on : DGX
# 'High'
# Working on : DHI
# 'High'
# Working on : DHIL
# 'High'
# Working on : DHR
# 'High'
# Working on : DHX
# 'High'
# Working on : DIN
# 'High'
# Working on : DIOD
# 'High'
# Working on : DIS
# 'High'
# Working on : DISCA
# 'High'
# Working on : DISCK
# 'High'
# Working on : DISH
# 'High'
# Working on : DIT
# 'High'
# Working on : DJCO
# 'High'
# Working on : DK
# 'High'
# Working on : DKS
# 'High'
# Working on : DLA
# 'High'
# Working on : DLB
# 'High'
# Working on : DLHC
# 'High'
# Working on : DLR
# 'High'
# Working on : DLTH
# 'High'
# Working on : DLTR
# 'High'
# Working on : DLX
# 'High'
# Working on : DMRC
# 'High'
# Working on : DNLI
# 'High'
# Working on : DNOW
# 'High'
# Working on : DOC
# 'High'
# Working on : DOOR
# 'High'
# Working on : DORM
# 'High'
# Working on : DOV
# 'High'
# Working on : DPZ
# 'High'
# Working on : DRE
# 'High'
# Working on : DRH
# 'High'
# Working on : DRI
# 'High'
# Working on : DRNA
# 'High'
# Working on : DRQ
# 'High'
# Working on : DRRX
# 'High'
# Working on : DS
# 'High'
# Working on : DSKE
# 'High'
# Working on : DSPG
# 'High'
# Working on : DSS
# 'High'
# Working on : DTE
# 'High'
# Working on : DUK
# 'High'
# Working on : DVA
# 'High'
# Working on : DVAX
# 'High'
# Working on : DVD
# 'High'
# Working on : DVN
# 'High'
# Working on : DWSN
# 'High'
# Working on : DX
# 'High'
# Working on : DXC
# 'High'
# Working on : DXCM
# 'High'
# Working on : DXLG
# 'High'
# Working on : DXPE
# 'High'
# Working on : DXYN
# 'High'
# Working on : DY
# 'High'
# Working on : DZSI
# 'High'
# Working on : EA
# 'High'
# Working on : EARN
# 'High'
# Working on : EAT
# 'High'
# Working on : EBAY
# 'High'
# Working on : EBF
# 'High'
# Working on : EBIX
# 'High'
# Working on : EBMT
# 'High'
# Working on : EBS
# 'High'
# Working on : EBSB
# 'High'
# Working on : EBTC
# 'High'
# Working on : ECHO
# 'High'
# Working on : ECL
# 'High'
# Working on : ECOL
# 'High'
# Working on : ECOM
# 'High'
# Working on : ECPG
# 'High'
# Working on : ED
# 'High'
# Working on : EDIT
# 'High'
# Working on : EDUC
# 'High'
# Working on : EEFT
# 'High'
# Working on : EEX
# 'High'
# Working on : EFC
# 'High'
# Working on : EFOI
# 'High'
# Working on : EFSC
# 'High'
# Working on : EFX
# 'High'
# Working on : EGAN
# 'High'
# Working on : EGBN
# 'High'
# Working on : EGHT
# 'High'
# Working on : EGLE
# 'High'
# Working on : EGP
# 'High'
# Working on : EGRX
# 'High'
# Working on : EGY
# 'High'
# Working on : EHC
# 'High'
# Working on : EHTH
# 'High'
# Working on : EIG
# 'High'
# Working on : EIGR
# 'High'
# Working on : EIX
# 'High'
# Working on : EKSO
# 'High'
# Working on : EL
# 'High'
# Working on : ELF
# 'High'
# Working on : ELMD
# 'High'
# Working on : ELOX
# 'High'
# Working on : ELS
# 'High'
# Working on : ELSE
# 'High'
# Working on : ELVT
# 'High'
# Working on : ELY
# 'High'
# Working on : EMAN
# 'High'
# Working on : EMCF
# 'High'
# Working on : EME
# 'High'
# Working on : EMKR
# 'High'
# Working on : EML
# 'High'
# Working on : EMMS
# 'High'
# Working on : EMN
# 'High'
# Working on : EMR
# 'High'
# Working on : ENDP
# 'High'
# Working on : ENG
# 'High'
# Working on : ENPH
# 'High'
# Working on : ENR
# 'High'
# Working on : ENS
# 'High'
# Working on : ENSG
# 'High'
# Working on : ENSV
# 'High'
# Working on : ENTA
# 'High'
# Working on : ENTG
# 'High'
# Working on : ENV
# 'High'
# Working on : ENVA
# 'High'
# Working on : ENZ
# 'High'
# Working on : EOG
# 'High'
# Working on : EPAM
# 'High'
# Working on : EPAY
# 'High'
# Working on : EPC
# 'High'
# Working on : EPM
# 'High'
# Working on : EPR
# 'High'
# Working on : EPZM
# 'High'
# Working on : EQBK
# 'High'
# Working on : EQC
# 'High'
# Working on : EQIX
# 'High'
# Working on : EQR
# 'High'
# Working on : EQT
# 'High'
# Working on : ERIE
# 'High'
# Working on : ERII
# 'High'
# Working on : ES
# 'High'
# Working on : ESBK
# 'High'
# Working on : ESCA
# 'High'
# Working on : ESE
# 'High'
# Working on : ESGR
# 'High'
# Working on : ESNT
# 'High'
# Working on : ESP
# 'High'
# Working on : ESPR
# 'High'
# Working on : ESRT
# 'High'
# Working on : ESS
# 'High'
# Working on : ESSA
# 'High'
# Working on : ESTE
# 'High'
# Working on : ESXB
# 'High'
# Working on : ETH
# 'High'
# Working on : ETN
# 'High'
# Working on : ETR
# 'High'
# Working on : ETSY
# 'High'
# Working on : EVBG
# 'High'
# Working on : EVBN
# 'High'
# Working on : EVC
# 'High'
# Working on : EVFM
# 'High'
# Working on : EVH
# 'High'
# Working on : EVI
# 'High'
# Working on : EVOK
# 'High'
# Working on : EVOL
# 'High'
# Working on : EVR
# 'High'
# Working on : EVRG
# 'High'
# Working on : EVRI
# 'High'
# Working on : EVTC
# 'High'
# Working on : EW
# 'High'
# Working on : EWBC
# 'High'
# Working on : EXAS
# 'High'
# Working on : EXC
# 'High'
# Working on : EXEL
# 'High'
# Working on : EXLS
# 'High'
# Working on : EXP
# 'High'
# Working on : EXPD
# 'High'
# Working on : EXPE
# 'High'
# Working on : EXPO
# 'High'
# Working on : EXPR
# 'High'
# Working on : EXR
# 'High'
# Working on : EXTN
# 'High'
# Working on : EXTR
# 'High'
# Working on : EYE
# 'High'
# Working on : EYEG
# 'High'
# Working on : EYES
# 'High'
# Working on : EYPT
# 'High'
# Working on : EZPW
# 'High'
# Working on : F
# 'High'
# Working on : FAF
# 'High'
# Working on : FANG
# 'High'
# Working on : FARM
# 'High'
# Working on : FARO
# 'High'
# Working on : FAST
# 'High'
# Working on : FATE
# 'High'
# Working on : FB
# 'High'
# Working on : FBC
# 'High'
# Working on : FBHS
# 'High'
# Working on : FBIO
# 'High'
# Working on : FBIZ
# 'High'
# Working on : FBK
# 'High'
# Working on : FBMS
# 'High'
# Working on : FBNC
# 'High'
# Working on : FBP
# 'High'
# Working on : FC
# 'High'
# Working on : FCAP
# 'High'
# Working on : FCBC
# 'High'
# Working on : FCBP
# 'High'
# Working on : FCCO
# 'High'
# Working on : FCCY
# 'High'
# Working on : FCEL
# 'High'
# Working on : FCF
# 'High'
# Working on : FCFS
# 'High'
# Working on : FCN
# 'High'
# Working on : FCNCA
# 'High'
# Working on : FCPT
# 'High'
# Working on : FCX
# 'High'
# Working on : FDBC
# 'High'
# Working on : FDP
# 'High'
# Working on : FDS
# 'High'
# Working on : FDX
# 'High'
# Working on : FE
# 'High'
# Working on : FEIM
# 'High'
# Working on : FELE
# 'High'
# Working on : FET
# 'High'
# Working on : FEYE
# 'High'
# Working on : FF
# 'High'
# Working on : FFBC
# 'High'
# Working on : FFIC
# 'High'
# Working on : FFIN
# 'High'
# Working on : FFIV
# 'High'
# Working on : FFNW
# 'High'
# Working on : FFWM
# 'High'
# Working on : FGBI
# 'High'
# Working on : FGEN
# 'High'
# Working on : FHB
# 'High'
# Working on : FHN
# 'High'
# Working on : FI
# 'High'
# Working on : FIBK
# 'High'
# Working on : FICO
# 'High'
# Working on : FIS
# 'High'
# Working on : FISI
# 'High'
# Working on : FISV
# 'High'
# Working on : FITB
# 'High'
# Working on : FIVE
# 'High'
# Working on : FIVN
# 'High'
# Working on : FIX
# 'High'
# Working on : FIZZ
# 'High'
# Working on : FL
# 'High'
# Working on : FLDM
# 'High'
# Working on : FLIC
# 'High'
# Working on : FLL
# 'High'
# Working on : FLMN
# 'High'
# Working on : FLNT
# 'High'
# Working on : FLO
# 'High'
# Working on : FLOW
# 'High'
# Working on : FLR
# 'High'
# Working on : FLS
# 'High'
# Working on : FLT
# 'High'
# Working on : FLWS
# 'High'
# Working on : FLXN
# 'High'
# Working on : FLXS
# 'High'
# Working on : FMAO
# 'High'
# Working on : FMBH
# 'High'
# Working on : FMBI
# 'High'
# Working on : FMC
# 'High'
# Working on : FMNB
# 'High'
# Working on : FN
# 'High'
# Working on : FNB
# 'High'
# Working on : FNCB
# 'High'
# Working on : FND
# 'High'
# Working on : FNF
# 'High'
# Working on : FNHC
# 'High'
# Working on : FNKO
# 'High'
# Working on : FNLC
# 'High'
# Working on : FNWB
# 'High'
# Working on : FOE
# 'High'
# Working on : FOLD
# 'High'
# Working on : FONR
# 'High'
# Working on : FOR
# 'High'
# Working on : FORD
# 'High'
# Working on : FORM
# 'High'
# Working on : FORR
# 'High'
# Working on : FOSL
# 'High'
# Working on : FOXF
# 'High'
# Working on : FPI
# 'High'
# Working on : FR
# 'High'
# Working on : FRBA
# 'High'
# Working on : FRBK
# 'High'
# Working on : FRC
# 'High'
# Working on : FRD
# 'High'
# Working on : FRGI
# 'High'
# Working on : FRME
# 'High'
# Working on : FRPH
# 'High'
# Working on : FRPT
# 'High'
# Working on : FRT
# 'High'
# Working on : FRTA
# 'High'
# Working on : FSBW
# 'High'
# Working on : FSFG
# 'High'
# Working on : FSLR
# 'High'
# Working on : FSP
# 'High'
# Working on : FSS
# 'High'
# Working on : FSTR
# 'High'
# Working on : FTEK
# 'High'
# Working on : FTI
# 'High'
# Working on : FTK
# 'High'
# Working on : FTNT
# 'High'
# Working on : FTV
# 'High'
# Working on : FUL
# 'High'
# Working on : FULT
# 'High'
# Working on : FUNC
# 'High'
# Working on : FUSB
# 'High'
# Working on : FVE
# 'High'
# Working on : FWONA
# 'High'
# Working on : FWONK
# 'High'
# Working on : FWRD
# 'High'
# Working on : G
# 'High'
# Working on : GABC
# 'High'
# Working on : GAIA
# 'High'
# Working on : GALT
# 'High'
# Working on : GATX
# 'High'
# Working on : GBCI
# 'High'
# Working on : GBL
# 'High'
# Working on : GBLI
# 'High'
# Working on : GBT
# 'High'
# Working on : GBX
# 'High'
# Working on : GCBC
# 'High'
# Working on : GCI
# 'High'
# Working on : GCO
# 'High'
# Working on : GCP
# 'High'
# Working on : GD
# 'High'
# Working on : GDDY
# 'High'
# Working on : GDEN
# 'High'
# Working on : GDOT
# 'High'
# Working on : GDP
# 'High'
# Working on : GE
# 'High'
# Working on : GEF
# 'High'
# Working on : GENC
# 'High'
# Working on : GEO
# 'High'
# Working on : GEOS
# 'High'
# Working on : GERN
# 'High'
# Working on : GES
# 'High'
# Working on : GEVO
# 'High'
# Working on : GFED
# 'High'
# Working on : GFF
# 'High'
# Working on : GGG
# 'High'
# Working on : GHC
# 'High'
# Working on : GHL
# 'High'
# Working on : GHM
# 'High'
# Working on : GIFI
# 'High'
# Working on : GIII
# 'High'
# Working on : GILD
# 'High'
# Working on : GIS
# 'High'
# Working on : GKOS
# 'High'
# Working on : GLBZ
# 'High'
# Working on : GLDD
# 'High'
# Working on : GLPI
# 'High'
# Working on : GLRE
# 'High'
# Working on : GLT
# 'High'
# Working on : GLW
# 'High'
# Working on : GLYC
# 'High'
# Working on : GM
# 'High'
# Working on : GME
# 'High'
# Working on : GMED
# 'High'
# Working on : GMRE
# 'High'
# Working on : GMS
# 'High'
# Working on : GNCA
# 'High'
# Working on : GNE
# 'High'
# Working on : GNK
# 'High'
# Working on : GNL
# 'High'
# Working on : GNRC
# 'High'
# Working on : GNTX
# 'High'
# Working on : GNTY
# 'High'
# Working on : GNW
# 'High'
# Working on : GOGO
# 'High'
# Working on : GOLF
# 'High'
# Working on : GOOD
# 'High'
# Working on : GOOG
# 'High'
# Working on : GOOGL
# 'High'
# Working on : GORO
# 'High'
# Working on : GPC
# 'High'
# Working on : GPI
# 'High'
# Working on : GPK
# 'High'
# Working on : GPMT
# 'High'
# Working on : GPN
# 'High'
# Working on : GPRE
# 'High'
# Working on : GPRO
# 'High'
# Working on : GPS
# 'High'
# Working on : GPX
# 'High'
# Working on : GRA
# 'High'
# Working on : GRBK
# 'High'
# Working on : GRC
# 'High'
# Working on : GRMN
# 'High'
# Working on : GROW
# 'High'
# Working on : GRPN
# 'High'
# Working on : GS
# 'High'
# Working on : GSAT
# 'High'
# Working on : GSBC
# 'High'
# Working on : GSIT
# 'High'
# Working on : GT
# 'High'
# Working on : GTHX
# 'High'
# Working on : GTIM
# 'High'
# Working on : GTLS
# 'High'
# Working on : GTN
# 'High'
# Working on : GTS
# 'High'
# Working on : GTT
# 'High'
# Working on : GTY
# 'High'
# Working on : GTYH
# 'High'
# Working on : GVA
# 'High'
# Working on : GVP
# 'High'
# Working on : GWB
# 'High'
# Working on : GWGH
# 'High'
# Working on : GWRE
# 'High'
# Working on : GWRS
# 'High'
# Working on : GWW
# 'High'
# Working on : H
# 'High'
# Working on : HA
# 'High'
# Working on : HAE
# 'High'
# Working on : HAFC
# 'High'
# Working on : HAIN
# 'High'
# Working on : HAL
# 'High'
# Working on : HALL
# 'High'
# Working on : HALO
# 'High'
# Working on : HAS
# 'High'
# Working on : HASI
# 'High'
# Working on : HAYN
# 'High'
# Working on : HBAN
# 'High'
# Working on : HBB
# 'High'
# Working on : HBCP
# 'High'
# Working on : HBI
# 'High'
# Working on : HBIO
# 'High'
# Working on : HBMD
# 'High'
# Working on : HBNC
# 'High'
# Working on : HBP
# 'High'
# Working on : HCA
# 'High'
# Working on : HCC
# 'High'
# Working on : HCCI
# 'High'
# Working on : HCHC
# 'High'
# Working on : HCI
# 'High'
# Working on : HCKT
# 'High'
# Working on : HCSG
# 'High'
# Working on : HD
# 'High'
# Working on : HDSN
# 'High'
# Working on : HE
# 'High'
# Working on : HEAR
# 'High'
# Working on : HEES
# 'High'
# Working on : HEI
# 'High'
# Working on : HELE
# 'High'
# Working on : HES
# 'High'
# Working on : HFBL
# 'High'
# Working on : HFC
# 'High'
# Working on : HFWA
# 'High'
# Working on : HGV
# 'High'
# Working on : HHC
# 'High'
# Working on : HI
# 'High'
# Working on : HIBB
# 'High'
# Working on : HIFS
# 'High'
# Working on : HIG
# 'High'
# Working on : HII
# 'High'
# Working on : HIL
# 'High'
# Working on : HIW
# 'High'
# Working on : HL
# 'High'
# Working on : HLF
# 'High'
# Working on : HLI
# 'High'
# Working on : HLIT
# 'High'
# Working on : HLNE
# 'High'
# Working on : HLT
# 'High'
# Working on : HLX
# 'High'
# Working on : HMHC
# 'High'
# Working on : HMN
# 'High'
# Working on : HMNF
# 'High'
# Working on : HMST
# 'High'
# Working on : HMTV
# 'High'
# Working on : HNI
# 'High'
# Working on : HNRG
# 'High'
# Working on : HOFT
# 'High'
# Working on : HOG
# 'High'
# Working on : HOLX
# 'High'
# Working on : HOMB
# 'High'
# Working on : HOME
# 'High'
# Working on : HON
# 'High'
# Working on : HONE
# 'High'
# Working on : HOPE
# 'High'
# Working on : HOV
# 'High'
# Working on : HP
# 'High'
# Working on : HPE
# 'High'
# Working on : HPP
# 'High'
# Working on : HPQ
# 'High'
# Working on : HQY
# 'High'
# Working on : HR
# 'High'
# Working on : HRB
# 'High'
# Working on : HRC
# 'High'
# Working on : HRI
# 'High'
# Working on : HRL
# 'High'
# Working on : HROW
# 'High'
# Working on : HRTG
# 'High'
# Working on : HRTX
# 'High'
# Working on : HSC
# 'High'
# Working on : HSIC
# 'High'
# Working on : HSII
# 'High'
# Working on : HSKA
# 'High'
# Working on : HSON
# 'High'
# Working on : HST
# 'High'
# Working on : HSTM
# 'High'
# Working on : HSY
# 'High'
# Working on : HT
# 'High'
# Working on : HTA
# 'High'
# Working on : HTBI
# 'High'
# Working on : HTBK
# 'High'
# Working on : HTBX
# 'High'
# Working on : HTGM
# 'High'
# Working on : HTH
# 'High'
# Working on : HTLD
# 'High'
# Working on : HTLF
# 'High'
# Working on : HUBB
# 'High'
# Working on : HUBG
# 'High'
# Working on : HUBS
# 'High'
# Working on : HUM
# 'High'
# Working on : HUN
# 'High'
# Working on : HURC
# 'High'
# Working on : HURN
# 'High'
# Working on : HUSA
# 'High'
# Working on : HVT
# 'High'
# Working on : HWBK
# 'High'
# Working on : HWC
# 'High'
# Working on : HWKN
# 'High'
# Working on : HXL
# 'High'
# Working on : HY
# 'High'
# Working on : HZN
# 'High'
# Working on : HZNP
# 'High'
# Working on : HZO
# 'High'
# Working on : IAC
# 'High'
# Working on : IART
# 'High'
# Working on : IBCP
# 'High'
# Working on : IBIO
# 'High'
# Working on : IBKR
# 'High'
# Working on : IBM
# 'High'
# Working on : IBOC
# 'High'
# Working on : IBP
# 'High'
# Working on : IBTX
# 'High'
# Working on : ICAD
# 'High'
# Working on : ICBK
# 'High'
# Working on : ICCC
# 'High'
# Working on : ICD
# 'High'
# Working on : ICE
# 'High'
# Working on : ICFI
# 'High'
# Working on : ICHR
# 'High'
# Working on : ICON
# 'High'
# Working on : ICPT
# 'High'
# Working on : ICUI
# 'High'
# Working on : IDA
# 'High'
# Working on : IDCC
# 'High'
# Working on : IDN
# 'High'
# Working on : IDRA
# 'High'
# Working on : IDT
# 'High'
# Working on : IDXG
# 'High'
# Working on : IDXX
# 'High'
# Working on : IEC
# 'High'
# Working on : IESC
# 'High'
# Working on : IEX
# 'High'
# Working on : IFF
# 'High'
# Working on : IHC
# 'High'
# Working on : III
# 'High'
# Working on : IIIN
# 'High'
# Working on : IIN
# 'High'
# Working on : IIPR
# 'High'
# Working on : IIVI
# 'High'
# Working on : IKNX
# 'High'
# Working on : ILMN
# 'High'
# Working on : IMGN
# 'High'
# Working on : IMH
# 'High'
# Working on : IMKTA
# 'High'
# Working on : IMMR
# 'High'
# Working on : IMXI
# 'High'
# Working on : INBK
# 'High'
# Working on : INCY
# 'High'
# Working on : INDB
# 'High'
# Working on : INFI
# 'High'
# Working on : INFN
# 'High'
# Working on : INFO
# 'High'
# Working on : INFU
# 'High'
# Working on : INGN
# 'High'
# Working on : INGR
# 'High'
# Working on : INN
# 'High'
# Working on : INO
# 'High'
# Working on : INOD
# 'High'
# Working on : INOV
# 'High'
# Working on : INPX
# 'High'
# Working on : INS
# 'High'
# Working on : INSE
# 'High'
# Working on : INSG
# 'High'
# Working on : INSM
# 'High'
# Working on : INSW
# 'High'
# Working on : INT
# 'High'
# Working on : INTC
# 'High'
# Working on : INTG
# 'High'
# Working on : INTT
# 'High'
# Working on : INTU
# 'High'
# Working on : INUV
# 'High'
# Working on : INVA
# 'High'
# Working on : INVE
# 'High'
# Working on : INVH
# 'High'
# Working on : IO
# 'High'
# Working on : IONS
# 'High'
# Working on : IOR
# 'High'
# Working on : IOSP
# 'High'
# Working on : IOVA
# 'High'
# Working on : IP
# 'High'
# Working on : IPAR
# 'High'
# Working on : IPG
# 'High'
# Working on : IPGP
# 'High'
# Working on : IPI
# 'High'
# Working on : IPWR
# 'High'
# Working on : IQV
# 'High'
# Working on : IR
# 'High'
# Working on : IRBT
# 'High'
# Working on : IRDM
# 'High'
# Working on : IRIX
# 'High'
# Working on : IRM
# 'High'
# Working on : IRMD
# 'High'
# Working on : IROQ
# 'High'
# Working on : IRT
# 'High'
# Working on : IRTC
# 'High'
# Working on : IRWD
# 'High'
# Working on : ISBC
# 'High'
# Working on : ISDR
# 'High'
# Working on : ISIG
# 'High'
# Working on : ISNS
# 'High'
# Working on : ISR
# 'High'
# Working on : ISRG
# 'High'
# Working on : ISSC
# 'High'
# Working on : ISTR
# 'High'
# Working on : IT
# 'High'
# Working on : ITCI
# 'High'
# Working on : ITGR
# 'High'
# Working on : ITI
# 'High'
# Working on : ITIC
# 'High'
# Working on : ITRI
# 'High'
# Working on : ITT
# 'High'
# Working on : ITW
# 'High'
# Working on : IVAC
# 'High'
# Working on : IVC
# 'High'
# Working on : IVR
# 'High'
# Working on : IVZ
# 'High'
# Working on : IZEA
# 'High'
# Working on : JACK
# 'High'
# Working on : JAGX
# 'High'
# Working on : JAKK
# 'High'
# Working on : JAX
# 'High'
# Working on : JAZZ
# 'High'
# Working on : JBGS
# 'High'
# Working on : JBHT
# 'High'
# Working on : JBL
# 'High'
# Working on : JBLU
# 'High'
# Working on : JBSS
# 'High'
# Working on : JBT
# 'High'
# Working on : JCI
# 'High'
# Working on : JCOM
# 'High'
# Working on : JCS
# 'High'
# Working on : JCTCF
# 'High'
# Working on : JEF
# 'High'
# Working on : JELD
# 'High'
# Working on : JHG
# 'High'
# Working on : JILL
# 'High'
# Working on : JJSF
# 'High'
# Working on : JKHY
# 'High'
# Working on : JLL
# 'High'
# Working on : JNCE
# 'High'
# Working on : JNJ
# 'High'
# Working on : JNPR
# 'High'
# Working on : JOB
# 'High'
# Working on : JOE
# 'High'
# Working on : JOUT
# 'High'
# Working on : JPM
# 'High'
# Working on : JRVR
# 'High'
# Working on : JVA
# 'High'
# Working on : JWN
# 'High'
# Working on : JYNT
# 'High'
# Working on : K
# 'High'
# Working on : KAI
# 'High'
# Working on : KALA
# 'High'
# Working on : KALU
# 'High'
# Working on : KALV
# 'High'
# Working on : KAMN
# 'High'
# Working on : KAR
# 'High'
# Working on : KBAL
# 'High'
# Working on : KBH
# 'High'
# Working on : KBR
# 'High'
# Working on : KDMN
# 'High'
# Working on : KDP
# 'High'
# Working on : KE
# 'High'
# Working on : KELYA
# 'High'
# Working on : KEQU
# 'High'
# Working on : KEX
# 'High'
# Working on : KEY
# 'High'
# Working on : KEYS
# 'High'
# Working on : KFFB
# 'High'
# Working on : KFRC
# 'High'
# Working on : KFY
# 'High'
# Working on : KHC
# 'High'
# Working on : KIDS
# 'High'
# Working on : KIM
# 'High'
# Working on : KIN
# 'High'
# Working on : KINS
# 'High'
# Working on : KIRK
# 'High'
# Working on : KKR
# 'High'
# Working on : KLAC
# 'High'
# Working on : KLIC
# 'High'
# Working on : KMB
# 'High'
# Working on : KMI
# 'High'
# Working on : KMPH
# 'High'
# Working on : KMPR
# 'High'
# Working on : KMT
# 'High'
# Working on : KMX
# 'High'
# Working on : KN
# 'High'
# Working on : KNL
# 'High'
# Working on : KNSL
# 'High'
# Working on : KNX
# 'High'
# Working on : KO
# 'High'
# Working on : KODK
# 'High'
# Working on : KOP
# 'High'
# Working on : KOPN
# 'High'
# Working on : KOS
# 'High'
# Working on : KPTI
# 'High'
# Working on : KR
# 'High'
# Working on : KRA
# 'High'
# Working on : KRC
# 'High'
# Working on : KREF
# 'High'
# Working on : KRG
# 'High'
# Working on : KRNY
# 'High'
# Working on : KRO
# 'High'
# Working on : KRYS
# 'High'
# Working on : KSS
# 'High'
# Working on : KSU
# 'High'
# Working on : KTCC
# 'High'
# Working on : KTOS
# 'High'
# Working on : KURA
# 'High'
# Working on : KVHI
# 'High'
# Working on : KW
# 'High'
# Working on : KWR
# 'High'
# Working on : L
# 'High'
# Working on : LAD
# 'High'
# Working on : LADR
# 'High'
# Working on : LAKE
# 'High'
# Working on : LAMR
# 'High'
# Working on : LANC
# 'High'
# Working on : LAND
# 'High'
# Working on : LARK
# 'High'
# Working on : LAUR
# 'High'
# Working on : LAWS
# 'High'
# Working on : LAZ
# 'High'
# Working on : LB
# 'High'
# Working on : LBAI
# 'High'
# Working on : LBC
# 'High'
# Working on : LBRDA
# 'High'
# Working on : LBRDK
# 'High'
# Working on : LBTYA
# 'High'
# Working on : LBTYK
# 'High'
# Working on : LC
# 'High'
# Working on : LCI
# 'High'
# Working on : LCII
# 'High'
# Working on : LCNB
# 'High'
# Working on : LCUT
# 'High'
# Working on : LDL
# 'High'
# Working on : LDOS
# 'High'
# Working on : LE
# 'High'
# Working on : LEA
# 'High'
# Working on : LECO
# 'High'
# Working on : LEE
# 'High'
# Working on : LEG
# 'High'
# Working on : LEN
# 'High'
# Working on : LEU
# 'High'
# Working on : LFUS
# 'High'
# Working on : LFVN
# 'High'
# Working on : LGIH
# 'High'
# Working on : LGL
# 'High'
# Working on : LGND
# 'High'
# Working on : LH
# 'High'
# Working on : LHCG
# 'High'
# Working on : LIFE
# 'High'
# Working on : LII
# 'High'
# Working on : LILA
# 'High'
# Working on : LILAK
# 'High'
# Working on : LIN
# 'High'
# Working on : LINC
# 'High'
# Working on : LIND
# 'High'
# Working on : LIQT
# 'High'
# Working on : LITE
# 'High'
# Working on : LIVE
# 'High'
# Working on : LIVN
# 'High'
# Working on : LIVX
# 'High'
# Working on : LJPC
# 'High'
# Working on : LKFN
# 'High'
# Working on : LKQ
# 'High'
# Working on : LL
# 'High'
# Working on : LLNW
# 'High'
# Working on : LLY
# 'High'
# Working on : LMAT
# 'High'
# Working on : LMFA
# 'High'
# Working on : LMNR
# 'High'
# Working on : LMNX
# 'High'
# Working on : LMT
# 'High'
# Working on : LNC
# 'High'
# Working on : LNDC
# 'High'
# Working on : LNG
# 'High'
# Working on : LNN
# 'High'
# Working on : LNT
# 'High'
# Working on : LNTH
# 'High'
# Working on : LOAN
# 'High'
# Working on : LOB
# 'High'
# Working on : LOCO
# 'High'
# Working on : LODE
# 'High'
# Working on : LOOP
# 'High'
# Working on : LOPE
# 'High'
# Working on : LORL
# 'High'
# Working on : LOW
# 'High'
# Working on : LPCN
# 'High'
# Working on : LPG
# 'High'
# Working on : LPI
# 'High'
# Working on : LPLA
# 'High'
# Working on : LPSN
# 'High'
# Working on : LPTH
# 'High'
# Working on : LPX
# 'High'
# Working on : LQDT
# 'High'
# Working on : LRCX
# 'High'
# Working on : LRN
# 'High'
# Working on : LSBK
# 'High'
# Working on : LSCC
# 'High'
# Working on : LSI
# 'High'
# Working on : LSTR
# 'High'
# Working on : LSXMA
# 'High'
# Working on : LSXMK
# 'High'
# Working on : LTBR
# 'High'
# Working on : LTC
# 'High'
# Working on : LTRPA
# 'High'
# Working on : LTRX
# 'High'
# Working on : LUB
# 'High'
# Working on : LULU
# 'High'
# Working on : LUNA
# 'High'
# Working on : LUV
# 'High'
# Working on : LVS
# 'High'
# Working on : LW
# 'High'
# Working on : LWAY
# 'High'
# Working on : LXP
# 'High'
# Working on : LXRX
# 'High'
# Working on : LXU
# 'High'
# Working on : LYB
# 'High'
# Working on : LYTS
# 'High'
# Working on : LYV
# 'High'
# Working on : LZB
# 'High'
# Working on : M
# 'High'
# Working on : MA
# 'High'
# Working on : MAA
# 'High'
# Working on : MAC
# 'High'
# Working on : MACK
# 'High'
# Working on : MAN
# 'High'
# Working on : MANH
# 'High'
# Working on : MANT
# 'High'
# Working on : MAR
# 'High'
# Working on : MARA
# 'High'
# Working on : MARK
# 'High'
# Working on : MAS
# 'High'
# Working on : MASI
# 'High'
# Working on : MAT
# 'High'
# Working on : MATW
# 'High'
# Working on : MATX
# 'High'
# Working on : MAYS
# 'High'
# Working on : MBCN
# 'High'
# Working on : MBI
# 'High'
# Working on : MBII
# 'High'
# Working on : MBIN
# 'High'
# Working on : MBIO
# 'High'
# Working on : MBOT
# 'High'
# Working on : MBUU
# 'High'
# Working on : MBWM
# 'High'
# Working on : MC
# 'High'
# Working on : MCB
# 'High'
# Working on : MCBC
# 'High'
# Working on : MCD
# 'High'
# Working on : MCF
# 'High'
# Working on : MCFT
# 'High'
# Working on : MCHP
# 'High'
# Working on : MCHX
# 'High'
# Working on : MCK
# 'High'
# Working on : MCO
# 'High'
# Working on : MCRB
# 'High'
# Working on : MCRI
# 'High'
# Working on : MCS
# 'High'
# Working on : MCY
# 'High'
# Working on : MD
# 'High'
# Working on : MDB
# 'High'
# Working on : MDC
# 'High'
# Working on : MDGL
# 'High'
# Working on : MDLY
# 'High'
# Working on : MDLZ
# 'High'
# Working on : MDP
# 'High'
# Working on : MDRX
# 'High'
# Working on : MDT
# 'High'
# Working on : MDU
# 'High'
# Working on : MED
# 'High'
# Working on : MEDP
# 'High'
# Working on : MEI
# 'High'
# Working on : MEIP
# 'High'
# Working on : MERC
# 'High'
# Working on : MET
# 'High'
# Working on : MFA
# 'High'
# Working on : MFNC
# 'High'
# Working on : MG
# 'High'
# Working on : MGEE
# 'High'
# Working on : MGI
# 'High'
# Working on : MGLN
# 'High'
# Working on : MGM
# 'High'
# Working on : MGNX
# 'High'
# Working on : MGPI
# 'High'
# Working on : MGRC
# 'High'
# Working on : MGY
# 'High'
# Working on : MGYR
# 'High'
# Working on : MHH
# 'High'
# Working on : MHK
# 'High'
# Working on : MHLD
# 'High'
# Working on : MHO
# 'High'
# Working on : MIC
# 'High'
# Working on : MICR
# 'High'
# Working on : MICT
# 'High'
# Working on : MIDD
# 'High'
# Working on : MIND
# 'High'
# Working on : MITK
# 'High'
# Working on : MITT
# 'High'
# Working on : MKC
# 'High'
# Working on : MKL
# 'High'
# Working on : MKSI
# 'High'
# Working on : MKTX
# 'High'
# Working on : MLAB
# 'High'
# Working on : MLHR
# 'High'
# Working on : MLI
# 'High'
# Working on : MLM
# 'High'
# Working on : MLND
# 'High'
# Working on : MLP
# 'High'
# Working on : MLR
# 'High'
# Working on : MLSS
# 'High'
# Working on : MLVF
# 'High'
# Working on : MMAC
# 'High'
# Working on : MMC
# 'High'
# Working on : MMI
# 'High'
# Working on : MMM
# 'High'
# Working on : MMS
# 'High'
# Working on : MMSI
# 'High'
# Working on : MN
# 'High'
# Working on : MNKD
# 'High'
# Working on : MNOV
# 'High'
# Working on : MNR
# 'High'
# Working on : MNRO
# 'High'
# Working on : MNST
# 'High'
# Working on : MNTX
# 'High'
# Working on : MO
# 'High'
# Working on : MOBL
# 'High'
# Working on : MOD
# 'High'
# Working on : MODN
# 'High'
# Working on : MOFG
# 'High'
# Working on : MOH
# 'High'
# Working on : MORN
# 'High'
# Working on : MOS
# 'High'
# Working on : MOSY
# 'High'
# Working on : MOV
# 'High'
# Working on : MPAA
# 'High'
# Working on : MPB
# 'High'
# Working on : MPC
# 'High'
# Working on : MPW
# 'High'
# Working on : MPWR
# 'High'
# Working on : MPX
# 'High'
# Working on : MRAM
# 'High'
# Working on : MRC
# 'High'
# Working on : MRCY
# 'High'
# Working on : MRIN
# 'High'
# Working on : MRK
# 'High'
# Working on : MRKR
# 'High'
# Working on : MRLN
# 'High'
# Working on : MRNS
# 'High'
# Working on : MRO
# 'High'
# Working on : MRSN
# 'High'
# Working on : MRTN
# 'High'
# Working on : MRTX
# 'High'
# Working on : MRVL
# 'High'
# Working on : MS
# 'High'
# Working on : MSA
# 'High'
# Working on : MSBI
# 'High'
# Working on : MSCI
# 'High'
# Working on : MSEX
# 'High'
# Working on : MSFT
# 'High'
# Working on : MSGN
# 'High'
# Working on : MSI
# 'High'
# Working on : MSM
# 'High'
# Working on : MSN
# 'High'
# Working on : MSON
# 'High'
# Working on : MSTR
# 'High'
# Working on : MTB
# 'High'
# Working on : MTCH
# 'High'
# Working on : MTD
# 'High'
# Working on : MTDR
# 'High'
# Working on : MTEM
# 'High'
# Working on : MTEX
# 'High'
# Working on : MTG
# 'High'
# Working on : MTH
# 'High'
# Working on : MTN
# 'High'
# Working on : MTNB
# 'High'
# Working on : MTOR
# 'High'
# Working on : MTRN
# 'High'
# Working on : MTRX
# 'High'
# Working on : MTSI
# 'High'
# Working on : MTW
# 'High'
# Working on : MTX
# 'High'
# Working on : MTZ
# 'High'
# Working on : MU
# 'High'
# Working on : MUR
# 'High'
# Working on : MUSA
# 'High'
# Working on : MUX
# 'High'
# Working on : MVBF
# 'High'
# Working on : MVIS
# 'High'
# Working on : MWA
# 'High'
# Working on : MXIM
# 'High'
# Working on : MXL
# 'High'
# Working on : MYE
# 'High'
# Working on : MYGN
# 'High'
# Working on : MYRG
# 'High'
# Working on : NAII
# 'High'
# Working on : NATH
# 'High'
# Working on : NATI
# 'High'
# Working on : NATR
# 'High'
# Working on : NAV
# 'High'
# Working on : NAVB
# 'High'
# Working on : NAVI
# 'High'
# Working on : NBEV
# 'High'
# Working on : NBHC
# 'High'
# Working on : NBIX
# 'High'
# Working on : NBN
# 'High'
# Working on : NBR
# 'High'
# Working on : NBTB
# 'High'
# Working on : NBY
# 'High'
# Working on : NC
# 'High'
# Working on : NCBS
# 'High'
# Working on : NCLH
# 'High'
# Working on : NCMI
# 'High'
# Working on : NCR
# 'High'
# Working on : NCSM
# 'High'
# Working on : NDAQ
# 'High'
# Working on : NDLS
# 'High'
# Working on : NDSN
# 'High'
# Working on : NEE
# 'High'
# Working on : NEM
# 'High'
# Working on : NEO
# 'High'
# Working on : NEOG
# 'High'
# Working on : NEON
# 'High'
# Working on : NERV
# 'High'
# Working on : NETE
# 'High'
# Working on : NEU
# 'High'
# Working on : NEWR
# 'High'
# Working on : NFBK
# 'High'
# Working on : NFG
# 'High'
# Working on : NFLX
# 'High'
# Working on : NGS
# 'High'
# Working on : NGVC
# 'High'
# Working on : NGVT
# 'High'
# Working on : NHC
# 'High'
# Working on : NHI
# 'High'
# Working on : NHTC
# 'High'
# Working on : NI
# 'High'
# Working on : NICK
# 'High'
# Working on : NJR
# 'High'
# Working on : NKE
# 'High'
# Working on : NKSH
# 'High'
# Working on : NKTR
# 'High'
# Working on : NL
# 'High'
# Working on : NLS
# 'High'
# Working on : NLSN
# 'High'
# Working on : NLY
# 'High'
# Working on : NMIH
# 'High'
# Working on : NMRK
# 'High'
# Working on : NNBR
# 'High'
# Working on : NNI
# 'High'
# Working on : NNN
# 'High'
# Working on : NNVC
# 'High'
# Working on : NOC
# 'High'
# Working on : NODK
# 'High'
# Working on : NOG
# 'High'
# Working on : NOV
# 'High'
# Working on : NOVT
# 'High'
# Working on : NOW
# 'High'
# Working on : NP
# 'High'
# Working on : NPK
# 'High'
# Working on : NPO
# 'High'
# Working on : NPTN
# 'High'
# Working on : NR
# 'High'
# Working on : NRC
# 'High'
# Working on : NRG
# 'High'
# Working on : NRIM
# 'High'
# Working on : NRZ
# 'High'
# Working on : NSA
# 'High'
# Working on : NSC
# 'High'
# Working on : NSEC
# 'High'
# Working on : NSIT
# 'High'
# Working on : NSP
# 'High'
# Working on : NSSC
# 'High'
# Working on : NSTG
# 'High'
# Working on : NTAP
# 'High'
# Working on : NTCT
# 'High'
# Working on : NTGR
# 'High'
# Working on : NTIC
# 'High'
# Working on : NTIP
# 'High'
# Working on : NTLA
# 'High'
# Working on : NTNX
# 'High'
# Working on : NTRA
# 'High'
# Working on : NTRS
# 'High'
# Working on : NTWK
# 'High'
# Working on : NUAN
# 'High'
# Working on : NUE
# 'High'
# Working on : NURO
# 'High'
# Working on : NUS
# 'High'
# Working on : NUVA
# 'High'
# Working on : NVAX
# 'High'
# Working on : NVDA
# 'High'
# Working on : NVEC
# 'High'
# Working on : NVEE
# 'High'
# Working on : NVFY
# 'High'
# Working on : NVIV
# 'High'
# Working on : NVR
# 'High'
# Working on : NVRO
# 'High'
# Working on : NVTA
# 'High'
# Working on : NWBI
# 'High'
# Working on : NWE
# 'High'
# Working on : NWFL
# 'High'
# Working on : NWHM
# 'High'
# Working on : NWL
# 'High'
# Working on : NWLI
# 'High'
# Working on : NWN
# 'High'
# Working on : NWPX
# 'High'
# Working on : NWS
# 'High'
# Working on : NWSA
# 'High'
# Working on : NX
# 'High'
# Working on : NXGN
# 'High'
# Working on : NXRT
# 'High'
# Working on : NXST
# 'High'
# Working on : NXTD
# 'High'
# Working on : NYCB
# 'High'
# Working on : NYMT
# 'High'
# Working on : NYT
# 'High'
# Working on : O
# 'High'
# Working on : OAS
# 'High'
# Working on : OBCI
# 'High'
# Working on : OC
# 'High'
# Working on : OCC
# 'High'
# Working on : OCFC
# 'High'
# Working on : OCN
# 'High'
# Working on : OCUL
# 'High'
# Working on : OCX
# 'High'
# Working on : ODC
# 'High'
# Working on : ODFL
# 'High'
# Working on : ODP
# 'High'
# Working on : ODT
# 'High'
# Working on : OESX
# 'High'
# Working on : OFC
# 'High'
# Working on : OFED
# 'High'
# Working on : OFG
# 'High'
# Working on : OFIX
# 'High'
# Working on : OFLX
# 'High'
# Working on : OGE
# 'High'
# Working on : OGEN
# 'High'
# Working on : OGS
# 'High'
# Working on : OHI
# 'High'
# Working on : OI
# 'High'
# Working on : OII
# 'High'
# Working on : OIS
# 'High'
# Working on : OKE
# 'High'
# Working on : OKTA
# 'High'
# Working on : OLED
# 'High'
# Working on : OLLI
# 'High'
# Working on : OLN
# 'High'
# Working on : OLP
# 'High'
# Working on : OMC
# 'High'
# Working on : OMCL
# 'High'
# Working on : OMER
# 'High'
# Working on : OMEX
# 'High'
# Working on : OMF
# 'High'
# Working on : OMI
# 'High'
# Working on : ON
# 'High'
# Working on : ONB
# 'High'
# Working on : ONCS
# 'High'
# Working on : ONTX
# 'High'
# Working on : ONVO
# 'High'
# Working on : OOMA
# 'High'
# Working on : OPGN
# 'High'
# Working on : OPI
# 'High'
# Working on : OPK
# 'High'
# Working on : OPOF
# 'High'
# Working on : OPRX
# 'High'
# Working on : OPTN
# 'High'
# Working on : OPTT
# 'High'
# Working on : OPY
# 'High'
# Working on : ORA
# 'High'
# Working on : ORBC
# 'High'
# Working on : ORC
# 'High'
# Working on : ORCL
# 'High'
# Working on : ORGO
# 'High'
# ...
# 'High'
# Working on : RUSHA
# 'High'
# Working on : RUSHB
# 'High'
# Working on : RUTH
# 'High'
# Working on : RVNC
# 'High'
# Working on : RVP
# 'High'
# Working on : RVSB
# 'High'
# Working on : RWT
# 'High'
# Working on : RXN
# 'High'
# Working on : RYAM
# 'High'
# Working on : RYI
# 'High'
# Working on : RYN
# 'High'
# Working on : RYTM
# 'High'
# Working on : SABR
# 'High'
# Working on : SACH
# 'High'
# Working on : SAFE
# 'High'
# Working on : SAFM
# 'High'
# Working on : SAFT
# 'High'
# Working on : SAGE
# 'High'
# Working on : SAH
# 'High'
# Working on : SAIA
# 'High'
# Working on : SAIC
# 'High'
# Working on : SAIL
# 'High'
# Working on : SAL
# 'High'
# Working on : SALM
# 'High'
# Working on : SAM
# 'High'
# Working on : SAMG
# 'High'
# Working on : SANM
# 'High'
# Working on : SANW
# 'High'
# Working on : SASR
# 'High'
# Working on : SATS
# 'High'
# Working on : SAVE
# 'High'
# Working on : SBAC
# 'High'
# Working on : SBCF
# 'High'
# Working on : SBFG
# 'High'
# Working on : SBGI
# 'High'
# Working on : SBH
# 'High'
# Working on : SBNY
# 'High'
# Working on : SBOW
# 'High'
# Working on : SBRA
# 'High'
# Working on : SBSI
# 'High'
# Working on : SBT
# 'High'
# Working on : SBUX
# 'High'
# Working on : SC
# 'High'
# Working on : SCHL
# 'High'
# Working on : SCHN
# 'High'
# Working on : SCHW
# 'High'
# Working on : SCI
# 'High'
# Working on : SCL
# 'High'
# Working on : SCON
# 'High'
# Working on : SCOR
# 'High'
# Working on : SCS
# 'High'
# Working on : SCSC
# 'High'
# Working on : SCVL
# 'High'
# Working on : SCWX
# 'High'
# Working on : SCX
# 'High'
# Working on : SCYX
# 'High'
# Working on : SD
# 'High'
# Working on : SDPI
# 'High'
# Working on : SEAC
# 'High'
# Working on : SEAS
# 'High'
# Working on : SEB
# 'High'
# Working on : SEDG
# 'High'
# Working on : SEE
# 'High'
# Working on : SEIC
# 'High'
# Working on : SELB
# 'High'
# Working on : SELF
# 'High'
# Working on : SEM
# 'High'
# Working on : SENEA
# 'High'
# Working on : SENEB
# 'High'
# Working on : SENS
# 'High'
# Working on : SESN
# 'High'
# Working on : SF
# 'High'
# Working on : SFBC
# 'High'
# Working on : SFBS
# 'High'
# Working on : SFE
# 'High'
# Working on : SFIX
# 'High'
# Working on : SFM
# 'High'
# Working on : SFNC
# 'High'
# Working on : SFST
# 'High'
# Working on : SGA
# 'High'
# Working on : SGC
# 'High'
# Working on : SGEN
# 'High'
# Working on : SGH
# 'High'
# Working on : SGMA
# 'High'
# Working on : SGMO
# 'High'
# Working on : SGMS
# 'High'
# Working on : SGRP
# 'High'
# Working on : SGRY
# 'High'
# Working on : SHAK
# 'High'
# Working on : SHBI
# 'High'
# Working on : SHEN
# 'High'
# Working on : SHO
# 'High'
# Working on : SHOO
# 'High'
# Working on : SHSP
# 'High'
# Working on : SHW
# 'High'
# Working on : SIEB
# 'High'
# Working on : SIEN
# 'High'
# Working on : SIF
# 'High'
# Working on : SIG
# 'High'
# Working on : SIGA
# 'High'
# Working on : SIGI
# 'High'
# Working on : SINT
# 'High'
# Working on : SIRI
# 'High'
# Working on : SITC
# 'High'
# Working on : SITE
# 'High'
# Working on : SIVB
# 'High'
# Working on : SIX
# 'High'
# Working on : SJI
# 'High'
# Working on : SJM
# 'High'
# Working on : SJW
# 'High'
# Working on : SKT
# 'High'
# Working on : SKX
# 'High'
# Working on : SKY
# 'High'
# Working on : SKYW
# 'High'
# Working on : SLAB
# 'High'
# Working on : SLB
# 'High'
# Working on : SLCA
# 'High'
# Working on : SLCT
# 'High'
# Working on : SLG
# 'High'
# Working on : SLGN
# 'High'
# Working on : SLM
# 'High'
# Working on : SLNO
# 'High'
# Working on : SLP
# 'High'
# Working on : SLS
# 'High'
# Working on : SM
# 'High'
# Working on : SMBC
# 'High'
# Working on : SMBK
# 'High'
# Working on : SMED
# 'High'
# Working on : SMG
# 'High'
# Working on : SMIT
# 'High'
# Working on : SMMF
# 'High'
# Working on : SMP
# 'High'
# Working on : SMPL
# 'High'
# Working on : SMSI
# 'High'
# Working on : SMTC
# 'High'
# Working on : SNA
# 'High'
# Working on : SNAP
# 'High'
# Working on : SNBR
# 'High'
# Working on : SNCR
# 'High'
# Working on : SND
# 'High'
# Working on : SNDR
# 'High'
# Working on : SNDX
# 'High'
# Working on : SNFCA
# 'High'
# Working on : SNOA
# 'High'
# Working on : SNPS
# 'High'
# Working on : SNR
# 'High'
# Working on : SNV
# 'High'
# Working on : SNX
# 'High'
# Working on : SO
# 'High'
# Working on : SOHO
# 'High'
# Working on : SOI
# 'High'
# Working on : SON
# 'High'
# Working on : SP
# 'High'
# Working on : SPB
# 'High'
# Working on : SPG
# 'High'
# Working on : SPGI
# 'High'
# Working on : SPKE
# 'High'
# Working on : SPLK
# 'High'
# Working on : SPNE
# 'High'
# Working on : SPOK
# 'High'
# Working on : SPPI
# 'High'
# Working on : SPR
# 'High'
# Working on : SPRO
# 'High'
# Working on : SPRT
# 'High'
# Working on : SPSC
# 'High'
# Working on : SPTN
# 'High'
# Working on : SPWH
# 'High'
# Working on : SPWR
# 'High'
# Working on : SPXC
# 'High'
# Working on : SQ
# 'High'
# Working on : SQBG
# 'High'
# Working on : SR
# 'High'
# Working on : SRC
# 'High'
# Working on : SRCE
# 'High'
# Working on : SRCL
# 'High'
# Working on : SRDX
# 'High'
# Working on : SRE
# 'High'
# Working on : SREV
# 'High'
# Working on : SRG
# 'High'
# Working on : SRI
# 'High'
# Working on : SRNE
# 'High'
# Working on : SRPT
# 'High'
# Working on : SRT
# 'High'
# Working on : SRTS
# 'High'
# Working on : SSB
# 'High'
# Working on : SSBI
# 'High'
# Working on : SSD
# 'High'
# Working on : SSKN
# 'High'
# Working on : SSNC
# 'High'
# Working on : SSP
# 'High'
# Working on : SSTI
# 'High'
# Working on : SSTK
# 'High'
# Working on : ST
# 'High'
# Working on : STAA
# 'High'
# Working on : STAG
# 'High'
# Working on : STAR
# 'High'
# Working on : STBA
# 'High'
# Working on : STC
# 'High'
# Working on : STCN
# 'High'
# Working on : STE
# 'High'
# Working on : STFC
# 'High'
# Working on : STKS
# 'High'
# Working on : STL
# 'High'
# Working on : STLD
# 'High'
# Working on : STMP
# 'High'
# Working on : STOR
# 'High'
# Working on : STRA
# 'High'
# Working on : STRL
# 'High'
# Working on : STRM
# 'High'
# Working on : STRS
# 'High'
# Working on : STRT
# 'High'
# Working on : STT
# 'High'
# Working on : STWD
# 'High'
# Working on : STX
# 'High'
# Working on : STZ
# 'High'
# Working on : SUI
# 'High'
# Working on : SUM
# 'High'
# Working on : SUMR
# 'High'
# Working on : SUNW
# 'High'
# Working on : SUP
# 'High'
# Working on : SUPN
# 'High'
# Working on : SVBI
# 'High'
# Working on : SVRA
# 'High'
# Working on : SVT
# 'High'
# Working on : SWCH
# 'High'
# Working on : SWK
# 'High'
# Working on : SWKS
# 'High'
# Working on : SWM
# 'High'
# Working on : SWN
# 'High'
# Working on : SWX
# 'High'
# Working on : SXC
# 'High'
# Working on : SXI
# 'High'
# Working on : SXT
# 'High'
# Working on : SYBT
# 'High'
# Working on : SYBX
# 'High'
# Working on : SYF
# 'High'
# Working on : SYK
# 'High'
# Working on : SYKE
# 'High'
# Working on : SYN
# 'High'
# Working on : SYNA
# 'High'
# Working on : SYNH
# 'High'
# Working on : SYNL
# 'High'
# Working on : SYPR
# 'High'
# Working on : SYRS
# 'High'
# Working on : SYX
# 'High'
# Working on : SYY
# 'High'
# Working on : T
# 'High'
# Working on : TACO
# 'High'
# Working on : TACT
# 'High'
# Working on : TAIT
# 'High'
# Working on : TAP
# 'High'
# Working on : TAST
# 'High'
# Working on : TAYD
# 'High'
# Working on : TBBK
# 'High'
# Working on : TBI
# 'High'
# Working on : TBK
# 'High'
# Working on : TBNK
# 'High'
# Working on : TBPH
# 'High'
# Working on : TCBI
# 'High'
# Working on : TCBK
# 'High'
# Working on : TCFC
# 'High'
# Working on : TCI
# 'High'
# Working on : TCMD
# 'High'
# Working on : TCON
# 'High'
# Working on : TCS
# 'High'
# Working on : TDC
# 'High'
# Working on : TDG
# 'High'
# Working on : TDOC
# 'High'
# Working on : TDS
# 'High'
# Working on : TDW
# 'High'
# Working on : TDY
# 'High'
# Working on : TECH
# 'High'
# Working on : TEL
# 'High'
# Working on : TELL
# 'High'
# Working on : TEN
# 'High'
# Working on : TENX
# 'High'
# Working on : TER
# 'High'
# Working on : TESS
# 'High'
# Working on : TEUM
# 'High'
# Working on : TEX
# 'High'
# Working on : TFSL
# 'High'
# Working on : TFX
# 'High'
# Working on : TG
# 'High'
# Working on : TGEN
# 'High'
# Working on : TGI
# 'High'
# Working on : TGLS
# 'High'
# Working on : TGNA
# 'High'
# Working on : TGT
# 'High'
# Working on : TGTX
# 'High'
# Working on : THC
# 'High'
# Working on : THFF
# 'High'
# Working on : THG
# 'High'
# Working on : THO
# 'High'
# Working on : THR
# 'High'
# Working on : THRM
# 'High'
# Working on : THS
# 'High'
# Working on : TILE
# 'High'
# Working on : TIPT
# 'High'
# Working on : TISI
# 'High'
# Working on : TITN
# 'High'
# Working on : TJX
# 'High'
# Working on : TKR
# 'High'
# Working on : TLGT
# 'High'
# Working on : TLYS
# 'High'
# Working on : TMHC
# 'High'
# Working on : TMO
# 'High'
# Working on : TMP
# 'High'
# Working on : TMST
# 'High'
# Working on : TMUS
# 'High'
# Working on : TNC
# 'High'
# Working on : TNDM
# 'High'
# Working on : TNET
# 'High'
# Working on : TNXP
# 'High'
# Working on : TOL
# 'High'
# Working on : TOWN
# 'High'
# Working on : TPB
# 'High'
# Working on : TPC
# 'High'
# Working on : TPH
# 'High'
# Working on : TPHS
# 'High'
# Working on : TPIC
# 'High'
# Working on : TPR
# 'High'
# Working on : TPX
# 'High'
# Working on : TR
# 'High'
# Working on : TRC
# 'High'
# Working on : TRCH
# 'High'
# Working on : TREC
# 'High'
# Working on : TREE
# 'High'
# Working on : TREX
# 'High'
# Working on : TRGP
# 'High'
# Working on : TRHC
# 'High'
# Working on : TRIP
# 'High'
# Working on : TRMB
# 'High'
# Working on : TRMK
# 'High'
# Working on : TRN
# 'High'
# Working on : TRNO
# 'High'
# Working on : TRNS
# 'High'
# Working on : TROW
# 'High'
# Working on : TROX
# 'High'
# Working on : TRS
# 'High'
# Working on : TRST
# 'High'
# Working on : TRT
# 'High'
# Working on : TRTN
# 'High'
# Working on : TRTX
# 'High'
# Working on : TRU
# 'High'
# Working on : TRUP
# 'High'
# Working on : TRV
# 'High'
# Working on : TRVN
# 'High'
# Working on : TSBK
# 'High'
# Working on : TSC
# 'High'
# Working on : TSCO
# 'High'
# Working on : TSE
# 'High'
# Working on : TSLA
# 'High'
# Working on : TSN
# 'High'
# Working on : TSQ
# 'High'
# Working on : TTC
# 'High'
# Working on : TTD
# 'High'
# Working on : TTEC
# 'High'
# Working on : TTEK
# 'High'
# Working on : TTGT
# 'High'
# Working on : TTI
# 'High'
# Working on : TTMI
# 'High'
# Working on : TTNP
# 'High'
# Working on : TTOO
# 'High'
# Working on : TTWO
# 'High'
# Working on : TUP
# 'High'
# Working on : TUSK
# 'High'
# Working on : TVTY
# 'High'
# Working on : TWI
# 'High'
# Working on : TWIN
# 'High'
# Working on : TWLO
# 'High'
# Working on : TWNK
# 'High'
# Working on : TWO
# 'High'
# Working on : TWOU
# 'High'
# Working on : TWTR
# 'High'
# Working on : TXMD
# 'High'
# Working on : TXN
# 'High'
# Working on : TXRH
# 'High'
# Working on : TXT
# 'High'
# Working on : TYL
# 'High'
# Working on : TYME
# 'High'
# Working on : TZOO
# 'High'
# Working on : UA
# 'High'
# Working on : UAA
# 'High'
# Working on : UAL
# 'High'
# Working on : UAMY
# 'High'
# Working on : UBA
# 'High'
# Working on : UBCP
# 'High'
# Working on : UBFO
# 'High'
# Working on : UBOH
# 'High'
# Working on : UBSI
# 'High'
# Working on : UCBI
# 'High'
# Working on : UCTT
# 'High'
# Working on : UDR
# 'High'
# Working on : UE
# 'High'
# Working on : UEC
# 'High'
# Working on : UEIC
# 'High'
# Working on : UFAB
# 'High'
# Working on : UFCS
# 'High'
# Working on : UFI
# 'High'
# Working on : UFPI
# 'High'
# Working on : UFPT
# 'High'
# Working on : UFS
# 'High'
# Working on : UG
# 'High'
# Working on : UGI
# 'High'
# Working on : UHAL
# 'High'
# Working on : UHS
# 'High'
# Working on : UHT
# 'High'
# Working on : UIHC
# 'High'
# Working on : UIS
# 'High'
# Working on : ULBI
# 'High'
# Working on : ULH
# 'High'
# Working on : ULTA
# 'High'
# Working on : UMBF
# 'High'
# Working on : UMH
# 'High'
# Working on : UMPQ
# 'High'
# Working on : UNAM
# 'High'
# Working on : UNB
# 'High'
# Working on : UNF
# 'High'
# Working on : UNFI
# 'High'
# Working on : UNH
# 'High'
# Working on : UNIT
# 'High'
# Working on : UNM
# 'High'
# Working on : UNP
# 'High'
# Working on : UNTY
# 'High'
# Working on : UNVR
# 'High'
# Working on : UONE
# 'High'
# Working on : UONEK
# 'High'
# Working on : UPLD
# 'High'
# Working on : UPS
# 'High'
# Working on : URBN
# 'High'
# Working on : URI
# 'High'
# Working on : USAK
# 'High'
# Working on : USAP
# 'High'
# Working on : USB
# 'High'
# Working on : USCR
# 'High'
# Working on : USEG
# 'High'
# Working on : USFD
# 'High'
# Working on : USIO
# 'High'
# Working on : USLM
# 'High'
# Working on : USM
# 'High'
# Working on : USNA
# 'High'
# Working on : USPH
# 'High'
# Working on : UTHR
# 'High'
# Working on : UTI
# 'High'
# Working on : UTL
# 'High'
# Working on : UTMD
# 'High'
# Working on : UUU
# 'High'
# Working on : UVE
# 'High'
# Working on : UVSP
# 'High'
# Working on : UVV
# 'High'
# Working on : V
# 'High'
# Working on : VAC
# 'High'
# Working on : VALU
# 'High'
# Working on : VBFC
# 'High'
# Working on : VBIV
# 'High'
# Working on : VBTX
# 'High'
# Working on : VC
# 'High'
# Working on : VCEL
# 'High'
# Working on : VCRA
# 'High'
# Working on : VCYT
# 'High'
# Working on : VEC
# 'High'
# Working on : VECO
# 'High'
# Working on : VEEV
# 'High'
# Working on : VER
# 'High'
# Working on : VERI
# 'High'
# Working on : VERU
# 'High'
# Working on : VFC
# 'High'
# Working on : VG
# 'High'
# Working on : VGR
# 'High'
# Working on : VHC
# 'High'
# Working on : VIAV
# 'High'
# Working on : VICR
# 'High'
# Working on : VIRC
# 'High'
# Working on : VIRT
# 'High'
# Working on : VISL
# 'High'
# Working on : VIVO
# 'High'
# Working on : VKTX
# 'High'
# Working on : VLGEA
# 'High'
# Working on : VLO
# 'High'
# Working on : VLY
# 'High'
# Working on : VMC
# 'High'
# Working on : VMI
# 'High'
# Working on : VMW
# 'High'
# Working on : VNCE
# 'High'
# Working on : VNDA
# 'High'
# Working on : VNO
# 'High'
# Working on : VNRX
# 'High'
# Working on : VNTR
# 'High'
# Working on : VOXX
# 'High'
# Working on : VOYA
# 'High'
# Working on : VPG
# 'High'
# Working on : VRA
# 'High'
# Working on : VRAY
# 'High'
# Working on : VREX
# 'High'
# Working on : VRNS
# 'High'
# Working on : VRNT
# 'High'
# Working on : VRRM
# 'High'
# Working on : VRS
# 'High'
# Working on : VRSK
# 'High'
# Working on : VRSN
# 'High'
# Working on : VRTS
# 'High'
# Working on : VRTV
# 'High'
# Working on : VRTX
# 'High'
# Working on : VSAT
# 'High'
# Working on : VSEC
# 'High'
# Working on : VSH
# 'High'
# Working on : VST
# 'High'
# Working on : VSTM
# 'High'
# Working on : VSTO
# 'High'
# Working on : VTNR
# 'High'
# Working on : VTR
# 'High'
# Working on : VTVT
# 'High'
# Working on : VUZI
# 'High'
# Working on : VVI
# 'High'
# Working on : VVV
# 'High'
# Working on : VXRT
# 'High'
# Working on : VYGR
# 'High'
# Working on : VZ
# 'High'
# Working on : W
# 'High'
# Working on : WAB
# 'High'
# Working on : WABC
# 'High'
# Working on : WAFD
# 'High'
# Working on : WAL
# 'High'
# Working on : WASH
# 'High'
# Working on : WAT
# 'High'
# Working on : WATT
# 'High'
# Working on : WBA
# 'High'
# Working on : WBS
# 'High'
# Working on : WBT
# 'High'
# Working on : WCC
# 'High'
# Working on : WD
# 'High'
# Working on : WDAY
# 'High'
# Working on : WDC
# 'High'
# Working on : WDFC
# 'High'
# Working on : WEC
# 'High'
# Working on : WELL
# 'High'
# Working on : WEN
# 'High'
# Working on : WERN
# 'High'
# Working on : WETF
# 'High'
# Working on : WEX
# 'High'
# Working on : WEYS
# 'High'
# Working on : WFC
# 'High'
# Working on : WGO
# 'High'
# Working on : WHG
# 'High'
# Working on : WHLM
# 'High'
# Working on : WHLR
# 'High'
# Working on : WHR
# 'High'
# Working on : WINA
# 'High'
# Working on : WING
# 'High'
# Working on : WIRE
# 'High'
# Working on : WK
# 'High'
# Working on : WKHS
# 'High'
# Working on : WLDN
# 'High'
# Working on : WLFC
# 'High'
# Working on : WLK
# 'High'
# Working on : WLL
# 'High'
# Working on : WLTW
# 'High'
# Working on : WM
# 'High'
# Working on : WMB
# 'High'
# Working on : WMC
# 'High'
# Working on : WMK
# 'High'
# Working on : WMS
# 'High'
# Working on : WMT
# 'High'
# Working on : WNC
# 'High'
# Working on : WNEB
# 'High'
# Working on : WOR
# 'High'
# Working on : WOW
# 'High'
# Working on : WPC
# 'High'
# Working on : WPG
# 'High'
# Working on : WRB
# 'High'
# Working on : WRE
# 'High'
# Working on : WRI
# 'High'
# Working on : WRK
# 'High'
# Working on : WRLD
# 'High'
# Working on : WSBC
# 'High'
# Working on : WSBF
# 'High'
# Working on : WSC
# 'High'
# Working on : WSFS
# 'High'
# Working on : WSM
# 'High'
# Working on : WSO
# 'High'
# Working on : WSR
# 'High'
# Working on : WST
# 'High'
# Working on : WSTG
# 'High'
# Working on : WSTL
# 'High'
# Working on : WTBA
# 'High'
# Working on : WTFC
# 'High'
# Working on : WTI
# 'High'
# Working on : WTM
# 'High'
# Working on : WTRH
# 'High'
# Working on : WTS
# 'High'
# Working on : WTT
# 'High'
# Working on : WTTR
# 'High'
# Working on : WU
# 'High'
# Working on : WVE
# 'High'
# Working on : WVFC
# 'High'
# Working on : WVVI
# 'High'
# Working on : WW
# 'High'
# Working on : WWD
# 'High'
# Working on : WWE
# 'High'
# Working on : WWR
# 'High'
# Working on : WWW
# 'High'
# Working on : WY
# 'High'
# Working on : WYNN
# 'High'
# Working on : WYY
# 'High'
# Working on : X
# 'High'
# Working on : XBIT
# 'High'
# Working on : XEC
# 'High'
# Working on : XEL
# 'High'
# Working on : XELA
# 'High'
# Working on : XELB
# 'High'
# Working on : XENT
# 'High'
# Working on : XFOR
# 'High'
# Working on : XHR
# 'High'
# Working on : XLNX
# 'High'
# Working on : XLRN
# 'High'
# Working on : XNCR
# 'High'
# Working on : XOM
# 'High'
# Working on : XOMA
# 'High'
# Working on : XONE
# 'High'
# Working on : XPER
# 'High'
# Working on : XPL
# 'High'
# Working on : XPO
# 'High'
# Working on : XRAY
# 'High'
# Working on : XRX
# 'High'
# Working on : XSPA
# 'High'
# Working on : XTNT
# 'High'
# Working on : XXII
# 'High'
# Working on : XYL
# 'High'
# Working on : Y
# 'High'
# Working on : YELP
# 'High'
# Working on : YEXT
# 'High'
# Working on : YORW
# 'High'
# Working on : YTEN
# 'High'
# Working on : YUM
# 'High'
# Working on : Z
# 'High'
# Working on : ZBH
# 'High'
# Working on : ZBRA
# 'High'
# Working on : ZDGE
# 'High'
# Working on : ZEN
# 'High'
# Working on : ZEUS
# 'High'
# Working on : ZG
# 'High'
# Working on : ZGNX
# 'High'
# Working on : ZION
# 'High'
# Working on : ZIOP
# 'High'
# Working on : ZIXI
# 'High'
# Working on : ZNGA
# 'High'
# Working on : ZSAN
# 'High'
# Working on : ZTS
# 'High'
# Working on : ZUMZ
# 'High'
# Working on : ZYNE
# 'High'
# Working on : ZYXI
# 'High'

# %%
# It is always better to test your results using one stock

print("Working on :", "AAPL")
new_df = get_stock_df_from_csv("AAPL")
new_df = add_daily_return_to_df(new_df)
new_df = add_cum_return_to_df(new_df)
new_df = add_bollinger_bands(new_df)
new_df = add_Ichimoku(new_df)
new_df.to_csv(PATH + 'AAPL' + '.csv')
new_df.head()
# Out:
# Working on : AAPL
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/fr/tckd51lj45dgnrphw808c5j80000gn/T/ipykernel_67731/1785803302.py in <module>
#       6 new_df = add_cum_return_to_df(new_df)
#       7 new_df = add_bollinger_bands(new_df)
# ----> 8 new_df = add_Ichimoku(new_df)
#       9 new_df.to_csv(PATH + 'AAPL' + '.csv')
#      10 new_df.head()
#
# /var/folders/fr/tckd51lj45dgnrphw808c5j80000gn/T/ipykernel_67731/390315317.py in add_Ichimoku(df)
#       1 def add_Ichimoku(df):
#       2     # Conversion
# ----> 3     hi_val = df['High'].rolling(window=9).max()
#       4     low_val = df['Low'].rolling(window=9).min()
#       5     df['Conversion'] = (hi_val + low_val) / 2
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'High'

# %%
get_stock_df_from_csv("AAPL")
# Out:
#             Date   Adj Close  daily_return
# 0     2017-01-03   27.372362           NaN
# 1     2017-01-04   27.341724     -0.001119
# 2     2017-01-05   27.480770      0.005085
# 3     2017-01-06   27.787130      0.011148
# 4     2017-01-09   28.041647      0.009160
# ...          ...         ...           ...
# 1161  2021-08-13  149.100006      0.001410
# 1162  2021-08-16  151.119995      0.013548
# 1163  2021-08-17  150.190002     -0.006154
# 1164  2021-08-18  146.360001     -0.025501
# 1165  2021-08-19  146.699997      0.002323
#
# [1166 rows x 3 columns]
