# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "/Users/oppoudel/dev/Python4Finance/Stocks/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("/Users/oppoudel/dev/Python4Finance/Wilshire-5000-Stocks-New.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  A
# /Users/oppoudel/dev/Python4Finance/Stocks/A.csv  Saved
# Finished
# Get Data for :  AA
# /Users/oppoudel/dev/Python4Finance/Stocks/AA.csv  Saved
# Finished
# Get Data for :  AAL
# /Users/oppoudel/dev/Python4Finance/Stocks/AAL.csv  Saved
# Finished
# Get Data for :  AAME
# /Users/oppoudel/dev/Python4Finance/Stocks/AAME.csv  Saved
# Finished
# Get Data for :  AAN
# /Users/oppoudel/dev/Python4Finance/Stocks/AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# /Users/oppoudel/dev/Python4Finance/Stocks/AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# /Users/oppoudel/dev/Python4Finance/Stocks/AAON.csv  Saved
# Finished
# Get Data for :  AAP
# /Users/oppoudel/dev/Python4Finance/Stocks/AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# /Users/oppoudel/dev/Python4Finance/Stocks/AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# /Users/oppoudel/dev/Python4Finance/Stocks/AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# /Users/oppoudel/dev/Python4Finance/Stocks/AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AAXN.csv  Saved
# Finished
# Get Data for :  ABBV
# /Users/oppoudel/dev/Python4Finance/Stocks/ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# /Users/oppoudel/dev/Python4Finance/Stocks/ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# /Users/oppoudel/dev/Python4Finance/Stocks/ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# /Users/oppoudel/dev/Python4Finance/Stocks/ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# /Users/oppoudel/dev/Python4Finance/Stocks/ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# /Users/oppoudel/dev/Python4Finance/Stocks/ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# /Users/oppoudel/dev/Python4Finance/Stocks/ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# /Users/oppoudel/dev/Python4Finance/Stocks/ABMD.csv  Saved
# Finished
# Get Data for :  ABR
# /Users/oppoudel/dev/Python4Finance/Stocks/ABR.csv  Saved
# Finished
# Get Data for :  ABT
# /Users/oppoudel/dev/Python4Finance/Stocks/ABT.csv  Saved
# Finished
# Get Data for :  ABTX
# /Users/oppoudel/dev/Python4Finance/Stocks/ABTX.csv  Saved
# Finished
# Get Data for :  AC
# /Users/oppoudel/dev/Python4Finance/Stocks/AC.csv  Saved
# Finished
# Get Data for :  ACA
# /Users/oppoudel/dev/Python4Finance/Stocks/ACA.csv  Saved
# Finished
# Get Data for :  ACAD
# /Users/oppoudel/dev/Python4Finance/Stocks/ACAD.csv  Saved
# Finished
# Get Data for :  ACBI
# /Users/oppoudel/dev/Python4Finance/Stocks/ACBI.csv  Saved
# Finished
# Get Data for :  ACC
# /Users/oppoudel/dev/Python4Finance/Stocks/ACC.csv  Saved
# Finished
# Get Data for :  ACCO
# /Users/oppoudel/dev/Python4Finance/Stocks/ACCO.csv  Saved
# Finished
# Get Data for :  ACER
# /Users/oppoudel/dev/Python4Finance/Stocks/ACER.csv  Saved
# Finished
# Get Data for :  ACGL
# /Users/oppoudel/dev/Python4Finance/Stocks/ACGL.csv  Saved
# Finished
# Get Data for :  ACHC
# /Users/oppoudel/dev/Python4Finance/Stocks/ACHC.csv  Saved
# Finished
# Get Data for :  ACHV
# /Users/oppoudel/dev/Python4Finance/Stocks/ACHV.csv  Saved
# Finished
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ACIA.csv  Saved
# Finished
# Get Data for :  ACIW
# /Users/oppoudel/dev/Python4Finance/Stocks/ACIW.csv  Saved
# Finished
# Get Data for :  ACLS
# /Users/oppoudel/dev/Python4Finance/Stocks/ACLS.csv  Saved
# Finished
# Get Data for :  ACM
# /Users/oppoudel/dev/Python4Finance/Stocks/ACM.csv  Saved
# Finished
# Get Data for :  ACMR
# /Users/oppoudel/dev/Python4Finance/Stocks/ACMR.csv  Saved
# Finished
# Get Data for :  ACN
# /Users/oppoudel/dev/Python4Finance/Stocks/ACN.csv  Saved
# Finished
# Get Data for :  ACNB
# /Users/oppoudel/dev/Python4Finance/Stocks/ACNB.csv  Saved
# Finished
# Get Data for :  ACOR
# /Users/oppoudel/dev/Python4Finance/Stocks/ACOR.csv  Saved
# Finished
# Get Data for :  ACRE
# /Users/oppoudel/dev/Python4Finance/Stocks/ACRE.csv  Saved
# Finished
# Get Data for :  ACRS
# /Users/oppoudel/dev/Python4Finance/Stocks/ACRS.csv  Saved
# Finished
# Get Data for :  ACRX
# /Users/oppoudel/dev/Python4Finance/Stocks/ACRX.csv  Saved
# Finished
# Get Data for :  ACTG
# /Users/oppoudel/dev/Python4Finance/Stocks/ACTG.csv  Saved
# Finished
# Get Data for :  ACU
# /Users/oppoudel/dev/Python4Finance/Stocks/ACU.csv  Saved
# Finished
# Get Data for :  ACY
# /Users/oppoudel/dev/Python4Finance/Stocks/ACY.csv  Saved
# Finished
# Get Data for :  ADBE
# /Users/oppoudel/dev/Python4Finance/Stocks/ADBE.csv  Saved
# Finished
# Get Data for :  ADC
# /Users/oppoudel/dev/Python4Finance/Stocks/ADC.csv  Saved
# Finished
# Get Data for :  ADES
# /Users/oppoudel/dev/Python4Finance/Stocks/ADES.csv  Saved
# Finished
# Get Data for :  ADI
# /Users/oppoudel/dev/Python4Finance/Stocks/ADI.csv  Saved
# Finished
# Get Data for :  ADM
# /Users/oppoudel/dev/Python4Finance/Stocks/ADM.csv  Saved
# Finished
# Get Data for :  ADMA
# /Users/oppoudel/dev/Python4Finance/Stocks/ADMA.csv  Saved
# Finished
# Get Data for :  ADMP
# /Users/oppoudel/dev/Python4Finance/Stocks/ADMP.csv  Saved
# Finished
# Get Data for :  ADMS
# - ADMS: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ADMS.csv  Saved
# Finished
# Get Data for :  ADNT
# /Users/oppoudel/dev/Python4Finance/Stocks/ADNT.csv  Saved
# Finished
# Get Data for :  ADP
# /Users/oppoudel/dev/Python4Finance/Stocks/ADP.csv  Saved
# Finished
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ADRO.csv  Saved
# Finished
# Get Data for :  ADS
# /Users/oppoudel/dev/Python4Finance/Stocks/ADS.csv  Saved
# Finished
# Get Data for :  ADSK
# /Users/oppoudel/dev/Python4Finance/Stocks/ADSK.csv  Saved
# Finished
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ADSW.csv  Saved
# Finished
# Get Data for :  ADT
# /Users/oppoudel/dev/Python4Finance/Stocks/ADT.csv  Saved
# Finished
# Get Data for :  ADTN
# /Users/oppoudel/dev/Python4Finance/Stocks/ADTN.csv  Saved
# Finished
# Get Data for :  ADUS
# /Users/oppoudel/dev/Python4Finance/Stocks/ADUS.csv  Saved
# Finished
# Get Data for :  ADVM
# /Users/oppoudel/dev/Python4Finance/Stocks/ADVM.csv  Saved
# Finished
# Get Data for :  ADXS
# /Users/oppoudel/dev/Python4Finance/Stocks/ADXS.csv  Saved
# Finished
# Get Data for :  AE
# /Users/oppoudel/dev/Python4Finance/Stocks/AE.csv  Saved
# Finished
# Get Data for :  AEE
# /Users/oppoudel/dev/Python4Finance/Stocks/AEE.csv  Saved
# Finished
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AEGN.csv  Saved
# Finished
# Get Data for :  AEHR
# /Users/oppoudel/dev/Python4Finance/Stocks/AEHR.csv  Saved
# Finished
# Get Data for :  AEIS
# /Users/oppoudel/dev/Python4Finance/Stocks/AEIS.csv  Saved
# Finished
# Get Data for :  AEL
# /Users/oppoudel/dev/Python4Finance/Stocks/AEL.csv  Saved
# Finished
# Get Data for :  AEMD
# /Users/oppoudel/dev/Python4Finance/Stocks/AEMD.csv  Saved
# Finished
# Get Data for :  AEO
# /Users/oppoudel/dev/Python4Finance/Stocks/AEO.csv  Saved
# Finished
# Get Data for :  AEP
# /Users/oppoudel/dev/Python4Finance/Stocks/AEP.csv  Saved
# Finished
# Get Data for :  AERI
# /Users/oppoudel/dev/Python4Finance/Stocks/AERI.csv  Saved
# Finished
# Get Data for :  AES
# /Users/oppoudel/dev/Python4Finance/Stocks/AES.csv  Saved
# Finished
# Get Data for :  AEY
# /Users/oppoudel/dev/Python4Finance/Stocks/AEY.csv  Saved
# Finished
# Get Data for :  AFG
# /Users/oppoudel/dev/Python4Finance/Stocks/AFG.csv  Saved
# Finished
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AFH.csv  Saved
# Finished
# Get Data for :  AFI
# /Users/oppoudel/dev/Python4Finance/Stocks/AFI.csv  Saved
# Finished
# Get Data for :  AFIN
# /Users/oppoudel/dev/Python4Finance/Stocks/AFIN.csv  Saved
# Finished
# Get Data for :  AFL
# /Users/oppoudel/dev/Python4Finance/Stocks/AFL.csv  Saved
# Finished
# Get Data for :  AGCO
# /Users/oppoudel/dev/Python4Finance/Stocks/AGCO.csv  Saved
# Finished
# Get Data for :  AGE
# /Users/oppoudel/dev/Python4Finance/Stocks/AGE.csv  Saved
# Finished
# Get Data for :  AGEN
# /Users/oppoudel/dev/Python4Finance/Stocks/AGEN.csv  Saved
# Finished
# Get Data for :  AGFS
# /Users/oppoudel/dev/Python4Finance/Stocks/AGFS.csv  Saved
# Finished
# Get Data for :  AGIO
# /Users/oppoudel/dev/Python4Finance/Stocks/AGIO.csv  Saved
# Finished
# Get Data for :  AGLE
# /Users/oppoudel/dev/Python4Finance/Stocks/AGLE.csv  Saved
# Finished
# Get Data for :  AGM
# /Users/oppoudel/dev/Python4Finance/Stocks/AGM.csv  Saved
# Finished
# Get Data for :  AGNC
# /Users/oppoudel/dev/Python4Finance/Stocks/AGNC.csv  Saved
# Finished
# Get Data for :  AGO
# /Users/oppoudel/dev/Python4Finance/Stocks/AGO.csv  Saved
# Finished
# Get Data for :  AGR
# /Users/oppoudel/dev/Python4Finance/Stocks/AGR.csv  Saved
# Finished
# Get Data for :  AGRX
# /Users/oppoudel/dev/Python4Finance/Stocks/AGRX.csv  Saved
# Finished
# Get Data for :  AGS
# /Users/oppoudel/dev/Python4Finance/Stocks/AGS.csv  Saved
# Finished
# Get Data for :  AGTC
# /Users/oppoudel/dev/Python4Finance/Stocks/AGTC.csv  Saved
# Finished
# Get Data for :  AGX
# /Users/oppoudel/dev/Python4Finance/Stocks/AGX.csv  Saved
# Finished
# Get Data for :  AGYS
# /Users/oppoudel/dev/Python4Finance/Stocks/AGYS.csv  Saved
# Finished
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AHC.csv  Saved
# Finished
# Get Data for :  AHH
# /Users/oppoudel/dev/Python4Finance/Stocks/AHH.csv  Saved
# Finished
# Get Data for :  AHT
# /Users/oppoudel/dev/Python4Finance/Stocks/AHT.csv  Saved
# Finished
# Get Data for :  AIG
# /Users/oppoudel/dev/Python4Finance/Stocks/AIG.csv  Saved
# Finished
# Get Data for :  AIMC
# /Users/oppoudel/dev/Python4Finance/Stocks/AIMC.csv  Saved
# Finished
# Get Data for :  AIMT
# - AIMT: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AIMT.csv  Saved
# Finished
# Get Data for :  AIN
# /Users/oppoudel/dev/Python4Finance/Stocks/AIN.csv  Saved
# Finished
# Get Data for :  AINC
# /Users/oppoudel/dev/Python4Finance/Stocks/AINC.csv  Saved
# Finished
# Get Data for :  AIR
# /Users/oppoudel/dev/Python4Finance/Stocks/AIR.csv  Saved
# Finished
# Get Data for :  AIRG
# /Users/oppoudel/dev/Python4Finance/Stocks/AIRG.csv  Saved
# Finished
# Get Data for :  AIRI
# /Users/oppoudel/dev/Python4Finance/Stocks/AIRI.csv  Saved
# Finished
# Get Data for :  AIRT
# /Users/oppoudel/dev/Python4Finance/Stocks/AIRT.csv  Saved
# Finished
# Get Data for :  AIT
# /Users/oppoudel/dev/Python4Finance/Stocks/AIT.csv  Saved
# Finished
# Get Data for :  AIV
# /Users/oppoudel/dev/Python4Finance/Stocks/AIV.csv  Saved
# Finished
# Get Data for :  AIZ
# /Users/oppoudel/dev/Python4Finance/Stocks/AIZ.csv  Saved
# Finished
# Get Data for :  AJG
# /Users/oppoudel/dev/Python4Finance/Stocks/AJG.csv  Saved
# Finished
# Get Data for :  AJRD
# /Users/oppoudel/dev/Python4Finance/Stocks/AJRD.csv  Saved
# Finished
# Get Data for :  AJX
# /Users/oppoudel/dev/Python4Finance/Stocks/AJX.csv  Saved
# Finished
# Get Data for :  AKAM
# /Users/oppoudel/dev/Python4Finance/Stocks/AKAM.csv  Saved
# Finished
# Get Data for :  AKBA
# /Users/oppoudel/dev/Python4Finance/Stocks/AKBA.csv  Saved
# Finished
# Get Data for :  AKCA
# - AKCA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AKCA.csv  Saved
# Finished
# Get Data for :  AKER
# - AKER: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AKER.csv  Saved
# Finished
# Get Data for :  AKR
# /Users/oppoudel/dev/Python4Finance/Stocks/AKR.csv  Saved
# Finished
# Get Data for :  AKTS
# /Users/oppoudel/dev/Python4Finance/Stocks/AKTS.csv  Saved
# Finished
# Get Data for :  AL
# /Users/oppoudel/dev/Python4Finance/Stocks/AL.csv  Saved
# Finished
# Get Data for :  ALB
# /Users/oppoudel/dev/Python4Finance/Stocks/ALB.csv  Saved
# Finished
# Get Data for :  ALBO
# /Users/oppoudel/dev/Python4Finance/Stocks/ALBO.csv  Saved
# Finished
# Get Data for :  ALCO
# /Users/oppoudel/dev/Python4Finance/Stocks/ALCO.csv  Saved
# Finished
# Get Data for :  ALDX
# /Users/oppoudel/dev/Python4Finance/Stocks/ALDX.csv  Saved
# Finished
# Get Data for :  ALE
# /Users/oppoudel/dev/Python4Finance/Stocks/ALE.csv  Saved
# Finished
# Get Data for :  ALEC
# /Users/oppoudel/dev/Python4Finance/Stocks/ALEC.csv  Saved
# Finished
# Get Data for :  ALEX
# /Users/oppoudel/dev/Python4Finance/Stocks/ALEX.csv  Saved
# Finished
# Get Data for :  ALG
# /Users/oppoudel/dev/Python4Finance/Stocks/ALG.csv  Saved
# Finished
# Get Data for :  ALGN
# /Users/oppoudel/dev/Python4Finance/Stocks/ALGN.csv  Saved
# Finished
# Get Data for :  ALGT
# /Users/oppoudel/dev/Python4Finance/Stocks/ALGT.csv  Saved
# Finished
# Get Data for :  ALIM
# /Users/oppoudel/dev/Python4Finance/Stocks/ALIM.csv  Saved
# Finished
# Get Data for :  ALJJ
# /Users/oppoudel/dev/Python4Finance/Stocks/ALJJ.csv  Saved
# Finished
# Get Data for :  ALK
# /Users/oppoudel/dev/Python4Finance/Stocks/ALK.csv  Saved
# Finished
# Get Data for :  ALKS
# /Users/oppoudel/dev/Python4Finance/Stocks/ALKS.csv  Saved
# Finished
# Get Data for :  ALL
# /Users/oppoudel/dev/Python4Finance/Stocks/ALL.csv  Saved
# Finished
# Get Data for :  ALLE
# /Users/oppoudel/dev/Python4Finance/Stocks/ALLE.csv  Saved
# Finished
# Get Data for :  ALLK
# /Users/oppoudel/dev/Python4Finance/Stocks/ALLK.csv  Saved
# Finished
# Get Data for :  ALLO
# /Users/oppoudel/dev/Python4Finance/Stocks/ALLO.csv  Saved
# Finished
# Get Data for :  ALLY
# /Users/oppoudel/dev/Python4Finance/Stocks/ALLY.csv  Saved
# Finished
# Get Data for :  ALNA
# /Users/oppoudel/dev/Python4Finance/Stocks/ALNA.csv  Saved
# Finished
# Get Data for :  ALNY
# /Users/oppoudel/dev/Python4Finance/Stocks/ALNY.csv  Saved
# Finished
# Get Data for :  ALOT
# /Users/oppoudel/dev/Python4Finance/Stocks/ALOT.csv  Saved
# Finished
# Get Data for :  ALPN
# /Users/oppoudel/dev/Python4Finance/Stocks/ALPN.csv  Saved
# Finished
# Get Data for :  ALRM
# /Users/oppoudel/dev/Python4Finance/Stocks/ALRM.csv  Saved
# Finished
# Get Data for :  ALSK
# - ALSK: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ALSK.csv  Saved
# Finished
# Get Data for :  ALSN
# /Users/oppoudel/dev/Python4Finance/Stocks/ALSN.csv  Saved
# Finished
# Get Data for :  ALT
# /Users/oppoudel/dev/Python4Finance/Stocks/ALT.csv  Saved
# Finished
# Get Data for :  ALTM
# /Users/oppoudel/dev/Python4Finance/Stocks/ALTM.csv  Saved
# Finished
# Get Data for :  ALTR
# /Users/oppoudel/dev/Python4Finance/Stocks/ALTR.csv  Saved
# Finished
# Get Data for :  ALV
# /Users/oppoudel/dev/Python4Finance/Stocks/ALV.csv  Saved
# Finished
# Get Data for :  ALX
# /Users/oppoudel/dev/Python4Finance/Stocks/ALX.csv  Saved
# Finished
# Get Data for :  ALXN
# - ALXN: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ALXN.csv  Saved
# Finished
# Get Data for :  AM
# /Users/oppoudel/dev/Python4Finance/Stocks/AM.csv  Saved
# Finished
# Get Data for :  AMAG
# - AMAG: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AMAG.csv  Saved
# Finished
# Get Data for :  AMAL
# /Users/oppoudel/dev/Python4Finance/Stocks/AMAL.csv  Saved
# Finished
# Get Data for :  AMAT
# /Users/oppoudel/dev/Python4Finance/Stocks/AMAT.csv  Saved
# Finished
# Get Data for :  AMBC
# /Users/oppoudel/dev/Python4Finance/Stocks/AMBC.csv  Saved
# Finished
# Get Data for :  AMC
# /Users/oppoudel/dev/Python4Finance/Stocks/AMC.csv  Saved
# Finished
# Get Data for :  AMCX
# /Users/oppoudel/dev/Python4Finance/Stocks/AMCX.csv  Saved
# Finished
# Get Data for :  AMD
# /Users/oppoudel/dev/Python4Finance/Stocks/AMD.csv  Saved
# Finished
# Get Data for :  AME
# /Users/oppoudel/dev/Python4Finance/Stocks/AME.csv  Saved
# Finished
# Get Data for :  AMED
# /Users/oppoudel/dev/Python4Finance/Stocks/AMED.csv  Saved
# Finished
# Get Data for :  AMG
# /Users/oppoudel/dev/Python4Finance/Stocks/AMG.csv  Saved
# Finished
# Get Data for :  AMGN
# /Users/oppoudel/dev/Python4Finance/Stocks/AMGN.csv  Saved
# Finished
# Get Data for :  AMH
# /Users/oppoudel/dev/Python4Finance/Stocks/AMH.csv  Saved
# Finished
# Get Data for :  AMKR
# /Users/oppoudel/dev/Python4Finance/Stocks/AMKR.csv  Saved
# Finished
# Get Data for :  AMN
# /Users/oppoudel/dev/Python4Finance/Stocks/AMN.csv  Saved
# Finished
# Get Data for :  AMNB
# /Users/oppoudel/dev/Python4Finance/Stocks/AMNB.csv  Saved
# Finished
# Get Data for :  AMOT
# /Users/oppoudel/dev/Python4Finance/Stocks/AMOT.csv  Saved
# Finished
# Get Data for :  AMP
# /Users/oppoudel/dev/Python4Finance/Stocks/AMP.csv  Saved
# Finished
# Get Data for :  AMPE
# /Users/oppoudel/dev/Python4Finance/Stocks/AMPE.csv  Saved
# Finished
# Get Data for :  AMPH
# /Users/oppoudel/dev/Python4Finance/Stocks/AMPH.csv  Saved
# Finished
# Get Data for :  AMRB
# - AMRB: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AMRB.csv  Saved
# Finished
# Get Data for :  AMRC
# /Users/oppoudel/dev/Python4Finance/Stocks/AMRC.csv  Saved
# Finished
# Get Data for :  AMRK
# /Users/oppoudel/dev/Python4Finance/Stocks/AMRK.csv  Saved
# Finished
# Get Data for :  AMRS
# /Users/oppoudel/dev/Python4Finance/Stocks/AMRS.csv  Saved
# Finished
# Get Data for :  AMRX
# /Users/oppoudel/dev/Python4Finance/Stocks/AMRX.csv  Saved
# Finished
# Get Data for :  AMS
# /Users/oppoudel/dev/Python4Finance/Stocks/AMS.csv  Saved
# Finished
# Get Data for :  AMSC
# /Users/oppoudel/dev/Python4Finance/Stocks/AMSC.csv  Saved
# Finished
# Get Data for :  AMSF
# /Users/oppoudel/dev/Python4Finance/Stocks/AMSF.csv  Saved
# Finished
# Get Data for :  AMSWA
# /Users/oppoudel/dev/Python4Finance/Stocks/AMSWA.csv  Saved
# Finished
# Get Data for :  AMT
# /Users/oppoudel/dev/Python4Finance/Stocks/AMT.csv  Saved
# Finished
# Get Data for :  AMTD
# /Users/oppoudel/dev/Python4Finance/Stocks/AMTD.csv  Saved
# Finished
# Get Data for :  AMTX
# /Users/oppoudel/dev/Python4Finance/Stocks/AMTX.csv  Saved
# Finished
# Get Data for :  AMWD
# /Users/oppoudel/dev/Python4Finance/Stocks/AMWD.csv  Saved
# Finished
# Get Data for :  AMZN
# /Users/oppoudel/dev/Python4Finance/Stocks/AMZN.csv  Saved
# Finished
# Get Data for :  AN
# /Users/oppoudel/dev/Python4Finance/Stocks/AN.csv  Saved
# Finished
# Get Data for :  ANAB
# /Users/oppoudel/dev/Python4Finance/Stocks/ANAB.csv  Saved
# Finished
# Get Data for :  ANAT
# /Users/oppoudel/dev/Python4Finance/Stocks/ANAT.csv  Saved
# Finished
# Get Data for :  ANDE
# /Users/oppoudel/dev/Python4Finance/Stocks/ANDE.csv  Saved
# Finished
# Get Data for :  ANET
# /Users/oppoudel/dev/Python4Finance/Stocks/ANET.csv  Saved
# Finished
# Get Data for :  ANF
# /Users/oppoudel/dev/Python4Finance/Stocks/ANF.csv  Saved
# Finished
# Get Data for :  ANGI
# /Users/oppoudel/dev/Python4Finance/Stocks/ANGI.csv  Saved
# Finished
# Get Data for :  ANGO
# /Users/oppoudel/dev/Python4Finance/Stocks/ANGO.csv  Saved
# Finished
# Get Data for :  ANH
# - ANH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ANH.csv  Saved
# Finished
# Get Data for :  ANIK
# /Users/oppoudel/dev/Python4Finance/Stocks/ANIK.csv  Saved
# Finished
# Get Data for :  ANIP
# /Users/oppoudel/dev/Python4Finance/Stocks/ANIP.csv  Saved
# Finished
# Get Data for :  ANIX
# /Users/oppoudel/dev/Python4Finance/Stocks/ANIX.csv  Saved
# Finished
# Get Data for :  ANSS
# /Users/oppoudel/dev/Python4Finance/Stocks/ANSS.csv  Saved
# Finished
# Get Data for :  ANTM
# /Users/oppoudel/dev/Python4Finance/Stocks/ANTM.csv  Saved
# Finished
# Get Data for :  AON
# /Users/oppoudel/dev/Python4Finance/Stocks/AON.csv  Saved
# Finished
# Get Data for :  AOS
# /Users/oppoudel/dev/Python4Finance/Stocks/AOS.csv  Saved
# Finished
# Get Data for :  AOSL
# /Users/oppoudel/dev/Python4Finance/Stocks/AOSL.csv  Saved
# Finished
# Get Data for :  AP
# /Users/oppoudel/dev/Python4Finance/Stocks/AP.csv  Saved
# Finished
# Get Data for :  APA
# /Users/oppoudel/dev/Python4Finance/Stocks/APA.csv  Saved
# Finished
# Get Data for :  APAM
# /Users/oppoudel/dev/Python4Finance/Stocks/APAM.csv  Saved
# Finished
# Get Data for :  APD
# /Users/oppoudel/dev/Python4Finance/Stocks/APD.csv  Saved
# Finished
# Get Data for :  APDN
# /Users/oppoudel/dev/Python4Finance/Stocks/APDN.csv  Saved
# Finished
# Get Data for :  APEI
# /Users/oppoudel/dev/Python4Finance/Stocks/APEI.csv  Saved
# Finished
# Get Data for :  APEN
# /Users/oppoudel/dev/Python4Finance/Stocks/APEN.csv  Saved
# Finished
# Get Data for :  APH
# /Users/oppoudel/dev/Python4Finance/Stocks/APH.csv  Saved
# Finished
# Get Data for :  APLE
# /Users/oppoudel/dev/Python4Finance/Stocks/APLE.csv  Saved
# Finished
# Get Data for :  APLS
# /Users/oppoudel/dev/Python4Finance/Stocks/APLS.csv  Saved
# Finished
# Get Data for :  APOG
# /Users/oppoudel/dev/Python4Finance/Stocks/APOG.csv  Saved
# Finished
# Get Data for :  APPF
# /Users/oppoudel/dev/Python4Finance/Stocks/APPF.csv  Saved
# Finished
# Get Data for :  APPN
# /Users/oppoudel/dev/Python4Finance/Stocks/APPN.csv  Saved
# Finished
# Get Data for :  APPS
# /Users/oppoudel/dev/Python4Finance/Stocks/APPS.csv  Saved
# Finished
# Get Data for :  APRN
# /Users/oppoudel/dev/Python4Finance/Stocks/APRN.csv  Saved
# Finished
# Get Data for :  APT
# /Users/oppoudel/dev/Python4Finance/Stocks/APT.csv  Saved
# Finished
# Get Data for :  APTS
# /Users/oppoudel/dev/Python4Finance/Stocks/APTS.csv  Saved
# Finished
# Get Data for :  APTV
# /Users/oppoudel/dev/Python4Finance/Stocks/APTV.csv  Saved
# Finished
# Get Data for :  APVO
# /Users/oppoudel/dev/Python4Finance/Stocks/APVO.csv  Saved
# Finished
# Get Data for :  APYX
# /Users/oppoudel/dev/Python4Finance/Stocks/APYX.csv  Saved
# Finished
# Get Data for :  AQB
# /Users/oppoudel/dev/Python4Finance/Stocks/AQB.csv  Saved
# Finished
# Get Data for :  AQMS
# /Users/oppoudel/dev/Python4Finance/Stocks/AQMS.csv  Saved
# Finished
# Get Data for :  AQUA
# /Users/oppoudel/dev/Python4Finance/Stocks/AQUA.csv  Saved
# Finished
# Get Data for :  AR
# /Users/oppoudel/dev/Python4Finance/Stocks/AR.csv  Saved
# Finished
# Get Data for :  ARA
# - ARA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ARA.csv  Saved
# Finished
# Get Data for :  ARAV
# /Users/oppoudel/dev/Python4Finance/Stocks/ARAV.csv  Saved
# Finished
# Get Data for :  ARAY
# /Users/oppoudel/dev/Python4Finance/Stocks/ARAY.csv  Saved
# Finished
# Get Data for :  ARC
# /Users/oppoudel/dev/Python4Finance/Stocks/ARC.csv  Saved
# Finished
# Get Data for :  ARCB
# /Users/oppoudel/dev/Python4Finance/Stocks/ARCB.csv  Saved
# Finished
# Get Data for :  ARCH
# /Users/oppoudel/dev/Python4Finance/Stocks/ARCH.csv  Saved
# Finished
# Get Data for :  ARDX
# /Users/oppoudel/dev/Python4Finance/Stocks/ARDX.csv  Saved
# Finished
# Get Data for :  ARE
# /Users/oppoudel/dev/Python4Finance/Stocks/ARE.csv  Saved
# Finished
# Get Data for :  ARES
# /Users/oppoudel/dev/Python4Finance/Stocks/ARES.csv  Saved
# Finished
# Get Data for :  ARGO
# /Users/oppoudel/dev/Python4Finance/Stocks/ARGO.csv  Saved
# Finished
# Get Data for :  ARI
# /Users/oppoudel/dev/Python4Finance/Stocks/ARI.csv  Saved
# Finished
# Get Data for :  ARKR
# /Users/oppoudel/dev/Python4Finance/Stocks/ARKR.csv  Saved
# Finished
# Get Data for :  ARL
# /Users/oppoudel/dev/Python4Finance/Stocks/ARL.csv  Saved
# Finished
# Get Data for :  ARLO
# /Users/oppoudel/dev/Python4Finance/Stocks/ARLO.csv  Saved
# Finished
# Get Data for :  ARMK
# /Users/oppoudel/dev/Python4Finance/Stocks/ARMK.csv  Saved
# Finished
# Get Data for :  ARNA
# /Users/oppoudel/dev/Python4Finance/Stocks/ARNA.csv  Saved
# Finished
# Get Data for :  ARNC
# /Users/oppoudel/dev/Python4Finance/Stocks/ARNC.csv  Saved
# Finished
# Get Data for :  AROC
# /Users/oppoudel/dev/Python4Finance/Stocks/AROC.csv  Saved
# Finished
# Get Data for :  AROW
# /Users/oppoudel/dev/Python4Finance/Stocks/AROW.csv  Saved
# Finished
# Get Data for :  ARPO
# - ARPO: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ARPO.csv  Saved
# Finished
# Get Data for :  ARR
# /Users/oppoudel/dev/Python4Finance/Stocks/ARR.csv  Saved
# Finished
# Get Data for :  ARTNA
# /Users/oppoudel/dev/Python4Finance/Stocks/ARTNA.csv  Saved
# Finished
# Get Data for :  ARTW
# /Users/oppoudel/dev/Python4Finance/Stocks/ARTW.csv  Saved
# Finished
# Get Data for :  ARVN
# /Users/oppoudel/dev/Python4Finance/Stocks/ARVN.csv  Saved
# Finished
# Get Data for :  ARW
# /Users/oppoudel/dev/Python4Finance/Stocks/ARW.csv  Saved
# Finished
# Get Data for :  ARWR
# /Users/oppoudel/dev/Python4Finance/Stocks/ARWR.csv  Saved
# Finished
# Get Data for :  ASB
# /Users/oppoudel/dev/Python4Finance/Stocks/ASB.csv  Saved
# Finished
# Get Data for :  ASFI
# - ASFI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ASFI.csv  Saved
# Finished
# Get Data for :  ASGN
# /Users/oppoudel/dev/Python4Finance/Stocks/ASGN.csv  Saved
# Finished
# Get Data for :  ASH
# /Users/oppoudel/dev/Python4Finance/Stocks/ASH.csv  Saved
# Finished
# Get Data for :  ASIX
# /Users/oppoudel/dev/Python4Finance/Stocks/ASIX.csv  Saved
# Finished
# Get Data for :  ASMB
# /Users/oppoudel/dev/Python4Finance/Stocks/ASMB.csv  Saved
# Finished
# Get Data for :  ASNA
# - ASNA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ASNA.csv  Saved
# Finished
# Get Data for :  ASPN
# /Users/oppoudel/dev/Python4Finance/Stocks/ASPN.csv  Saved
# Finished
# Get Data for :  ASPS
# /Users/oppoudel/dev/Python4Finance/Stocks/ASPS.csv  Saved
# Finished
# Get Data for :  ASRT
# /Users/oppoudel/dev/Python4Finance/Stocks/ASRT.csv  Saved
# Finished
# Get Data for :  ASRV
# /Users/oppoudel/dev/Python4Finance/Stocks/ASRV.csv  Saved
# Finished
# Get Data for :  ASTC
# /Users/oppoudel/dev/Python4Finance/Stocks/ASTC.csv  Saved
# Finished
# Get Data for :  ASTE
# /Users/oppoudel/dev/Python4Finance/Stocks/ASTE.csv  Saved
# Finished
# Get Data for :  ASUR
# /Users/oppoudel/dev/Python4Finance/Stocks/ASUR.csv  Saved
# Finished
# Get Data for :  ASYS
# /Users/oppoudel/dev/Python4Finance/Stocks/ASYS.csv  Saved
# Finished
# Get Data for :  ATEC
# /Users/oppoudel/dev/Python4Finance/Stocks/ATEC.csv  Saved
# Finished
# Get Data for :  ATEN
# /Users/oppoudel/dev/Python4Finance/Stocks/ATEN.csv  Saved
# Finished
# Get Data for :  ATGE
# /Users/oppoudel/dev/Python4Finance/Stocks/ATGE.csv  Saved
# Finished
# Get Data for :  ATH
# - ATH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ATH.csv  Saved
# Finished
# Get Data for :  ATHX
# /Users/oppoudel/dev/Python4Finance/Stocks/ATHX.csv  Saved
# Finished
# Get Data for :  ATI
# /Users/oppoudel/dev/Python4Finance/Stocks/ATI.csv  Saved
# Finished
# Get Data for :  ATKR
# /Users/oppoudel/dev/Python4Finance/Stocks/ATKR.csv  Saved
# Finished
# Get Data for :  ATLC
# /Users/oppoudel/dev/Python4Finance/Stocks/ATLC.csv  Saved
# Finished
# Get Data for :  ATLO
# /Users/oppoudel/dev/Python4Finance/Stocks/ATLO.csv  Saved
# Finished
# Get Data for :  ATNI
# /Users/oppoudel/dev/Python4Finance/Stocks/ATNI.csv  Saved
# Finished
# Get Data for :  ATNM
# /Users/oppoudel/dev/Python4Finance/Stocks/ATNM.csv  Saved
# Finished
# Get Data for :  ATNX
# /Users/oppoudel/dev/Python4Finance/Stocks/ATNX.csv  Saved
# Finished
# Get Data for :  ATO
# /Users/oppoudel/dev/Python4Finance/Stocks/ATO.csv  Saved
# Finished
# Get Data for :  ATOS
# /Users/oppoudel/dev/Python4Finance/Stocks/ATOS.csv  Saved
# Finished
# Get Data for :  ATR
# /Users/oppoudel/dev/Python4Finance/Stocks/ATR.csv  Saved
# Finished
# Get Data for :  ATRA
# /Users/oppoudel/dev/Python4Finance/Stocks/ATRA.csv  Saved
# Finished
# Get Data for :  ATRC
# /Users/oppoudel/dev/Python4Finance/Stocks/ATRC.csv  Saved
# Finished
# Get Data for :  ATRI
# /Users/oppoudel/dev/Python4Finance/Stocks/ATRI.csv  Saved
# Finished
# Get Data for :  ATRO
# /Users/oppoudel/dev/Python4Finance/Stocks/ATRO.csv  Saved
# Finished
# Get Data for :  ATRS
# /Users/oppoudel/dev/Python4Finance/Stocks/ATRS.csv  Saved
# Finished
# Get Data for :  ATSG
# /Users/oppoudel/dev/Python4Finance/Stocks/ATSG.csv  Saved
# Finished
# Get Data for :  ATUS
# /Users/oppoudel/dev/Python4Finance/Stocks/ATUS.csv  Saved
# Finished
# Get Data for :  ATVI
# /Users/oppoudel/dev/Python4Finance/Stocks/ATVI.csv  Saved
# Finished
# Get Data for :  AUBN
# /Users/oppoudel/dev/Python4Finance/Stocks/AUBN.csv  Saved
# Finished
# Get Data for :  AUMN
# /Users/oppoudel/dev/Python4Finance/Stocks/AUMN.csv  Saved
# Finished
# Get Data for :  AUTO
# /Users/oppoudel/dev/Python4Finance/Stocks/AUTO.csv  Saved
# Finished
# Get Data for :  AVA
# /Users/oppoudel/dev/Python4Finance/Stocks/AVA.csv  Saved
# Finished
# Get Data for :  AVAV
# /Users/oppoudel/dev/Python4Finance/Stocks/AVAV.csv  Saved
# Finished
# Get Data for :  AVB
# /Users/oppoudel/dev/Python4Finance/Stocks/AVB.csv  Saved
# Finished
# Get Data for :  AVD
# /Users/oppoudel/dev/Python4Finance/Stocks/AVD.csv  Saved
# Finished
# Get Data for :  AVEO
# /Users/oppoudel/dev/Python4Finance/Stocks/AVEO.csv  Saved
# Finished
# Get Data for :  AVGO
# /Users/oppoudel/dev/Python4Finance/Stocks/AVGO.csv  Saved
# Finished
# Get Data for :  AVGR
# /Users/oppoudel/dev/Python4Finance/Stocks/AVGR.csv  Saved
# Finished
# Get Data for :  AVID
# /Users/oppoudel/dev/Python4Finance/Stocks/AVID.csv  Saved
# Finished
# Get Data for :  AVLR
# /Users/oppoudel/dev/Python4Finance/Stocks/AVLR.csv  Saved
# Finished
# Get Data for :  AVNS
# /Users/oppoudel/dev/Python4Finance/Stocks/AVNS.csv  Saved
# Finished
# Get Data for :  AVNW
# /Users/oppoudel/dev/Python4Finance/Stocks/AVNW.csv  Saved
# Finished
# Get Data for :  AVRO
# /Users/oppoudel/dev/Python4Finance/Stocks/AVRO.csv  Saved
# Finished
# Get Data for :  AVT
# /Users/oppoudel/dev/Python4Finance/Stocks/AVT.csv  Saved
# Finished
# Get Data for :  AVTR
# /Users/oppoudel/dev/Python4Finance/Stocks/AVTR.csv  Saved
# Finished
# Get Data for :  AVXL
# /Users/oppoudel/dev/Python4Finance/Stocks/AVXL.csv  Saved
# Finished
# Get Data for :  AVY
# /Users/oppoudel/dev/Python4Finance/Stocks/AVY.csv  Saved
# Finished
# Get Data for :  AVYA
# /Users/oppoudel/dev/Python4Finance/Stocks/AVYA.csv  Saved
# Finished
# Get Data for :  AWI
# /Users/oppoudel/dev/Python4Finance/Stocks/AWI.csv  Saved
# Finished
# Get Data for :  AWK
# /Users/oppoudel/dev/Python4Finance/Stocks/AWK.csv  Saved
# Finished
# Get Data for :  AWR
# /Users/oppoudel/dev/Python4Finance/Stocks/AWR.csv  Saved
# Finished
# Get Data for :  AWRE
# /Users/oppoudel/dev/Python4Finance/Stocks/AWRE.csv  Saved
# Finished
# Get Data for :  AWSM
# - AWSM: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AWSM.csv  Saved
# Finished
# Get Data for :  AX
# /Users/oppoudel/dev/Python4Finance/Stocks/AX.csv  Saved
# Finished
# Get Data for :  AXAS
# /Users/oppoudel/dev/Python4Finance/Stocks/AXAS.csv  Saved
# Finished
# Get Data for :  AXDX
# /Users/oppoudel/dev/Python4Finance/Stocks/AXDX.csv  Saved
# Finished
# Get Data for :  AXE
# - AXE: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/AXE.csv  Saved
# Finished
# Get Data for :  AXGN
# /Users/oppoudel/dev/Python4Finance/Stocks/AXGN.csv  Saved
# Finished
# Get Data for :  AXL
# /Users/oppoudel/dev/Python4Finance/Stocks/AXL.csv  Saved
# Finished
# Get Data for :  AXNX
# /Users/oppoudel/dev/Python4Finance/Stocks/AXNX.csv  Saved
# Finished
# Get Data for :  AXP
# /Users/oppoudel/dev/Python4Finance/Stocks/AXP.csv  Saved
# Finished
# Get Data for :  AXR
# /Users/oppoudel/dev/Python4Finance/Stocks/AXR.csv  Saved
# Finished
# Get Data for :  AXS
# /Users/oppoudel/dev/Python4Finance/Stocks/AXS.csv  Saved
# Finished
# Get Data for :  AXSM
# /Users/oppoudel/dev/Python4Finance/Stocks/AXSM.csv  Saved
# Finished
# Get Data for :  AXTA
# /Users/oppoudel/dev/Python4Finance/Stocks/AXTA.csv  Saved
# Finished
# Get Data for :  AXTI
# /Users/oppoudel/dev/Python4Finance/Stocks/AXTI.csv  Saved
# Finished
# Get Data for :  AYI
# /Users/oppoudel/dev/Python4Finance/Stocks/AYI.csv  Saved
# Finished
# Get Data for :  AYX
# /Users/oppoudel/dev/Python4Finance/Stocks/AYX.csv  Saved
# Finished
# Get Data for :  AZO
# /Users/oppoudel/dev/Python4Finance/Stocks/AZO.csv  Saved
# Finished
# Get Data for :  AZPN
# /Users/oppoudel/dev/Python4Finance/Stocks/AZPN.csv  Saved
# Finished
# Get Data for :  AZZ
# /Users/oppoudel/dev/Python4Finance/Stocks/AZZ.csv  Saved
# Finished
# Get Data for :  B
# /Users/oppoudel/dev/Python4Finance/Stocks/B.csv  Saved
# Finished
# Get Data for :  BA
# /Users/oppoudel/dev/Python4Finance/Stocks/BA.csv  Saved
# Finished
# Get Data for :  BAC
# /Users/oppoudel/dev/Python4Finance/Stocks/BAC.csv  Saved
# Finished
# Get Data for :  BAH
# /Users/oppoudel/dev/Python4Finance/Stocks/BAH.csv  Saved
# Finished
# Get Data for :  BANC
# /Users/oppoudel/dev/Python4Finance/Stocks/BANC.csv  Saved
# Finished
# Get Data for :  BAND
# /Users/oppoudel/dev/Python4Finance/Stocks/BAND.csv  Saved
# Finished
# Get Data for :  BANF
# /Users/oppoudel/dev/Python4Finance/Stocks/BANF.csv  Saved
# Finished
# Get Data for :  BANR
# /Users/oppoudel/dev/Python4Finance/Stocks/BANR.csv  Saved
# Finished
# Get Data for :  BASI
# - BASI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BASI.csv  Saved
# Finished
# Get Data for :  BATRA
# /Users/oppoudel/dev/Python4Finance/Stocks/BATRA.csv  Saved
# Finished
# Get Data for :  BATRK
# /Users/oppoudel/dev/Python4Finance/Stocks/BATRK.csv  Saved
# Finished
# Get Data for :  BAX
# /Users/oppoudel/dev/Python4Finance/Stocks/BAX.csv  Saved
# Finished
# Get Data for :  BBBY
# /Users/oppoudel/dev/Python4Finance/Stocks/BBBY.csv  Saved
# Finished
# Get Data for :  BBCP
# /Users/oppoudel/dev/Python4Finance/Stocks/BBCP.csv  Saved
# Finished
# Get Data for :  BBGI
# /Users/oppoudel/dev/Python4Finance/Stocks/BBGI.csv  Saved
# Finished
# Get Data for :  BBSI
# /Users/oppoudel/dev/Python4Finance/Stocks/BBSI.csv  Saved
# Finished
# Get Data for :  BBW
# /Users/oppoudel/dev/Python4Finance/Stocks/BBW.csv  Saved
# Finished
# Get Data for :  BBY
# /Users/oppoudel/dev/Python4Finance/Stocks/BBY.csv  Saved
# Finished
# Get Data for :  BC
# /Users/oppoudel/dev/Python4Finance/Stocks/BC.csv  Saved
# Finished
# Get Data for :  BCBP
# /Users/oppoudel/dev/Python4Finance/Stocks/BCBP.csv  Saved
# Finished
# Get Data for :  BCC
# /Users/oppoudel/dev/Python4Finance/Stocks/BCC.csv  Saved
# Finished
# Get Data for :  BCEI
# - BCEI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BCEI.csv  Saved
# Finished
# Get Data for :  BCLI
# /Users/oppoudel/dev/Python4Finance/Stocks/BCLI.csv  Saved
# Finished
# Get Data for :  BCO
# /Users/oppoudel/dev/Python4Finance/Stocks/BCO.csv  Saved
# Finished
# Get Data for :  BCOR
# /Users/oppoudel/dev/Python4Finance/Stocks/BCOR.csv  Saved
# Finished
# Get Data for :  BCOV
# /Users/oppoudel/dev/Python4Finance/Stocks/BCOV.csv  Saved
# Finished
# Get Data for :  BCPC
# /Users/oppoudel/dev/Python4Finance/Stocks/BCPC.csv  Saved
# Finished
# Get Data for :  BCRX
# /Users/oppoudel/dev/Python4Finance/Stocks/BCRX.csv  Saved
# Finished
# Get Data for :  BDC
# /Users/oppoudel/dev/Python4Finance/Stocks/BDC.csv  Saved
# Finished
# Get Data for :  BDGE
# - BDGE: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BDGE.csv  Saved
# Finished
# Get Data for :  BDL
# /Users/oppoudel/dev/Python4Finance/Stocks/BDL.csv  Saved
# Finished
# Get Data for :  BDN
# /Users/oppoudel/dev/Python4Finance/Stocks/BDN.csv  Saved
# Finished
# Get Data for :  BDSI
# /Users/oppoudel/dev/Python4Finance/Stocks/BDSI.csv  Saved
# Finished
# Get Data for :  BDX
# /Users/oppoudel/dev/Python4Finance/Stocks/BDX.csv  Saved
# Finished
# Get Data for :  BE
# /Users/oppoudel/dev/Python4Finance/Stocks/BE.csv  Saved
# Finished
# Get Data for :  BEAT
# /Users/oppoudel/dev/Python4Finance/Stocks/BEAT.csv  Saved
# Finished
# Get Data for :  BECN
# /Users/oppoudel/dev/Python4Finance/Stocks/BECN.csv  Saved
# Finished
# Get Data for :  BELFA
# /Users/oppoudel/dev/Python4Finance/Stocks/BELFA.csv  Saved
# Finished
# Get Data for :  BELFB
# /Users/oppoudel/dev/Python4Finance/Stocks/BELFB.csv  Saved
# Finished
# Get Data for :  BEN
# /Users/oppoudel/dev/Python4Finance/Stocks/BEN.csv  Saved
# Finished
# Get Data for :  BERY
# /Users/oppoudel/dev/Python4Finance/Stocks/BERY.csv  Saved
# Finished
# Get Data for :  BFAM
# /Users/oppoudel/dev/Python4Finance/Stocks/BFAM.csv  Saved
# Finished
# Get Data for :  BFIN
# /Users/oppoudel/dev/Python4Finance/Stocks/BFIN.csv  Saved
# Finished
# Get Data for :  BFS
# /Users/oppoudel/dev/Python4Finance/Stocks/BFS.csv  Saved
# Finished
# Get Data for :  BFST
# /Users/oppoudel/dev/Python4Finance/Stocks/BFST.csv  Saved
# Finished
# Get Data for :  BG
# /Users/oppoudel/dev/Python4Finance/Stocks/BG.csv  Saved
# Finished
# Get Data for :  BGCP
# /Users/oppoudel/dev/Python4Finance/Stocks/BGCP.csv  Saved
# Finished
# Get Data for :  BGFV
# /Users/oppoudel/dev/Python4Finance/Stocks/BGFV.csv  Saved
# Finished
# Get Data for :  BGS
# /Users/oppoudel/dev/Python4Finance/Stocks/BGS.csv  Saved
# Finished
# Get Data for :  BGSF
# /Users/oppoudel/dev/Python4Finance/Stocks/BGSF.csv  Saved
# Finished
# Get Data for :  BH
# /Users/oppoudel/dev/Python4Finance/Stocks/BH.csv  Saved
# Finished
# Get Data for :  BHB
# /Users/oppoudel/dev/Python4Finance/Stocks/BHB.csv  Saved
# Finished
# Get Data for :  BHE
# /Users/oppoudel/dev/Python4Finance/Stocks/BHE.csv  Saved
# Finished
# Get Data for :  BHF
# /Users/oppoudel/dev/Python4Finance/Stocks/BHF.csv  Saved
# Finished
# Get Data for :  BHLB
# /Users/oppoudel/dev/Python4Finance/Stocks/BHLB.csv  Saved
# Finished
# Get Data for :  BHR
# /Users/oppoudel/dev/Python4Finance/Stocks/BHR.csv  Saved
# Finished
# Get Data for :  BHVN
# /Users/oppoudel/dev/Python4Finance/Stocks/BHVN.csv  Saved
# Finished
# Get Data for :  BIG
# /Users/oppoudel/dev/Python4Finance/Stocks/BIG.csv  Saved
# Finished
# Get Data for :  BIIB
# /Users/oppoudel/dev/Python4Finance/Stocks/BIIB.csv  Saved
# Finished
# Get Data for :  BIO
# /Users/oppoudel/dev/Python4Finance/Stocks/BIO.csv  Saved
# Finished
# Get Data for :  BIOC
# /Users/oppoudel/dev/Python4Finance/Stocks/BIOC.csv  Saved
# Finished
# Get Data for :  BIOL
# /Users/oppoudel/dev/Python4Finance/Stocks/BIOL.csv  Saved
# Finished
# Get Data for :  BJ
# /Users/oppoudel/dev/Python4Finance/Stocks/BJ.csv  Saved
# Finished
# Get Data for :  BJRI
# /Users/oppoudel/dev/Python4Finance/Stocks/BJRI.csv  Saved
# Finished
# Get Data for :  BK
# /Users/oppoudel/dev/Python4Finance/Stocks/BK.csv  Saved
# Finished
# Get Data for :  BKD
# /Users/oppoudel/dev/Python4Finance/Stocks/BKD.csv  Saved
# Finished
# Get Data for :  BKE
# /Users/oppoudel/dev/Python4Finance/Stocks/BKE.csv  Saved
# Finished
# Get Data for :  BKH
# /Users/oppoudel/dev/Python4Finance/Stocks/BKH.csv  Saved
# Finished
# Get Data for :  BKI
# /Users/oppoudel/dev/Python4Finance/Stocks/BKI.csv  Saved
# Finished
# Get Data for :  BKNG
# /Users/oppoudel/dev/Python4Finance/Stocks/BKNG.csv  Saved
# Finished
# Get Data for :  BKSC
# /Users/oppoudel/dev/Python4Finance/Stocks/BKSC.csv  Saved
# Finished
# Get Data for :  BKTI
# /Users/oppoudel/dev/Python4Finance/Stocks/BKTI.csv  Saved
# Finished
# Get Data for :  BKU
# /Users/oppoudel/dev/Python4Finance/Stocks/BKU.csv  Saved
# Finished
# Get Data for :  BL
# /Users/oppoudel/dev/Python4Finance/Stocks/BL.csv  Saved
# Finished
# Get Data for :  BLBD
# /Users/oppoudel/dev/Python4Finance/Stocks/BLBD.csv  Saved
# Finished
# Get Data for :  BLCM
# /Users/oppoudel/dev/Python4Finance/Stocks/BLCM.csv  Saved
# Finished
# Get Data for :  BLD
# /Users/oppoudel/dev/Python4Finance/Stocks/BLD.csv  Saved
# Finished
# Get Data for :  BLDR
# /Users/oppoudel/dev/Python4Finance/Stocks/BLDR.csv  Saved
# Finished
# Get Data for :  BLFS
# /Users/oppoudel/dev/Python4Finance/Stocks/BLFS.csv  Saved
# Finished
# Get Data for :  BLK
# /Users/oppoudel/dev/Python4Finance/Stocks/BLK.csv  Saved
# Finished
# Get Data for :  BLKB
# /Users/oppoudel/dev/Python4Finance/Stocks/BLKB.csv  Saved
# Finished
# Get Data for :  BLL
# /Users/oppoudel/dev/Python4Finance/Stocks/BLL.csv  Saved
# Finished
# Get Data for :  BLMN
# /Users/oppoudel/dev/Python4Finance/Stocks/BLMN.csv  Saved
# Finished
# Get Data for :  BLUE
# /Users/oppoudel/dev/Python4Finance/Stocks/BLUE.csv  Saved
# Finished
# Get Data for :  BMCH
# - BMCH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BMCH.csv  Saved
# Finished
# Get Data for :  BMI
# /Users/oppoudel/dev/Python4Finance/Stocks/BMI.csv  Saved
# Finished
# Get Data for :  BMRC
# /Users/oppoudel/dev/Python4Finance/Stocks/BMRC.csv  Saved
# Finished
# Get Data for :  BMRN
# /Users/oppoudel/dev/Python4Finance/Stocks/BMRN.csv  Saved
# Finished
# Get Data for :  BMTC
# - BMTC: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BMTC.csv  Saved
# Finished
# Get Data for :  BMY
# /Users/oppoudel/dev/Python4Finance/Stocks/BMY.csv  Saved
# Finished
# Get Data for :  BNED
# /Users/oppoudel/dev/Python4Finance/Stocks/BNED.csv  Saved
# Finished
# Get Data for :  BNFT
# /Users/oppoudel/dev/Python4Finance/Stocks/BNFT.csv  Saved
# Finished
# Get Data for :  BOCH
# - BOCH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BOCH.csv  Saved
# Finished
# Get Data for :  BOH
# /Users/oppoudel/dev/Python4Finance/Stocks/BOH.csv  Saved
# Finished
# Get Data for :  BOKF
# /Users/oppoudel/dev/Python4Finance/Stocks/BOKF.csv  Saved
# Finished
# Get Data for :  BOMN
# /Users/oppoudel/dev/Python4Finance/Stocks/BOMN.csv  Saved
# Finished
# Get Data for :  BOOM
# /Users/oppoudel/dev/Python4Finance/Stocks/BOOM.csv  Saved
# Finished
# Get Data for :  BOOT
# /Users/oppoudel/dev/Python4Finance/Stocks/BOOT.csv  Saved
# Finished
# Get Data for :  BOTJ
# /Users/oppoudel/dev/Python4Finance/Stocks/BOTJ.csv  Saved
# Finished
# Get Data for :  BOX
# /Users/oppoudel/dev/Python4Finance/Stocks/BOX.csv  Saved
# Finished
# Get Data for :  BPFH
# - BPFH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BPFH.csv  Saved
# Finished
# Get Data for :  BPMC
# /Users/oppoudel/dev/Python4Finance/Stocks/BPMC.csv  Saved
# Finished
# Get Data for :  BPOP
# /Users/oppoudel/dev/Python4Finance/Stocks/BPOP.csv  Saved
# Finished
# Get Data for :  BPRN
# /Users/oppoudel/dev/Python4Finance/Stocks/BPRN.csv  Saved
# Finished
# Get Data for :  BPTH
# /Users/oppoudel/dev/Python4Finance/Stocks/BPTH.csv  Saved
# Finished
# Get Data for :  BR
# /Users/oppoudel/dev/Python4Finance/Stocks/BR.csv  Saved
# Finished
# Get Data for :  BRC
# /Users/oppoudel/dev/Python4Finance/Stocks/BRC.csv  Saved
# Finished
# Get Data for :  BREW
# - BREW: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BREW.csv  Saved
# Finished
# Get Data for :  BRG
# /Users/oppoudel/dev/Python4Finance/Stocks/BRG.csv  Saved
# Finished
# Get Data for :  BRID
# /Users/oppoudel/dev/Python4Finance/Stocks/BRID.csv  Saved
# Finished
# Get Data for :  BRKL
# /Users/oppoudel/dev/Python4Finance/Stocks/BRKL.csv  Saved
# Finished
# Get Data for :  BRKR
# /Users/oppoudel/dev/Python4Finance/Stocks/BRKR.csv  Saved
# Finished
# Get Data for :  BRKS
# - BRKS: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BRKS.csv  Saved
# Finished
# Get Data for :  BRN
# /Users/oppoudel/dev/Python4Finance/Stocks/BRN.csv  Saved
# Finished
# Get Data for :  BRO
# /Users/oppoudel/dev/Python4Finance/Stocks/BRO.csv  Saved
# Finished
# Get Data for :  BRT
# /Users/oppoudel/dev/Python4Finance/Stocks/BRT.csv  Saved
# Finished
# Get Data for :  BRX
# /Users/oppoudel/dev/Python4Finance/Stocks/BRX.csv  Saved
# Finished
# Get Data for :  BRY
# /Users/oppoudel/dev/Python4Finance/Stocks/BRY.csv  Saved
# Finished
# Get Data for :  BSET
# /Users/oppoudel/dev/Python4Finance/Stocks/BSET.csv  Saved
# Finished
# Get Data for :  BSGM
# /Users/oppoudel/dev/Python4Finance/Stocks/BSGM.csv  Saved
# Finished
# Get Data for :  BSQR
# /Users/oppoudel/dev/Python4Finance/Stocks/BSQR.csv  Saved
# Finished
# Get Data for :  BSRR
# /Users/oppoudel/dev/Python4Finance/Stocks/BSRR.csv  Saved
# Finished
# Get Data for :  BSTC
# - BSTC: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BSTC.csv  Saved
# Finished
# Get Data for :  BSX
# /Users/oppoudel/dev/Python4Finance/Stocks/BSX.csv  Saved
# Finished
# Get Data for :  BTN
# /Users/oppoudel/dev/Python4Finance/Stocks/BTN.csv  Saved
# Finished
# Get Data for :  BTU
# /Users/oppoudel/dev/Python4Finance/Stocks/BTU.csv  Saved
# Finished
# Get Data for :  BURL
# /Users/oppoudel/dev/Python4Finance/Stocks/BURL.csv  Saved
# Finished
# Get Data for :  BUSE
# /Users/oppoudel/dev/Python4Finance/Stocks/BUSE.csv  Saved
# Finished
# Get Data for :  BV
# /Users/oppoudel/dev/Python4Finance/Stocks/BV.csv  Saved
# Finished
# Get Data for :  BW
# /Users/oppoudel/dev/Python4Finance/Stocks/BW.csv  Saved
# Finished
# Get Data for :  BWA
# /Users/oppoudel/dev/Python4Finance/Stocks/BWA.csv  Saved
# Finished
# Get Data for :  BWEN
# /Users/oppoudel/dev/Python4Finance/Stocks/BWEN.csv  Saved
# Finished
# Get Data for :  BWFG
# /Users/oppoudel/dev/Python4Finance/Stocks/BWFG.csv  Saved
# Finished
# Get Data for :  BWXT
# /Users/oppoudel/dev/Python4Finance/Stocks/BWXT.csv  Saved
# Finished
# Get Data for :  BXC
# /Users/oppoudel/dev/Python4Finance/Stocks/BXC.csv  Saved
# Finished
# Get Data for :  BXMT
# /Users/oppoudel/dev/Python4Finance/Stocks/BXMT.csv  Saved
# Finished
# Get Data for :  BXP
# /Users/oppoudel/dev/Python4Finance/Stocks/BXP.csv  Saved
# Finished
# Get Data for :  BXS
# - BXS: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/BXS.csv  Saved
# Finished
# Get Data for :  BY
# /Users/oppoudel/dev/Python4Finance/Stocks/BY.csv  Saved
# Finished
# Get Data for :  BYD
# /Users/oppoudel/dev/Python4Finance/Stocks/BYD.csv  Saved
# Finished
# Get Data for :  BYFC
# /Users/oppoudel/dev/Python4Finance/Stocks/BYFC.csv  Saved
# Finished
# Get Data for :  BYND
# /Users/oppoudel/dev/Python4Finance/Stocks/BYND.csv  Saved
# Finished
# Get Data for :  BZH
# /Users/oppoudel/dev/Python4Finance/Stocks/BZH.csv  Saved
# Finished
# Get Data for :  C
# /Users/oppoudel/dev/Python4Finance/Stocks/C.csv  Saved
# Finished
# Get Data for :  CABO
# /Users/oppoudel/dev/Python4Finance/Stocks/CABO.csv  Saved
# Finished
# Get Data for :  CAC
# /Users/oppoudel/dev/Python4Finance/Stocks/CAC.csv  Saved
# Finished
# Get Data for :  CACC
# /Users/oppoudel/dev/Python4Finance/Stocks/CACC.csv  Saved
# Finished
# Get Data for :  CACI
# /Users/oppoudel/dev/Python4Finance/Stocks/CACI.csv  Saved
# Finished
# Get Data for :  CADE
# /Users/oppoudel/dev/Python4Finance/Stocks/CADE.csv  Saved
# Finished
# Get Data for :  CAG
# /Users/oppoudel/dev/Python4Finance/Stocks/CAG.csv  Saved
# Finished
# Get Data for :  CAH
# /Users/oppoudel/dev/Python4Finance/Stocks/CAH.csv  Saved
# Finished
# Get Data for :  CAI
# - CAI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CAI.csv  Saved
# Finished
# Get Data for :  CAKE
# /Users/oppoudel/dev/Python4Finance/Stocks/CAKE.csv  Saved
# Finished
# Get Data for :  CAL
# /Users/oppoudel/dev/Python4Finance/Stocks/CAL.csv  Saved
# Finished
# Get Data for :  CALA
# /Users/oppoudel/dev/Python4Finance/Stocks/CALA.csv  Saved
# Finished
# Get Data for :  CALM
# /Users/oppoudel/dev/Python4Finance/Stocks/CALM.csv  Saved
# Finished
# Get Data for :  CALX
# /Users/oppoudel/dev/Python4Finance/Stocks/CALX.csv  Saved
# Finished
# Get Data for :  CAMP
# /Users/oppoudel/dev/Python4Finance/Stocks/CAMP.csv  Saved
# Finished
# Get Data for :  CAPR
# /Users/oppoudel/dev/Python4Finance/Stocks/CAPR.csv  Saved
# Finished
# Get Data for :  CAR
# /Users/oppoudel/dev/Python4Finance/Stocks/CAR.csv  Saved
# Finished
# Get Data for :  CARA
# /Users/oppoudel/dev/Python4Finance/Stocks/CARA.csv  Saved
# Finished
# Get Data for :  CARG
# /Users/oppoudel/dev/Python4Finance/Stocks/CARG.csv  Saved
# Finished
# Get Data for :  CARS
# /Users/oppoudel/dev/Python4Finance/Stocks/CARS.csv  Saved
# Finished
# Get Data for :  CASA
# /Users/oppoudel/dev/Python4Finance/Stocks/CASA.csv  Saved
# Finished
# Get Data for :  CASH
# /Users/oppoudel/dev/Python4Finance/Stocks/CASH.csv  Saved
# Finished
# Get Data for :  CASI
# /Users/oppoudel/dev/Python4Finance/Stocks/CASI.csv  Saved
# Finished
# Get Data for :  CASS
# /Users/oppoudel/dev/Python4Finance/Stocks/CASS.csv  Saved
# Finished
# Get Data for :  CASY
# /Users/oppoudel/dev/Python4Finance/Stocks/CASY.csv  Saved
# Finished
# Get Data for :  CAT
# /Users/oppoudel/dev/Python4Finance/Stocks/CAT.csv  Saved
# Finished
# Get Data for :  CATB
# - CATB: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CATB.csv  Saved
# Finished
# Get Data for :  CATC
# /Users/oppoudel/dev/Python4Finance/Stocks/CATC.csv  Saved
# Finished
# Get Data for :  CATM
# - CATM: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CATM.csv  Saved
# Finished
# Get Data for :  CATO
# /Users/oppoudel/dev/Python4Finance/Stocks/CATO.csv  Saved
# Finished
# Get Data for :  CATS
# - CATS: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CATS.csv  Saved
# Finished
# Get Data for :  CATY
# /Users/oppoudel/dev/Python4Finance/Stocks/CATY.csv  Saved
# Finished
# Get Data for :  CB
# /Users/oppoudel/dev/Python4Finance/Stocks/CB.csv  Saved
# Finished
# Get Data for :  CBAN
# /Users/oppoudel/dev/Python4Finance/Stocks/CBAN.csv  Saved
# Finished
# Get Data for :  CBAY
# /Users/oppoudel/dev/Python4Finance/Stocks/CBAY.csv  Saved
# Finished
# Get Data for :  CBB
# - CBB: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CBB.csv  Saved
# Finished
# Get Data for :  CBFV
# /Users/oppoudel/dev/Python4Finance/Stocks/CBFV.csv  Saved
# Finished
# Get Data for :  CBIO
# /Users/oppoudel/dev/Python4Finance/Stocks/CBIO.csv  Saved
# Finished
# Get Data for :  CBLI
# - CBLI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CBLI.csv  Saved
# Finished
# Get Data for :  CBMG
# - CBMG: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/CBMG.csv  Saved
# Finished
# Get Data for :  CBOE
# /Users/oppoudel/dev/Python4Finance/Stocks/CBOE.csv  Saved
# Finished
# Get Data for :  CBRE
# /Users/oppoudel/dev/Python4Finance/Stocks/CBRE.csv  Saved
# Finished
# Get Data for :  CBRL
# /Users/oppoudel/dev/Python4Finance/Stocks/CBRL.csv  Saved
# Finished
# Get Data for :  CBSH
# /Users/oppoudel/dev/Python4Finance/Stocks/CBSH.csv  Saved
# Finished
# Get Data for :  CBT
# /Users/oppoudel/dev/Python4Finance/Stocks/CBT.csv  Saved
# Finished
# Get Data for :  CBTX
# /Users/oppoudel/dev/Python4Finance/Stocks/CBTX.csv  Saved
# Finished
# Get Data for :  CBU
# /Users/oppoudel/dev/Python4Finance/Stocks/CBU.csv  Saved
# Finished
# Get Data for :  CBZ
# /Users/oppoudel/dev/Python4Finance/Stocks/CBZ.csv  Saved
# Finished
# Get Data for :  CC
# /Users/oppoudel/dev/Python4Finance/Stocks/CC.csv  Saved
# ...
# Finished
# Get Data for :  VIRT
# /Users/oppoudel/dev/Python4Finance/Stocks/VIRT.csv  Saved
# Finished
# Get Data for :  VRTS
# /Users/oppoudel/dev/Python4Finance/Stocks/VRTS.csv  Saved
# Finished
# Get Data for :  VRTU
# - VRTU: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/VRTU.csv  Saved
# Finished
# Get Data for :  V
# /Users/oppoudel/dev/Python4Finance/Stocks/V.csv  Saved
# Finished
# Get Data for :  VSH
# /Users/oppoudel/dev/Python4Finance/Stocks/VSH.csv  Saved
# Finished
# Get Data for :  VPG
# /Users/oppoudel/dev/Python4Finance/Stocks/VPG.csv  Saved
# Finished
# Get Data for :  VISL
# /Users/oppoudel/dev/Python4Finance/Stocks/VISL.csv  Saved
# Finished
# Get Data for :  VSTO
# /Users/oppoudel/dev/Python4Finance/Stocks/VSTO.csv  Saved
# Finished
# Get Data for :  VC
# /Users/oppoudel/dev/Python4Finance/Stocks/VC.csv  Saved
# Finished
# Get Data for :  VST
# /Users/oppoudel/dev/Python4Finance/Stocks/VST.csv  Saved
# Finished
# Get Data for :  VSI
# - VSI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/VSI.csv  Saved
# Finished
# Get Data for :  VSLR
# - VSLR: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/VSLR.csv  Saved
# Finished
# Get Data for :  VVUS
# - VVUS: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/VVUS.csv  Saved
# Finished
# Get Data for :  VMW
# /Users/oppoudel/dev/Python4Finance/Stocks/VMW.csv  Saved
# Finished
# Get Data for :  VCRA
# /Users/oppoudel/dev/Python4Finance/Stocks/VCRA.csv  Saved
# Finished
# Get Data for :  VNRX
# /Users/oppoudel/dev/Python4Finance/Stocks/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/VISI.csv  Saved
# Finished
# Get Data for :  VG
# /Users/oppoudel/dev/Python4Finance/Stocks/VG.csv  Saved
# Finished
# Get Data for :  VNO
# /Users/oppoudel/dev/Python4Finance/Stocks/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# /Users/oppoudel/dev/Python4Finance/Stocks/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# /Users/oppoudel/dev/Python4Finance/Stocks/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# /Users/oppoudel/dev/Python4Finance/Stocks/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# /Users/oppoudel/dev/Python4Finance/Stocks/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# /Users/oppoudel/dev/Python4Finance/Stocks/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# /Users/oppoudel/dev/Python4Finance/Stocks/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# /Users/oppoudel/dev/Python4Finance/Stocks/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# /Users/oppoudel/dev/Python4Finance/Stocks/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# /Users/oppoudel/dev/Python4Finance/Stocks/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# /Users/oppoudel/dev/Python4Finance/Stocks/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# /Users/oppoudel/dev/Python4Finance/Stocks/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# /Users/oppoudel/dev/Python4Finance/Stocks/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# /Users/oppoudel/dev/Python4Finance/Stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# /Users/oppoudel/dev/Python4Finance/Stocks/WBA.csv  Saved
# Finished
# Get Data for :  WD
# /Users/oppoudel/dev/Python4Finance/Stocks/WD.csv  Saved
# Finished
# Get Data for :  WMT
# /Users/oppoudel/dev/Python4Finance/Stocks/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# /Users/oppoudel/dev/Python4Finance/Stocks/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# /Users/oppoudel/dev/Python4Finance/Stocks/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# /Users/oppoudel/dev/Python4Finance/Stocks/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# /Users/oppoudel/dev/Python4Finance/Stocks/WASH.csv  Saved
# Finished
# Get Data for :  WM
# /Users/oppoudel/dev/Python4Finance/Stocks/WM.csv  Saved
# Finished
# Get Data for :  WAT
# /Users/oppoudel/dev/Python4Finance/Stocks/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# /Users/oppoudel/dev/Python4Finance/Stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# /Users/oppoudel/dev/Python4Finance/Stocks/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# /Users/oppoudel/dev/Python4Finance/Stocks/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# /Users/oppoudel/dev/Python4Finance/Stocks/WVE.csv  Saved
# Finished
# Get Data for :  W
# /Users/oppoudel/dev/Python4Finance/Stocks/W.csv  Saved
# Finished
# Get Data for :  WSTG
# /Users/oppoudel/dev/Python4Finance/Stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# /Users/oppoudel/dev/Python4Finance/Stocks/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# /Users/oppoudel/dev/Python4Finance/Stocks/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# /Users/oppoudel/dev/Python4Finance/Stocks/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# /Users/oppoudel/dev/Python4Finance/Stocks/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# /Users/oppoudel/dev/Python4Finance/Stocks/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# /Users/oppoudel/dev/Python4Finance/Stocks/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# /Users/oppoudel/dev/Python4Finance/Stocks/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# /Users/oppoudel/dev/Python4Finance/Stocks/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# /Users/oppoudel/dev/Python4Finance/Stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# /Users/oppoudel/dev/Python4Finance/Stocks/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# /Users/oppoudel/dev/Python4Finance/Stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# /Users/oppoudel/dev/Python4Finance/Stocks/WST.csv  Saved
# Finished
# Get Data for :  WABC
# /Users/oppoudel/dev/Python4Finance/Stocks/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# /Users/oppoudel/dev/Python4Finance/Stocks/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# /Users/oppoudel/dev/Python4Finance/Stocks/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# /Users/oppoudel/dev/Python4Finance/Stocks/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# /Users/oppoudel/dev/Python4Finance/Stocks/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# /Users/oppoudel/dev/Python4Finance/Stocks/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# /Users/oppoudel/dev/Python4Finance/Stocks/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# /Users/oppoudel/dev/Python4Finance/Stocks/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# /Users/oppoudel/dev/Python4Finance/Stocks/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# /Users/oppoudel/dev/Python4Finance/Stocks/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# /Users/oppoudel/dev/Python4Finance/Stocks/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# /Users/oppoudel/dev/Python4Finance/Stocks/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# /Users/oppoudel/dev/Python4Finance/Stocks/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# /Users/oppoudel/dev/Python4Finance/Stocks/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# /Users/oppoudel/dev/Python4Finance/Stocks/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# /Users/oppoudel/dev/Python4Finance/Stocks/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# /Users/oppoudel/dev/Python4Finance/Stocks/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# /Users/oppoudel/dev/Python4Finance/Stocks/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# /Users/oppoudel/dev/Python4Finance/Stocks/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# /Users/oppoudel/dev/Python4Finance/Stocks/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# /Users/oppoudel/dev/Python4Finance/Stocks/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# /Users/oppoudel/dev/Python4Finance/Stocks/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# /Users/oppoudel/dev/Python4Finance/Stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# /Users/oppoudel/dev/Python4Finance/Stocks/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# /Users/oppoudel/dev/Python4Finance/Stocks/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# /Users/oppoudel/dev/Python4Finance/Stocks/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# - WLTW: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# /Users/oppoudel/dev/Python4Finance/Stocks/WSC.csv  Saved
# Finished
# Get Data for :  WING
# /Users/oppoudel/dev/Python4Finance/Stocks/WING.csv  Saved
# Finished
# Get Data for :  WINA
# /Users/oppoudel/dev/Python4Finance/Stocks/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# /Users/oppoudel/dev/Python4Finance/Stocks/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# /Users/oppoudel/dev/Python4Finance/Stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# /Users/oppoudel/dev/Python4Finance/Stocks/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# /Users/oppoudel/dev/Python4Finance/Stocks/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# /Users/oppoudel/dev/Python4Finance/Stocks/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# /Users/oppoudel/dev/Python4Finance/Stocks/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# /Users/oppoudel/dev/Python4Finance/Stocks/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# /Users/oppoudel/dev/Python4Finance/Stocks/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# /Users/oppoudel/dev/Python4Finance/Stocks/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# /Users/oppoudel/dev/Python4Finance/Stocks/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# /Users/oppoudel/dev/Python4Finance/Stocks/INT.csv  Saved
# Finished
# Get Data for :  WWE
# /Users/oppoudel/dev/Python4Finance/Stocks/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# /Users/oppoudel/dev/Python4Finance/Stocks/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# /Users/oppoudel/dev/Python4Finance/Stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# /Users/oppoudel/dev/Python4Finance/Stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# /Users/oppoudel/dev/Python4Finance/Stocks/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/WYND.csv  Saved
# Finished
# Get Data for :  WH
# /Users/oppoudel/dev/Python4Finance/Stocks/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# /Users/oppoudel/dev/Python4Finance/Stocks/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# /Users/oppoudel/dev/Python4Finance/Stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# /Users/oppoudel/dev/Python4Finance/Stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# /Users/oppoudel/dev/Python4Finance/Stocks/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# /Users/oppoudel/dev/Python4Finance/Stocks/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# /Users/oppoudel/dev/Python4Finance/Stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# /Users/oppoudel/dev/Python4Finance/Stocks/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# /Users/oppoudel/dev/Python4Finance/Stocks/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# /Users/oppoudel/dev/Python4Finance/Stocks/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# - XLNX: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# /Users/oppoudel/dev/Python4Finance/Stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# /Users/oppoudel/dev/Python4Finance/Stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# /Users/oppoudel/dev/Python4Finance/Stocks/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# /Users/oppoudel/dev/Python4Finance/Stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# /Users/oppoudel/dev/Python4Finance/Stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# /Users/oppoudel/dev/Python4Finance/Stocks/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# /Users/oppoudel/dev/Python4Finance/Stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# /Users/oppoudel/dev/Python4Finance/Stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# /Users/oppoudel/dev/Python4Finance/Stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# /Users/oppoudel/dev/Python4Finance/Stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# /Users/oppoudel/dev/Python4Finance/Stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# /Users/oppoudel/dev/Python4Finance/Stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# /Users/oppoudel/dev/Python4Finance/Stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# /Users/oppoudel/dev/Python4Finance/Stocks/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# /Users/oppoudel/dev/Python4Finance/Stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# /Users/oppoudel/dev/Python4Finance/Stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# /Users/oppoudel/dev/Python4Finance/Stocks/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# /Users/oppoudel/dev/Python4Finance/Stocks/Z.csv  Saved
# Finished
# Get Data for :  ZG
# /Users/oppoudel/dev/Python4Finance/Stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# /Users/oppoudel/dev/Python4Finance/Stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# /Users/oppoudel/dev/Python4Finance/Stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# - ZIOP: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# - ZIXI: No data found, symbol may be delisted
# /Users/oppoudel/dev/Python4Finance/Stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# /Users/oppoudel/dev/Python4Finance/Stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# /Users/oppoudel/dev/Python4Finance/Stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# /Users/oppoudel/dev/Python4Finance/Stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# /Users/oppoudel/dev/Python4Finance/Stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# /Users/oppoudel/dev/Python4Finance/Stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# /Users/oppoudel/dev/Python4Finance/Stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# /Users/oppoudel/dev/Python4Finance/Stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# /Users/oppoudel/dev/Python4Finance/Stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# /Users/oppoudel/dev/Python4Finance/Stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# /Users/oppoudel/dev/Python4Finance/Stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# /Users/oppoudel/dev/Python4Finance/Stocks/ZNGA.csv  Saved
# Finished
